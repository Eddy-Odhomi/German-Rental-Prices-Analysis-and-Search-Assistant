# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
## Berlin

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_wg_gesucht_data(city, pages=4):
    all_data = []
    for page in range(1, pages + 1):
        url = f"https://www.wg-gesucht.de/wg-zimmer-und-1-zimmer-wohnungen-und-wohnungen-und-haeuser-in-{city}.8.0+1+2+3.1.0.html?pagination={page}"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }

        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        listings = soup.find_all('div', class_='wgg_card offer_list_item')

        for listing in listings:
            title_element = listing.find('h3', class_='truncate_title')
            title = title_element.find('a').get_text(strip=True) if title_element else 'N/A'

            wg_info_element = listing.find('span', text=True)
            wg_type = 'N/A'
            location = 'N/A'
            if wg_info_element:
                wg_info_text = wg_info_element.get_text(separator="|", strip=True)
                wg_info_parts = wg_info_text.split('|')
                if len(wg_info_parts) > 0:
                    wg_type = wg_info_parts[0].strip()
                if len(wg_info_parts) > 1:
                    location = ' | '.join(wg_info_parts[1:]).strip()

            rent_price_element = listing.find('b')
            rent_price = rent_price_element.get_text(strip=True) if rent_price_element and '€' in rent_price_element.get_text() else 'N/A'

            area_element = listing.find_all('b')
            m2 = 'N/A'
            for area in area_element:
                if 'm²' in area.get_text():
                    m2 = area.get_text(strip=True)
                    break

            date_element = listing.find('div', class_='col-xs-5 text-center')
            listed_date = date_element.get_text(strip=True) if date_element else 'N/A'

            owner_element = listing.find('span', class_='ml5')
            owner = owner_element.get_text(strip=True) if owner_element else 'N/A'

            all_data.append({
                'title': title,
                'wg_type': wg_type,
                'location': location,
                'rent_price': rent_price,
                'area': m2,
                'listed_date': listed_date,
                'owner': owner
            })

    return pd.DataFrame(all_data)

berlin_data = get_wg_gesucht_data('Berlin', pages=4)
berlin_data.head(4)
# Out:
# C:\Users\odhomi\AppData\Local\Temp\ipykernel_32624\1357202039.py:22: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   wg_info_element = listing.find('span', text=True)
#                                                                                                                                                                                   title  \
# 0                                                                                                                                FOTOS FOLGEN!!! 2 Zimmer Wohnung von Nov'24 bis Feb'25
# 1                                                                                                                           WG Zimmer in schöner Altbauwohnung Berlin Mitte/ Tiergarten
# 2  URBANELITE.COM // No deposit! (no Kaution) // In the middle of the exclusive Berlin district Berlin Friedrichshain! // All inclusive furnished luxury room close to Alexanderplatz!!
# ...

# %%
pd.set_option('display.max_colwidth', None)
berlin_data['location']
berlin_data
# Out:
#                                                                                                                                                                                     title  \
# 0                                                                                                                                  FOTOS FOLGEN!!! 2 Zimmer Wohnung von Nov'24 bis Feb'25
# 1                                                                                                                             WG Zimmer in schöner Altbauwohnung Berlin Mitte/ Tiergarten
# 2    URBANELITE.COM // No deposit! (no Kaution) // In the middle of the exclusive Berlin district Berlin Friedrichshain! // All inclusive furnished luxury room close to Alexanderplatz!!
# 3                                                                                                                                 Verkehrsgünstiges Studentenzimmer nach Generalsanierung
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_wg_gesucht_data(city, pages=4):
    all_data = []
    for page in range(1, pages + 1):
        url = f"https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }

        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        listings = soup.find_all('div', class_='wgg_card offer_list_item')

        for listing in listings:
            title_element = listing.find('h3', class_='truncate_title')
            title = title_element.find('a').get_text(strip=True) if title_element else 'N/A'

            wg_info_element = listing.find('span', text=True)
            wg_type = 'N/A'
            location = 'N/A'
            if wg_info_element:
                wg_info_text = wg_info_element.get_text(separator="|", strip=True)
                wg_info_parts = wg_info_text.split('|')
                if len(wg_info_parts) > 0:
                    wg_type = wg_info_parts[0].strip()
                if len(wg_info_parts) > 1:
                    location = ' | '.join(wg_info_parts[1:]).strip()

            rent_price_element = listing.find('b')
            rent_price = rent_price_element.get_text(strip=True) if rent_price_element and '€' in rent_price_element.get_text() else 'N/A'

            area_element = listing.find_all('b')
            m2 = 'N/A'
            for area in area_element:
                if 'm²' in area.get_text():
                    m2 = area.get_text(strip=True)
                    break

            date_element = listing.find('div', class_='col-xs-5 text-center')
            listed_date = date_element.get_text(strip=True) if date_element else 'N/A'

            owner_element = listing.find('span', class_='ml5')
            owner = owner_element.get_text(strip=True) if owner_element else 'N/A'

            all_data.append({
                'title': title,
                'wg_type': wg_type,
                'location': location,
                'rent_price': rent_price,
                'area': m2,
                'listed_date': listed_date,
                'owner': owner
            })

    return pd.DataFrame(all_data)

frankfurt_data = get_wg_gesucht_data('Frankfurt', pages=50)
frankfurt_data.head(6)
# Out:
# C:\Users\odhomi\AppData\Local\Temp\ipykernel_32624\2865447035.py:22: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   wg_info_element = listing.find('span', text=True)
#                                                                                       title  \
# 0  Ab 15.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
# 1  Ab 01.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
# 2                                                                           1-Zimmerwohnung
# 3                                                                Ganzes Studio in Frankfurt
# 4                                                Studio-Apartment zu vermieten in Frankfurt
# 5                                                Sie suchen? Wir haben Ihr neues Zuhause...
#
#             wg_type  \
# 0  1-Zimmer-Wohnung
# 1  1-Zimmer-Wohnung
# 2  1-Zimmer-Wohnung
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_wg_gesucht_data(city, pages=4):
    all_data = []
    for page in range(1, pages + 1):
        url = f"https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Stuttgart.124.1.1.0.html"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }

        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        listings = soup.find_all('div', class_='wgg_card offer_list_item')

        for listing in listings:
            title_element = listing.find('h3', class_='truncate_title')
            title = title_element.find('a').get_text(strip=True) if title_element else 'N/A'

            wg_info_element = listing.find('span', text=True)
            wg_type = 'N/A'
            location = 'N/A'
            if wg_info_element:
                wg_info_text = wg_info_element.get_text(separator="|", strip=True)
                wg_info_parts = wg_info_text.split('|')
                if len(wg_info_parts) > 0:
                    wg_type = wg_info_parts[0].strip()
                if len(wg_info_parts) > 1:
                    location = ' | '.join(wg_info_parts[1:]).strip()

            rent_price_element = listing.find('b')
            rent_price = rent_price_element.get_text(strip=True) if rent_price_element and '€' in rent_price_element.get_text() else 'N/A'

            area_element = listing.find_all('b')
            m2 = 'N/A'
            for area in area_element:
                if 'm²' in area.get_text():
                    m2 = area.get_text(strip=True)
                    break

            date_element = listing.find('div', class_='col-xs-5 text-center')
            listed_date = date_element.get_text(strip=True) if date_element else 'N/A'

            owner_element = listing.find('span', class_='ml5')
            owner = owner_element.get_text(strip=True) if owner_element else 'N/A'

            all_data.append({
                'title': title,
                'wg_type': wg_type,
                'location': location,
                'rent_price': rent_price,
                'area': m2,
                'listed_date': listed_date,
                'owner': owner
            })

    return pd.DataFrame(all_data)

stuttgart_data = get_wg_gesucht_data('Stuttgart', pages=50)
stuttgart_data.head(6)
# Out:
# C:\Users\odhomi\AppData\Local\Temp\ipykernel_32624\1201053058.py:22: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   wg_info_element = listing.find('span', text=True)
#                                                                                                                                                                                                   title  \
# 0                                                                                                      Einzelappartement auf dem Campus der Universität Hohenheim (Nur für Studierende!/students only!)
# 1                                                                                                                                                          Möbliertes Studio am Kräherwald mit Terrasse
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_wg_gesucht_data(city, pages=4):
    all_data = []
    for page in range(1, pages + 1):
        url = f"https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }

        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        listings = soup.find_all('div', class_='wgg_card offer_list_item')

        for listing in listings:
            title_element = listing.find('h3', class_='truncate_title')
            title_tag = title_element.find('a') if title_element else None
            title = title_tag.get_text(strip=True) if title_tag else 'N/A'
            listing_url = f"https://www.wg-gesucht.de{title_tag['href']}" if title_tag else 'N/A'

            wg_info_element = listing.find('span', text=True)
            wg_type = 'N/A'
            location = 'N/A'
            if wg_info_element:
                wg_info_text = wg_info_element.get_text(separator="|", strip=True)
                wg_info_parts = wg_info_text.split('|')
                if len(wg_info_parts) > 0:
                    wg_type = wg_info_parts[0].strip()
                if len(wg_info_parts) > 1:
                    location = ' | '.join(wg_info_parts[1:]).strip()

            rent_price_element = listing.find('b')
            rent_price = rent_price_element.get_text(strip=True) if rent_price_element and '€' in rent_price_element.get_text() else 'N/A'

            area_element = listing.find_all('b')
            m2 = 'N/A'
            for area in area_element:
                if 'm²' in area.get_text():
                    m2 = area.get_text(strip=True)
                    break

            date_element = listing.find('div', class_='col-xs-5 text-center')
            listed_date = date_element.get_text(strip=True) if date_element else 'N/A'

            owner_element = listing.find('span', class_='ml5')
            owner = owner_element.get_text(strip=True) if owner_element else 'N/A'

            # Scrape availability
            availability_element = listing.find('span', class_='noprint')
            availability = availability_element.get_text(strip=True) if availability_element else 'N/A'

            # Scrape minimum rental period (duration)
            duration_element = listing.find('span', text='minimum rental period')
            duration = duration_element.get_text(strip=True) if duration_element else 'N/A'

            # Append all the data
            all_data.append({
                'title': title,
                'wg_type': wg_type,
                'location': location,
                'rent_price': rent_price,
                'area': m2,
                'listed_date': listed_date,
                'owner': owner,
                'url': listing_url  # Add the listing URL
            })

    return pd.DataFrame(all_data)

# Test the function
frankfurt_data = get_wg_gesucht_data('Frankfurt', pages=50)
frankfurt_data.head(6)
# Out:
# C:\Users\odhomi\AppData\Local\Temp\ipykernel_32624\2957331043.py:24: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   wg_info_element = listing.find('span', text=True)
# C:\Users\odhomi\AppData\Local\Temp\ipykernel_32624\2957331043.py:56: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   duration_element = listing.find('span', text='minimum rental period')
#                                                                                       title  \
# 0  Ab 15.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
# 1  Ab 01.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
# 2                                                                           1-Zimmerwohnung
# 3                                                                Ganzes Studio in Frankfurt
# ...

# %%
# Making the first column to a listing id

# %%
# Add 'id' column to the existing DataFrame
frankfurt_data.reset_index(inplace=True)
frankfurt_data.rename(columns={'index': 'id'}, inplace=True)

# Display the updated DataFrame with the 'id' column
frankfurt_data
# Out:
#       id  \
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
# ..   ...
# 994  994
# 995  995
# 996  996
# 997  997
# 998  998
#
#                                                                                         title  \
# 0    Ab 15.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
# 1    Ab 01.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
# 2                                                                             1-Zimmerwohnung
# 3                                                                  Ganzes Studio in Frankfurt
# 4                                                  Studio-Apartment zu vermieten in Frankfurt
# ..                                                                                        ...
# 994                      (Verfügbar 1-24 Monate) - Gemütliches, helles ein-Zimmer-Appartement
# ...

# %% [markdown]
# ## frankfurt 11 columns

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_wg_gesucht_data(city, pages=4):
    all_data = []
    for page in range(1, pages+1):
        url = f"https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        listings = soup.find_all('div', class_='wgg_card offer_list_item')
        
        for listing in listings:
            title_element = listing.find('h3', class_='truncate_title')
            title_tag = title_element.find('a') if title_element else None
            title = title_tag.get_text(strip=True) if title_tag else 'N/A'
            listing_url = f"https://www.wg-gesucht.de{title_tag['href']}" if title_tag else 'N/A'
            
            # Extract ID from the URL
            listing_id = 'N/A'
            if listing_url != 'N/A':
                listing_id = listing_url.split('.')[-2]
            
            wg_info_element = listing.find('span', text=True)
            wg_type = 'N/A'
            location = 'N/A'
            if wg_info_element:
                wg_info_text = wg_info_element.get_text(separator="|", strip=True)
                wg_info_parts = wg_info_text.split('|')
                if len(wg_info_parts) > 0:
                    wg_type = wg_info_parts[0].strip()
                if len(wg_info_parts) > 1:
                    location = ' | '.join(wg_info_parts[1:]).strip()
            
            rent_price_element = listing.find('b')
            rent_price = rent_price_element.get_text(strip=True) if rent_price_element and '€' in rent_price_element.get_text() else 'N/A'
            
            area_element = listing.find_all('b')
            m2 = 'N/A'
            for area in area_element:
                if 'm²' in area.get_text():
                    m2 = area.get_text(strip=True)
                    break
            
            date_element = listing.find('div', class_='col-xs-5 text-center')
            listed_date = date_element.get_text(strip=True) if date_element else 'N/A'
            
            owner_element = listing.find('span', class_='ml5')
            owner = owner_element.get_text(strip=True) if owner_element else 'N/A'
            
            all_data.append({
                'id': listing_id,
                'title': title,
                'wg_type': wg_type,
                'location': location,
                'rent_price': rent_price,
                'area': m2,
                'listed_date': listed_date,
                'owner': owner,
            })
    
    frankfurt_data = pd.DataFrame(all_data)
    
    # Clean the location column, but leave the structure intact for splitting
    frankfurt_data['location_clean'] = frankfurt_data['location'].str.replace(r'\n', '', regex=True).str.strip()
    frankfurt_data
    # Split the location into two parts: before and after the first '|'
    location_split = frankfurt_data['location_clean'].str.split('|', n=1, expand=True)
    
    # Now handle the city and neighbourhood from the first part
    frankfurt_data['City'] = location_split[0].str.extract(r'^(.*?)\s')[0].str.strip()
    frankfurt_data['Neighbourhood'] = location_split[0].str.extract(r'\s(.*)$')[0].str.strip()
    
    # Assign the street from the second part
    frankfurt_data['Street'] = location_split[1].str.strip().replace(r'\n', '', regex=True).fillna('N/A')
    
    # Drop the temporary columns
    frankfurt_data = frankfurt_data.drop(['location', 'location_clean'], axis=1)
    
    return frankfurt_data

# Example usage:
city = 'Frankfurt-am-Main'
frankfurt_data = get_wg_gesucht_data(city)
frankfurt_data
# Out:
# C:\Users\odhomi\AppData\Local\Temp\ipykernel_32624\2109744610.py:28: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   wg_info_element = listing.find('span', text=True)
#           id  \
# 0    7673952
# 1   11306130
# 2    9833799
# 3   11347490
# 4   11351848
# ..       ...
# 76  11289752
# 77  11154259
# 78  11010897
# 79  11010925
# 80  11144222
#
#                                                                                        title  \
# 0   Ab 15.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
# 1   Ab 01.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
# 2                                                                            1-Zimmerwohnung
# 3                                                                 Ganzes Studio in Frankfurt
# 4                                                 Studio-Apartment zu vermieten in Frankfurt
# ...

# %% [markdown]
# #FRANKFURT WITH THE EDITED COLUMN WITH TEMPORARY AND PARMANERT COLUMN

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

def get_wg_gesucht_data(city, pages=4):
    all_data = []
    for page in range(1, pages + 1):
        url = f"https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        listings = soup.find_all('div', class_='wgg_card offer_list_item')
        for listing in listings:
            title_element = listing.find('h3', class_='truncate_title')
            title_tag = title_element.find('a') if title_element else None
            title = title_tag.get_text(strip=True) if title_tag else 'N/A'
            listing_url = f"https://www.wg-gesucht.de{title_tag['href']}" if title_tag else 'N/A'
            
            # Extract ID from the URL
            listing_id = 'N/A'
            if listing_url != 'N/A':
                listing_id = listing_url.split('.')[-2]
            
            wg_info_element = listing.find('span', text=True)
            wg_type = 'N/A'
            location = 'N/A'
            if wg_info_element:
                wg_info_text = wg_info_element.get_text(separator="|", strip=True)
                wg_info_parts = wg_info_text.split('|')
                if len(wg_info_parts) > 0:
                    wg_type = wg_info_parts[0].strip()
                if len(wg_info_parts) > 1:
                    location = ' | '.join(wg_info_parts[1:]).strip()
            
            rent_price_element = listing.find('b')
            rent_price = rent_price_element.get_text(strip=True) if rent_price_element and '€' in rent_price_element.get_text() else 'N/A'
            
            area_element = listing.find_all('b')
            m2 = 'N/A'
            for area in area_element:
                if 'm²' in area.get_text():
                    m2 = area.get_text(strip=True)
                    break
            
            date_element = listing.find('div', class_='col-xs-5 text-center')
            listed_date = date_element.get_text(strip=True) if date_element else 'N/A'
            
            owner_element = listing.find('span', class_='ml5')
            owner = owner_element.get_text(strip=True) if owner_element else 'N/A'
            
            all_data.append({
                'id': listing_id,
                'title': title,
                'wg_type': wg_type,
                'location': location,
                'rent_price': rent_price,
                'area': m2,
                'listed_date': listed_date,
                'owner': owner,
            })
    
    frankfurt_data = pd.DataFrame(all_data)
    
    # Clean the location column, but leave the structure intact for splitting
    frankfurt_data['location_clean'] = frankfurt_data['location'].str.replace(r'\n', '', regex=True).str.strip()
    
    # Split the location into two parts: before and after the first '|'
    location_split = frankfurt_data['location_clean'].str.split('|', n=1, expand=True)
    
    # Handle the city and neighbourhood from the first part
    frankfurt_data['City'] = location_split[0].str.extract(r'^(.*?)\s')[0].str.strip()
    frankfurt_data['Neighbourhood'] = location_split[0].str.extract(r'\s(.*)$')[0].str.strip()
    
    # Assign the street from the second part
    frankfurt_data['Street'] = location_split[1].str.strip().replace(r'\n', '', regex=True).fillna('N/A')
    
    # Clean the date field and add a new column for rental type
    frankfurt_data['available_date'] = frankfurt_data['listed_date'].apply(clean_date)
    frankfurt_data['rental_type'] = frankfurt_data['available_date'].apply(lambda x: 'Temporary' if ' - ' in x else 'Long-term')
    
    # Drop the original listed_date column
    frankfurt_data = frankfurt_data.drop('listed_date', axis=1)
    
    # Drop the temporary columns
    frankfurt_data = frankfurt_data.drop(['location', 'location_clean'], axis=1)
    
    return frankfurt_data

def clean_date(date_string):
    # Remove newline characters and extra spaces
    cleaned = re.sub(r'\s+', ' ', date_string).strip()
    
    # Check if there are two dates
    if ' - ' in cleaned:
        # Split the dates and format them
        start, end = cleaned.split(' - ')
        start = start.strip()
        end = end.strip()
        return f"{start} - {end}"
    else:
        # If there's only one date, return it as is
        return cleaned

# Example usage:
city = 'Frankfurt-am-Main'
frankfurt_data = get_wg_gesucht_data(city)
#print(data.head())
frankfurt_data.head(10)
# Out:
# C:\Users\odhomi\AppData\Local\Temp\ipykernel_32624\3611962906.py:28: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   wg_info_element = listing.find('span', text=True)
#          id  \
# 0   4984131
# 1  11207729
# 2   7793297
# 3   8662690
# 4   9145631
# 5  11368413
# 6  11368354
# 7  11366193
# 8   4415968
# 9   9013072
#
#                                                                                                                  title  \
# 0                                  Wochenendpendler als Nachmieter gesucht für möblierte Wohnung im ruhigen Reihenhaus
# 1                                                                                   1-Zimmer Wohnung in Frankfurt City
# 2                                 THE FIZZ Frankfurt - Fully furnished Apartments for Students and Young Professionals
# 3                                THE FIZZ Frankfurt - Vollmöblierte Apartments für Studierende und Young Professionals
# ...

# %%
# !pip install googlemaps

# %%
# using the Geo coding for Frankfurt

# %%
import pandas as pd
from googlemaps import Client
import time

def get_postal_code(address, city, api_key):
    gmaps = Client(key=api_key)
    full_address = f"{address}, {city}, Germany"
    try:
        time.sleep(0.1)  # Add a small delay to avoid hitting rate limits
        result = gmaps.geocode(full_address)
        if result:
            for component in result[0]['address_components']:
                if 'postal_code' in component['types']:
                    return component['long_name']
    except Exception as e:
        print(f"Error geocoding {full_address}: {e}")
    return None

# Replace 'YOUR_API_KEY' with your actual Google Maps API key
api_key = 'API KEY'

# Assuming your DataFrame is named hamburg_data
frankfurt_data['postal_code'] = frankfurt_data.apply(
    lambda row: get_postal_code(row['Street'], row['City'], api_key)
    if row['Street'] != 'N/A' else None,
    axis=1
)

# %%
frankfurt_data.head(10)
# Out:
#          id  \
# 0   4984131
# 1  11207729
# 2   7793297
# 3   8662690
# 4   9145631
# 5  11368413
# 6  11368354
# 7  11366193
# 8   4415968
# 9   9013072
#
#                                                                                                                  title  \
# 0                                  Wochenendpendler als Nachmieter gesucht für möblierte Wohnung im ruhigen Reihenhaus
# 1                                                                                   1-Zimmer Wohnung in Frankfurt City
# 2                                 THE FIZZ Frankfurt - Fully furnished Apartments for Students and Young Professionals
# 3                                THE FIZZ Frankfurt - Vollmöblierte Apartments für Studierende und Young Professionals
# 4                                  THE FIZZ Frankfurt - Vollmöblierte Apartments für Studenten und Young Professionals
# ...

# %% [markdown]
# Stuttgart 11 columns ready to use

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_wg_gesucht_data(city, pages=4):
    all_data = []
    for page in range(1, pages+1):
        url = f"https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Stuttgart.124.1.1.0.html"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        listings = soup.find_all('div', class_='wgg_card offer_list_item')
        
        for listing in listings:
            title_element = listing.find('h3', class_='truncate_title')
            title_tag = title_element.find('a') if title_element else None
            title = title_tag.get_text(strip=True) if title_tag else 'N/A'
            listing_url = f"https://www.wg-gesucht.de{title_tag['href']}" if title_tag else 'N/A'
            
            # Extract ID from the URL
            listing_id = 'N/A'
            if listing_url != 'N/A':
                listing_id = listing_url.split('.')[-2]
            
            wg_info_element = listing.find('span', text=True)
            wg_type = 'N/A'
            location = 'N/A'
            if wg_info_element:
                wg_info_text = wg_info_element.get_text(separator="|", strip=True)
                wg_info_parts = wg_info_text.split('|')
                if len(wg_info_parts) > 0:
                    wg_type = wg_info_parts[0].strip()
                if len(wg_info_parts) > 1:
                    location = ' | '.join(wg_info_parts[1:]).strip()
            
            rent_price_element = listing.find('b')
            rent_price = rent_price_element.get_text(strip=True) if rent_price_element and '€' in rent_price_element.get_text() else 'N/A'
            
            area_element = listing.find_all('b')
            m2 = 'N/A'
            for area in area_element:
                if 'm²' in area.get_text():
                    m2 = area.get_text(strip=True)
                    break
            
            date_element = listing.find('div', class_='col-xs-5 text-center')
            listed_date = date_element.get_text(strip=True) if date_element else 'N/A'
            
            owner_element = listing.find('span', class_='ml5')
            owner = owner_element.get_text(strip=True) if owner_element else 'N/A'
            
            all_data.append({
                'id': listing_id,
                'title': title,
                'wg_type': wg_type,
                'location': location,
                'rent_price': rent_price,
                'area': m2,
                'listed_date': listed_date,
                'owner': owner,
            })
    
    stuttgard_data = pd.DataFrame(all_data)
    
    # Clean the location column, but leave the structure intact for splitting
    stuttgard_data['location_clean'] = stuttgard_data['location'].str.replace(r'\n', '', regex=True).str.strip()
    stuttgard_data
    # Split the location into two parts: before and after the first '|'
    location_split = stuttgard_data['location_clean'].str.split('|', n=1, expand=True)
    
    # Now handle the city and neighbourhood from the first part
    stuttgard_data['City'] = location_split[0].str.extract(r'^(.*?)\s')[0].str.strip()
    stuttgard_data['Neighbourhood'] = location_split[0].str.extract(r'\s(.*)$')[0].str.strip()
    
    # Assign the street from the second part
    stuttgard_data['Street'] = location_split[1].str.strip().replace(r'\n', '', regex=True).fillna('N/A')
    
    # Drop the temporary columns
    stuttgard_data = stuttgard_data.drop(['location', 'location_clean'], axis=1)
    
    return stuttgard_data

# Example usage:
city = 'Frankfurt-am-Main'
stuttgard_data = get_wg_gesucht_data(city)
stuttgard_data
# Out:
# C:\Users\odhomi\AppData\Local\Temp\ipykernel_32624\2635560432.py:28: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   wg_info_element = listing.find('span', text=True)
#           id  \
# 0   11308438
# 1   11224355
# 2    5451423
# 3   10755368
# 4   10170485
# ..       ...
# 73  11123759
# 74  11144203
# 75  11123765
# 76  11123758
# 77  11154217
#
#                                                                                                                          title  \
# 0                                            Möblierte 1-Zimmerwohnung mit TV, Küchenzeile, Dusche/WC, Internet, Waschmaschine
# 1                                                               Zeitwohnen in Stuttgart Cannstatt ab 1 Monat, flexibel buchbar
# 2                             Einzelappartement auf dem Campus der Universität Hohenheim (Nur für Studierende!/students only!)
# ...

# %% [markdown]
# stuttgard with the edited column temporary and permanent

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

def clean_date(date_string):
    """Clean the date string."""
    cleaned = re.sub(r'\s+', ' ', date_string).strip()
    if ' - ' in cleaned:
        start, end = cleaned.split(' - ')
        return f"{start.strip()} - {end.strip()}"
    return cleaned

def get_wg_gesucht_data(city, pages=4):
    all_data = []
    for page in range(1, pages + 1):
        url = f"https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Stuttgart.124.1.1.0.html"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }
        response = requests.get(url, headers=headers)
        
        # Check response status
        if response.status_code != 200:
            print(f"Failed to retrieve page {page}. Status code: {response.status_code}")
            continue
        
        soup = BeautifulSoup(response.content, 'html.parser')
        
        listings = soup.find_all('div', class_='wgg_card offer_list_item')
        if not listings:
            print(f"No listings found on page {page}.")
            continue
        
        for listing in listings:
            title_element = listing.find('h3', class_='truncate_title')
            title_tag = title_element.find('a') if title_element else None
            title = title_tag.get_text(strip=True) if title_tag else 'N/A'
            listing_url = f"https://www.wg-gesucht.de{title_tag['href']}" if title_tag else 'N/A'
            
            listing_id = listing_url.split('.')[-2] if listing_url != 'N/A' else 'N/A'
            
            wg_info_element = listing.find('span', text=True)
            wg_type, location = 'N/A', 'N/A'
            if wg_info_element:
                wg_info_text = wg_info_element.get_text(separator="|", strip=True)
                wg_info_parts = wg_info_text.split('|')
                if wg_info_parts:
                    wg_type = wg_info_parts[0].strip()
                    if len(wg_info_parts) > 1:
                        location = ' | '.join(wg_info_parts[1:]).strip()
            
            rent_price_element = listing.find('b')
            rent_price = rent_price_element.get_text(strip=True) if rent_price_element and '€' in rent_price_element.get_text() else 'N/A'
            
            area_element = listing.find_all('b')
            m2 = 'N/A'
            for area in area_element:
                if 'm²' in area.get_text():
                    m2 = area.get_text(strip=True)
                    break
            
            date_element = listing.find('div', class_='col-xs-5 text-center')
            listed_date = date_element.get_text(strip=True) if date_element else 'N/A'
            
            owner_element = listing.find('span', class_='ml5')
            owner = owner_element.get_text(strip=True) if owner_element else 'N/A'
            
            all_data.append({
                'id': listing_id,
                'title': title,
                'wg_type': wg_type,
                'location': location,
                'rent_price': rent_price,
                'area': m2,
                'listed_date': listed_date,
                'owner': owner,
            })
    
    stuttgart_data = pd.DataFrame(all_data)
    
    # Check if 'listed_date' exists before proceeding
    if 'listed_date' not in stuttgart_data.columns:
        print("The 'listed_date' column is missing from the data.")
        return stuttgart_data
    
    # Clean the listed_date column
    stuttgart_data['available_date'] = stuttgart_data['listed_date'].apply(clean_date)

    # Clean the location column and split into parts
    stuttgart_data['location_clean'] = stuttgart_data['location'].str.replace(r'\n', '', regex=True).str.strip()
    location_split = stuttgart_data['location_clean'].str.split('|', n=1, expand=True)

    stuttgart_data['City'] = location_split[0].str.extract(r'^(.*?)\s')[0].str.strip()
    stuttgart_data['Neighbourhood'] = location_split[0].str.extract(r'\s(.*)$')[0].str.strip()
    stuttgart_data['Street'] = location_split[1].str.strip().replace(r'\n', '', regex=True).fillna('N/A')
    
    stuttgart_data['rental_type'] = stuttgart_data['available_date'].apply(lambda x: 'Temporary' if ' - ' in x else 'Long-term')
    
    # Drop the original listed_date column if no longer needed
    stuttgart_data = stuttgart_data.drop('listed_date', axis=1)
    stuttgart_data = stuttgart_data.drop(['location', 'location_clean'], axis=1)
    
    return stuttgart_data

# Example usage:
city = 'Stuttgart'
stuttgart_data = get_wg_gesucht_data(city)
#print(stuttgart_data.head(10))
stuttgart_data
# Out:
# C:\Users\odhomi\AppData\Local\Temp\ipykernel_32624\633736417.py:43: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   wg_info_element = listing.find('span', text=True)
#            id  \
# 0    10755368
# 1    11257208
# 2    11308438
# 3    11224355
# 4     5451423
# ..        ...
# 99   11323902
# 100  11123765
# 101  11123758
# 102  11295562
# 103  11127133
#
#                                                                                                 title  \
# 0                                                        Möbliertes Studio am Kräherwald mit Terrasse
# 1                                                              Stilvolles Erker Studio in bester Lage
# 2                   Möblierte 1-Zimmerwohnung mit TV, Küchenzeile, Dusche/WC, Internet, Waschmaschine
# 3                                      Zeitwohnen in Stuttgart Cannstatt ab 1 Monat, flexibel buchbar
# ...

# %%
## Go coding usage

# %%
import pandas as pd
from googlemaps import Client
import time

def get_postal_code(address, city, api_key):
    gmaps = Client(key=api_key)
    full_address = f"{address}, {city}, Germany"
    try:
        time.sleep(0.1)  # Add a small delay to avoid hitting rate limits
        result = gmaps.geocode(full_address)
        if result:
            for component in result[0]['address_components']:
                if 'postal_code' in component['types']:
                    return component['long_name']
    except Exception as e:
        print(f"Error geocoding {full_address}: {e}")
    return None

# Replace 'YOUR_API_KEY' with your actual Google Maps API key
api_key = 'API KEY'

# Assuming your DataFrame is named hamburg_data
stuttgard_data['postal_code'] = stuttgard_data.apply(
    lambda row: get_postal_code(row['Street'], row['City'], api_key)
    if row['Street'] != 'N/A' else None,
    axis=1
)

# %%
stuttgard_data
# Out:
#            id  \
# 0    10755368
# 1    11368194
# 2    11257208
# 3    11308438
# 4    11224355
# ..        ...
# 99   11144730
# 100  11127193
# 101  11123758
# 102  11123765
# 103  11123759
#
#                                                                                  title  \
# 0                                         Möbliertes Studio am Kräherwald mit Terrasse
# 1                                                     Apartment mit einem Schlafzimmer
# 2                                               Stilvolles Erker Studio in bester Lage
# 3    Möblierte 1-Zimmerwohnung mit TV, Küchenzeile, Dusche/WC, Internet, Waschmaschine
# 4                       Zeitwohnen in Stuttgart Cannstatt ab 1 Monat, flexibel buchbar
# ..                                                                                 ...
# 99    (Verfügbar 1-24 Monate) - Cosy Apartments - voll ausgestattetes Studio mit Küche
# ...

# %% [markdown]
# # only to compare #######

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_wg_gesucht_data(city='Stuttgart', pages=4):
    all_data = []
    for page in range(1, pages+1):
        # Use the proper Stuttgart URL with pagination
        url = f"https://www.wg-gesucht.de/1-zimmer-wohnungen-in-{city}.124.1.1.{page}.html"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        listings = soup.find_all('div', class_='wgg_card offer_list_item')
        
        for listing in listings:
            title_element = listing.find('h3', class_='truncate_title')
            title_tag = title_element.find('a') if title_element else None
            title = title_tag.get_text(strip=True) if title_tag else 'N/A'
            listing_url = f"https://www.wg-gesucht.de{title_tag['href']}" if title_tag else 'N/A'
            
            # Extract ID from the URL
            listing_id = 'N/A'
            if listing_url != 'N/A':
                listing_id = listing_url.split('.')[-2]
            
            wg_info_element = listing.find('span', text=True)
            wg_type = 'N/A'
            location = 'N/A'
            if wg_info_element:
                wg_info_text = wg_info_element.get_text(separator="|", strip=True)
                wg_info_parts = wg_info_text.split('|')
                if len(wg_info_parts) > 0:
                    wg_type = wg_info_parts[0].strip()
                if len(wg_info_parts) > 1:
                    location = ' | '.join(wg_info_parts[1:]).strip()
            
            rent_price_element = listing.find('b')
            rent_price = rent_price_element.get_text(strip=True) if rent_price_element and '€' in rent_price_element.get_text() else 'N/A'
            
            area_element = listing.find_all('b')
            m2 = 'N/A'
            for area in area_element:
                if 'm²' in area.get_text():
                    m2 = area.get_text(strip=True)
                    break
            
            date_element = listing.find('div', class_='col-xs-5 text-center')
            listed_date = date_element.get_text(strip=True) if date_element else 'N/A'
            
            owner_element = listing.find('span', class_='ml5')
            owner = owner_element.get_text(strip=True) if owner_element else 'N/A'
            
            all_data.append({
                'id': listing_id,
                'title': title,
                'wg_type': wg_type,
                'location': location,
                'rent_price': rent_price,
                'area': m2,
                'listed_date': listed_date,
                'owner': owner,
            })
    
    # Create DataFrame for Stuttgart data
    stuttgard_data = pd.DataFrame(all_data)
    
    # Clean the location column, but leave the structure intact for splitting
    stuttgard_data['location_clean'] = stuttgard_data['location'].str.replace(r'\n', '', regex=True).str.strip()
    
    # Split the location into two parts: before and after the first '|'
    location_split = stuttgard_data['location_clean'].str.split('|', n=1, expand=True)
    
    # Now handle the city and neighbourhood from the first part
    stuttgard_data['City'] = location_split[0].str.extract(r'^(.*?)\s')[0].str.strip()
    stuttgard_data['Neighbourhood'] = location_split[0].str.extract(r'\s(.*)$')[0].str.strip()
    
    # Assign the street from the second part
    stuttgard_data['Street'] = location_split[1].str.strip().replace(r'\n', '', regex=True).fillna('N/A')
    
    # Drop the temporary columns
    stuttgard_data = stuttgard_data.drop(['location', 'location_clean'], axis=1)
    
    return stuttgard_data

# Example usage for Stuttgart:
city = 'Stuttgart'
stuttgard_data = get_wg_gesucht_data(city)
#print(stuttgard_data.head())
stuttgart_data
# Out:
# C:\Users\odhomi\AppData\Local\Temp\ipykernel_21404\1062805404.py:29: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   wg_info_element = listing.find('span', text=True)
#                                                                                                                            title  \
# 0                          Voll möbliertes Apartment inkl. Waschmaschine & Trockenraum in Stuttgart Alt- Sillenbuch zu vermieten
# 1     Gemütliche Studenten und Jungberufstätige \n3 WG-Zimmer in Stuttgart mit sehr guter Anbindung und Einkaufsmöglichkeiten...
# 2                                       möblierte 1-Zi. Wohnung mit Balkon in Stuttgart Nord 70191 befristet zur Untervermietung
# 3                                                                        Studio-Apartment zur Miete in Stuttgart-Nord, Stuttgart
# ...

# %%
## edited the column liisted_date to mm.dd.yyyy

# %%
import pandas as pd

# Sample data for the stuttgard_data DataFrame (assuming it's already created)

# If the dates are mixed, we can use 'dayfirst=True' to handle different date formats
def clean_and_format_date(date_str):
    try:
        # Extract the first part of the date before the newline
        date_part = date_str.split('\n')[0].strip()
        # Try to parse with dayfirst set to True for mixed formats
        return pd.to_datetime(date_part, dayfirst=True).strftime('%m.%d.%Y')
    except ValueError:
        # If there's an issue parsing, return the original string
        return date_str

# Apply the function to the listed_date column
stuttgard_data['listed_date'] = stuttgard_data['listed_date'].apply(clean_and_format_date)

# Display the DataFrame with the changes in the listed_date column
#print(stuttgard_data)
stuttgard_data
# Out:
# C:\Users\odhomi\AppData\Local\Temp\ipykernel_32624\3754308469.py:11: UserWarning: Parsing dates in %m.%d.%Y format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   return pd.to_datetime(date_part, dayfirst=True).strftime('%m.%d.%Y')
#           id                                              title  \
# 0   11357490  1-Zimmer-Wohnung in Stuttgart-Nord (nahe Milan...
# 1   11360095     schöne möblierte 1-Zimmer-Wohnung in Stuttgart
# 2    7172557  Individuelles Apartment in schöner Lage am Ran...
# 3    8029524                                1 Zimmer-Apartement
# 4   11358088  Zentrales und helles Appartment mitten in Stut...
# ..       ...                                                ...
# 73  11127448  (Verfügbar 1-24 Monate) - Hochwertiges Apartme...
# 74  11123765         1-Zimmer-Haus zu vermieten in Steinenbronn
# 75  11295562  Studio-Apartment zur Miete in Stuttgart-Nord, ...
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_wg_gesucht_data(city='Stuttgart', pages=4):
    all_data = []
    for page in range(1, pages+1):
        # Use the proper Stuttgart URL with pagination
        url = f"https://www.wg-gesucht.de/1-zimmer-wohnungen-in-{city}.124.1.1.{page}.html"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        listings = soup.find_all('div', class_='wgg_card offer_list_item')
        
        for listing in listings:
            title_element = listing.find('h3', class_='truncate_title')
            title_tag = title_element.find('a') if title_element else None
            title = title_tag.get_text(strip=True) if title_tag else 'N/A'
            listing_url = f"https://www.wg-gesucht.de{title_tag['href']}" if title_tag else 'N/A'
            
            # Extract ID from the URL
            listing_id = 'N/A'
            if listing_url != 'N/A':
                listing_id = listing_url.split('.')[-2]
            
            wg_info_element = listing.find('span', text=True)
            wg_type = 'N/A'
            location = 'N/A'
            if wg_info_element:
                wg_info_text = wg_info_element.get_text(separator="|", strip=True)
                wg_info_parts = wg_info_text.split('|')
                if len(wg_info_parts) > 0:
                    wg_type = wg_info_parts[0].strip()
                if len(wg_info_parts) > 1:
                    location = ' | '.join(wg_info_parts[1:]).strip()
            
            rent_price_element = listing.find('b')
            rent_price = rent_price_element.get_text(strip=True) if rent_price_element and '€' in rent_price_element.get_text() else 'N/A'
            
            area_element = listing.find_all('b')
            m2 = 'N/A'
            for area in area_element:
                if 'm²' in area.get_text():
                    m2 = area.get_text(strip=True)
                    break
            
            date_element = listing.find('div', class_='col-xs-5 text-center')
            listed_date = date_element.get_text(strip=True) if date_element else 'N/A'
            
            owner_element = listing.find('span', class_='ml5')
            owner = owner_element.get_text(strip=True) if owner_element else 'N/A'
            
            all_data.append({
                'id': listing_id,
                'title': title,
                'wg_type': wg_type,
                'location': location,
                'rent_price': rent_price,
                'area': m2,
                'listed_date': listed_date,
                'owner': owner,
            })
    
    # Create DataFrame for Stuttgart data
    stuttgard_data = pd.DataFrame(all_data)
    
    # Clean the location column, but leave the structure intact for splitting
    stuttgard_data['location_clean'] = stuttgard_data['location'].str.replace(r'\n', '', regex=True).str.strip()
    
    # Split the location into two parts: before and after the first '|'
    location_split = stuttgard_data['location_clean'].str.split('|', n=1, expand=True)
    
    # Now handle the city and neighbourhood from the first part
    stuttgard_data['City'] = location_split[0].str.extract(r'^(.*?)\s')[0].str.strip()
    stuttgard_data['Neighbourhood'] = location_split[0].str.extract(r'\s(.*)$')[0].str.strip()
    
    # Assign the street from the second part
    stuttgard_data['Street'] = location_split[1].str.strip().replace(r'\n', '', regex=True).fillna('N/A')
    
    # Drop the temporary columns
    stuttgard_data = stuttgard_data.drop(['location', 'location_clean'], axis=1)
    
    return stuttgard_data

# Example usage for Stuttgart:
city = 'Stuttgart'
stuttgard_data = get_wg_gesucht_data(city)
#print(stuttgard_data.head())
stuttgard_data
# Out:
# C:\Users\odhomi\AppData\Local\Temp\ipykernel_32624\731812531.py:29: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   wg_info_element = listing.find('span', text=True)
#           id                                              title  \
# 0   11357490  1-Zimmer-Wohnung in Stuttgart-Nord (nahe Milan...
# 1   11360095     schöne möblierte 1-Zimmer-Wohnung in Stuttgart
# 2    7172557  Individuelles Apartment in schöner Lage am Ran...
# 3    8029524                                1 Zimmer-Apartement
# 4   11358088  Zentrales und helles Appartment mitten in Stut...
# ..       ...                                                ...
# 73  11144095  (Verfügbar 1-24 Monate) - Modern möblierte Woh...
# 74  11295562  Studio-Apartment zur Miete in Stuttgart-Nord, ...
# 75  11144203  (Verfügbar 1-24 Monate) - 1 Zimmer Apartment i...
# 76  11123758        1-Zimmer-Wohnung zu vermieten in Waldenbuch
# ...

# %%
### save to csv files

# %%
stuttgard_data.to_csv(f"wg_data_{city}.csv", index=False)
print(f"Data for {city} saved successfully.")
# Out:
# Data for Stuttgart saved successfully.

# %%
## converting the listed_data column with the for mm.dd.yyyy

# %%
#import pandas as pd

# Sample data for the stuttgard_data DataFrame (assuming it's already created)

# If the dates are mixed, we can use 'dayfirst=True' to handle different date formats
def clean_and_format_date(date_str):
    ##try:
        # Extract the first part of the date before the newline
        ##date_part = date_str.split('\n')[0].strip()
        # Try to parse with dayfirst set to True for mixed formats
        return pd.to_datetime(date_part, dayfirst=True).strftime('%m.%d.%Y')
    ##except ValueError:
        # If there's an issue parsing, return the original string
       ## return date_str

# Apply the function to the listed_date column
##stuttgard_data['listed_date'] = stuttgard_data['listed_date'].apply(clean_and_format_date)

# Display the DataFrame with the changes in the listed_date column
#print(stuttgard_data)
##stuttgard_data

# %%
pip install geopy pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_wg_gesucht_data(city='Stuttgart', pages=4):
    all_data = []
    for page in range(1, pages+1):
        # Use the proper Stuttgart URL with pagination
        url = f"https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Stuttgart.124.1.1.0.html"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        listings = soup.find_all('div', class_='wgg_card offer_list_item')
        
        for listing in listings:
            title_element = listing.find('h3', class_='truncate_title')
            title_tag = title_element.find('a') if title_element else None
            title = title_tag.get_text(strip=True) if title_tag else 'N/A'
            listing_url = f"https://www.wg-gesucht.de{title_tag['href']}" if title_tag else 'N/A'
            
            # Extract ID from the URL
            listing_id = 'N/A'
            if listing_url != 'N/A':
                listing_id = listing_url.split('.')[-2]
            
            wg_info_element = listing.find('span', text=True)
            wg_type = 'N/A'
            location = 'N/A'
            if wg_info_element:
                wg_info_text = wg_info_element.get_text(separator="|", strip=True)
                wg_info_parts = wg_info_text.split('|')
                if len(wg_info_parts) > 0:
                    wg_type = wg_info_parts[0].strip()
                if len(wg_info_parts) > 1:
                    location = ' | '.join(wg_info_parts[1:]).strip()
            
            rent_price_element = listing.find('b')
            rent_price = rent_price_element.get_text(strip=True) if rent_price_element and '€' in rent_price_element.get_text() else 'N/A'
            
            area_element = listing.find_all('b')
            m2 = 'N/A'
            for area in area_element:
                if 'm²' in area.get_text():
                    m2 = area.get_text(strip=True)
                    break
            
            date_element = listing.find('div', class_='col-xs-5 text-center')
            listed_date = date_element.get_text(strip=True) if date_element else 'N/A'
            
            owner_element = listing.find('span', class_='ml5')
            owner = owner_element.get_text(strip=True) if owner_element else 'N/A'
            
            all_data.append({
                'id': listing_id,
                'title': title,
                'wg_type': wg_type,
                'location': location,
                'rent_price': rent_price,
                'area': m2,
                'listed_date': listed_date,
                'owner': owner,
            })
    
    # Create DataFrame for Stuttgart data
    stuttgard_data = pd.DataFrame(all_data)
    
    # Clean the location column
    stuttgard_data['location_clean'] = stuttgard_data['location'].str.replace(r'\n', '', regex=True).str.strip()
    
    # Split the location into two parts: before and after the first '|'
    location_split = stuttgard_data['location_clean'].str.split('|', n=1, expand=True)
    
    # Now handle the city and neighbourhood from the first part
    stuttgard_data['City'] = location_split[0].str.extract(r'^(.*?)\s')[0].str.strip()
    stuttgard_data['Neighbourhood'] = location_split[0].str.extract(r'\s(.*)$')[0].str.strip()
    
    # Assign the street from the second part
    stuttgard_data['Street'] = location_split[1].str.strip().replace(r'\n', '', regex=True).fillna('N/A')
    
    # Example mapping of streets to postal codes
    postal_code_mapping = {
        'Kronstädter Straße': '90489',
        'Another Address': 'not found',  # You can add more streets and their postal codes here
        # Add more mappings as needed
    }
    
    # Function to get postal code based on street
    def get_postal_code(street):
        return postal_code_mapping.get(street, 'not found')

    # Apply function to add postal codes
    stuttgard_data['Postal Code'] = stuttgard_data['Street'].apply(get_postal_code)
    
    # Drop the temporary columns
    stuttgard_data = stuttgard_data.drop(['location', 'location_clean'], axis=1)
    
    return stuttgard_data

# Example usage for Stuttgart:
city = 'Stuttgart'
stuttgard_data = get_wg_gesucht_data(city)
#print(stuttgard_data)
stuttgard_data
# Out:
# C:\Users\odhomi\AppData\Local\Temp\ipykernel_32624\565794236.py:29: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   wg_info_element = listing.find('span', text=True)
#            id  \
# 0    10755368
# 1    11368194
# 2    11257208
# 3    11308438
# 4    11224355
# ..        ...
# 99   11144730
# 100  11127193
# 101  11123758
# 102  11123765
# 103  11123759
#
#                                                                                  title  \
# 0                                         Möbliertes Studio am Kräherwald mit Terrasse
# 1                                                     Apartment mit einem Schlafzimmer
# 2                                               Stilvolles Erker Studio in bester Lage
# 3    Möblierte 1-Zimmerwohnung mit TV, Küchenzeile, Dusche/WC, Internet, Waschmaschine
# 4                       Zeitwohnen in Stuttgart Cannstatt ab 1 Monat, flexibel buchbar
# ...

# %%
# !pip install googlemaps

# %%
import pandas as pd
from googlemaps import Client
import time

def get_postal_code(address, city, api_key):
    gmaps = Client(key=api_key)
    full_address = f"{address}, {city}, Germany"
    try:
        time.sleep(0.1)  # Add a small delay to avoid hitting rate limits
        result = gmaps.geocode(full_address)
        if result:
            for component in result[0]['address_components']:
                if 'postal_code' in component['types']:
                    return component['long_name']
    except Exception as e:
        print(f"Error geocoding {full_address}: {e}")
    return None

# Replace 'YOUR_API_KEY' with your actual Google Maps API key
api_key = 'API KEY'

# Assuming your DataFrame is named hamburg_data
stuttgard_data['postal_code'] = stuttgard_data.apply(
    lambda row: get_postal_code(row['Street'], row['City'], api_key)
    if row['Street'] != 'N/A' else None,
    axis=1
)

# %%
stuttgard_data
# Out:
#            id  \
# 0    10755368
# 1    11368194
# 2    11257208
# 3    11308438
# 4    11224355
# ..        ...
# 99   11144730
# 100  11127193
# 101  11123758
# 102  11123765
# 103  11123759
#
#                                                                                  title  \
# 0                                         Möbliertes Studio am Kräherwald mit Terrasse
# 1                                                     Apartment mit einem Schlafzimmer
# 2                                               Stilvolles Erker Studio in bester Lage
# 3    Möblierte 1-Zimmerwohnung mit TV, Küchenzeile, Dusche/WC, Internet, Waschmaschine
# 4                       Zeitwohnen in Stuttgart Cannstatt ab 1 Monat, flexibel buchbar
# ..                                                                                 ...
# 99    (Verfügbar 1-24 Monate) - Cosy Apartments - voll ausgestattetes Studio mit Küche
# ...
