# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
url = "https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html"

# %%
look = requests.get(url)

# %%
print(look)
# Out:
# <Response [200]>

# %%
html_page = BeautifulSoup(response.content, "html.parser")

# Now you can extract data from 'html_page'
print(html_page.prettify())  # Prints the HTML in a readable format
# Out:
# <!DOCTYPE html>
# <html lang="de">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" id="viewport" name="viewport"/>
#   <meta content="WG-Gesucht.de" name="Author"/>
#   <meta content="NOARCHIVE" name="ROBOTS"/>
#   <script data-cmp-ab="1">
#    window.cmp_block_ignoredomains = [
#                 "stripe.com",
#                 "meineschufa.de",
#                 "my.matterport.com",
#                 "recaptcha.net",
#                 "paypal.com",
#                 "acrobatservices.adobe.com",
#                 "itsmydata.de",
#                 "static.elfsight.com"
#             ];
#   </script>
#   <script data-cmp-ab="1" data-cmp-cdn="cdn.consentmanager.net" data-cmp-host="a.delivery.consentmanager.net" data-cmp-id="15144" src="https://cdn.consentmanager.net/delivery/autoblock/15144.js" type="text/javascript">
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# ...

# %%
 soup = BeautifulSoup(look.content,"html")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="de">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width" id="viewport" name="viewport"/>
# <meta content="WG-Gesucht.de" name="Author"/>
# <meta content="NOARCHIVE" name="ROBOTS"/>
# <script data-cmp-ab="1">
#             window.cmp_block_ignoredomains = [
#                 "stripe.com",
#                 "meineschufa.de",
#                 "my.matterport.com",
#                 "recaptcha.net",
#                 "paypal.com",
#                 "acrobatservices.adobe.com",
#                 "itsmydata.de",
#                 "static.elfsight.com"
#             ];
#         </script>
# <script data-cmp-ab="1" data-cmp-cdn="cdn.consentmanager.net" data-cmp-host="a.delivery.consentmanager.net" data-cmp-id="15144" src="https://cdn.consentmanager.net/delivery/autoblock/15144.js" type="text/javascript"></script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="de">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" id="viewport" name="viewport"/>
#   <meta content="WG-Gesucht.de" name="Author"/>
#   <meta content="NOARCHIVE" name="ROBOTS"/>
#   <script data-cmp-ab="1">
#    window.cmp_block_ignoredomains = [
#                 "stripe.com",
#                 "meineschufa.de",
#                 "my.matterport.com",
#                 "recaptcha.net",
#                 "paypal.com",
#                 "acrobatservices.adobe.com",
#                 "itsmydata.de",
#                 "static.elfsight.com"
#             ];
#   </script>
#   <script data-cmp-ab="1" data-cmp-cdn="cdn.consentmanager.net" data-cmp-host="a.delivery.consentmanager.net" data-cmp-id="15144" src="https://cdn.consentmanager.net/delivery/autoblock/15144.js" type="text/javascript">
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# ...

# %%
Look = r"""

<!DOCTYPE html>
<html lang="de">
 <head>
  <meta charset="utf-8"/>
  <meta content="width=device-width" id="viewport" name="viewport"/>
  <meta content="WG-Gesucht.de" name="Author"/>
  <meta content="NOARCHIVE" name="ROBOTS"/>
  <script data-cmp-ab="1">
   window.cmp_block_ignoredomains = [
                "stripe.com",
                "meineschufa.de",
                "my.matterport.com",
                "recaptcha.net",
                "paypal.com",
                "acrobatservices.adobe.com",
                "itsmydata.de",
                "static.elfsight.com"
            ];
  </script>
  <script data-cmp-ab="1" data-cmp-cdn="cdn.consentmanager.net" data-cmp-host="a.delivery.consentmanager.net" data-cmp-id="15144" src="https://cdn.consentmanager.net/delivery/autoblock/15144.js" type="text/javascript">
  </script>
  <script>
   (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
        new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
        j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
        'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
        })(window,document,'script','dataLayer','GTM-N9G6Q9V');
  </script>
  <title>
   Wohnungen Frankfurt am Main : 1-Zimmer-Wohnungen Angebote in Frankfurt am Main Wohnungen Frankfurt am Main in Frankfurt am Main
  </title>
  <meta content="Wohnungen Frankfurt am Main : 1-Zimmer-Wohnungen Angebote in Frankfurt am Main Wohnungen Frankfurt am Main in Frankfurt am Main" name="title"/>
  <link href="https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html" rel="canonical"/>
  <meta content="false" name="pinterest-rich-pin"/>
  <meta content="WG Zimmer Wohnungsmarkt Wohnungssuche Mietwohnung Suche Biete anbieten Angebot Zwischenmiete Wohnung Zimmersuche Wohnung Wohnungen Mietwohnungen Mietgesuche Mietangebote Wohnungsangebote Wohnungsanzeigen Schweiz Österreich Berlin Stuttgart Hamburg München Köln" name="Keywords"/>
  <meta content="Wohnungen Frankfurt am Main. Kostenlose Wohnungs-Börse mit über 200.000 aktuellen Anzeigen - provisionsfrei! Jetzt kostenlos inserieren in Frankfurt am Main!" name="Description"/>
  <meta content="de" name="locale"/>
  <link href="https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html" hreflang="de" rel="alternate"/>
  <link href="https://www.wg-gesucht.de/en/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html" hreflang="en" rel="alternate"/>
  <link href="https://www.wg-gesucht.de/es/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html" hreflang="es" rel="alternate"/>
  <meta content="app-id=1084293678" name="apple-itunes-app"/>
  <meta content="app-id=com.wggesucht.android" name="google-play-app"/>
  <link href="https://www.wg-gesucht.de/img/preview/ang/liste/thumb_3.jpg" rel="image_src"/>
  <meta content="https://www.wg-gesucht.de/img/preview/ang/liste/thumb_3.jpg" itemprop="image" property="og:image"/>
  <meta content="article" property="og:type"/>
  <meta content="Wohnungen Frankfurt am Main : 1-Zimmer-Wohnungen Angebote in Frankfurt am Main Wohnungen Frankfurt am Main in Frankfurt am Main" property="og:title"/>
  <meta content="WG-Gesucht.de" property="og:site_name"/>
  <meta content="865138980249899" property="fb:app_id"/>
  <meta content="https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html" property="og:url"/>
  <meta content="" property="og:description"/>
  <meta content="summary" name="twitter:card"/>
  <meta content="" name="twitter:site"/>
  <meta content="WG-Gesucht.de - Wohnungen Frankfurt am Main : 1-Zimmer-Wohnungen Angebote in Frankfurt am Main Wohnungen Frankfurt am Main in Frankfurt am Main" name="twitter:title"/>
  <meta content="Wohnungen Frankfurt am Main. Kostenlose Wohnungs-Börse mit über 200.000 aktuellen Anzeigen - provisionsfrei! Jetzt kostenlos inserieren in Frankfurt am Main!" name="twitter:description"/>
  <meta content="https://www.wg-gesucht.de/img/twitter_card_logo.png" name="twitter:image"/>
  <link href="/assets/css/featherlight/featherlight.min.tjb1632386797.css" media="screen" rel="stylesheet" type="text/css"/>
  <link href="/assets/css/croppie.min.tjb1632386797.css" media="screen" rel="stylesheet" type="text/css"/>
  <link href="/js/external_libraries/bootstrap-select-1.13.9/css/bootstrap-select.min.css" rel="stylesheet"/>
  <link href="/assets/css/wgg-styles-compiled.min.tjb1726052798.css" media="screen" rel="stylesheet" type="text/css"/>
  <link href="/assets/css/master_printer-2-3-5.min.css" media="print" rel="stylesheet" type="text/css"/>
  <!--[if lt IE 9]>
          <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
          <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
        <![endif]-->
  <style>
   @-webkit-viewport   { width: device-width; }
            @-moz-viewport      { width: device-width; }
            @-ms-viewport       { width: device-width; }
            @-o-viewport        { width: device-width; }
            @viewport           { width: device-width; }
  </style>
  <script>
   if (navigator.userAgent.match(/IEMobile\/10\.0/)) {
                var msViewportStyle = document.createElement("style");
                msViewportStyle.appendChild(
                    document.createTextNode(
                        "@-ms-viewport{ width:auto!important }"
                    )
                );
                document.getElementsByTagName("head")[0].appendChild(msViewportStyle);
            }
  </script>
  <link href="/assets/favicon/favicon_wg_gesucht.ico" rel="shortcut icon"/>
  <link href="assets/precomposed/apple-touch-icon-144x144-precomposed-wg-gesucht.png" rel="apple-touch-icon" sizes="144x144"/>
  <link href="assets/precomposed/apple-touch-icon-120x120-precomposed-wg-gesucht.png" rel="apple-touch-icon" sizes="120x120"/>
  <link href="assets/precomposed/apple-touch-icon-114x114-precomposed-wg-gesucht.png" rel="apple-touch-icon" sizes="114x114"/>
  <link href="assets/precomposed/apple-touch-icon-72x72-precomposed-wg-gesucht.png" rel="apple-touch-icon" sizes="72x72"/>
  <link href="assets/precomposed/apple-touch-icon-precomposed-wg-gesucht.png" rel="apple-touch-icon"/>
  <script>
   window.onerror = function(msg, file, line) {
                return true;
            };
  </script>
  <script src="/js/jquery/jquery-3.6.3/jquery-3.6.3.min.js">
  </script>
  <script src="/js/jquery/jquery-migrate-3.4.0/jquery-migrate-3.4.0.min.js">
  </script>
  <script src="/js/external_libraries/bootstrap-3.3.7/bootstrap-3.3.7.full.min.js">
  </script>
  <script src="https://www.wg-gesucht.de/js/translations/de_de/functions.js">
  </script>
  <script src="/js/functions.tjb1711551598.js">
  </script>
  <link href="https://cdn.consentmanager.mgr.consensu.org/delivery/cmp.min.css" rel="stylesheet"/>
  <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
  </script>
  <script>
   var googletag = googletag || {};
    googletag.cmd = googletag.cmd || [];

    googletag.cmd.push(function() {
        googletag.pubads().enableAsyncRendering();
        googletag.pubads().collapseEmptyDivs(true);

                    googletag.defineSlot('/1009105/d_MR_AG_liste_LHS1', [300, 250], 'div-gpt-ad-1579038499204-0').addService(googletag.pubads());
        
                    googletag.pubads().setTargeting("wgg_city", "frankfurt-am-main");
                            googletag.pubads().setTargeting("cityname", "Frankfurt-am-Main");
                            googletag.pubads().setTargeting("wgg_pic", "1");
                            googletag.pubads().setTargeting("wgg_rubrik", "1");
                            googletag.pubads().setTargeting("wgg_rubrik", "1");
                            googletag.pubads().setTargeting("wgg_pos", "angebote_liste_details");
                            googletag.pubads().setTargeting("wgg_bula", "Hessen");
                                            googletag.pubads().setTargeting("wgg_rent_type", "0");
                        googletag.enableServices();
    });
  </script>
  <script src="//storage.googleapis.com/adtags/wg-gesucht/wg-gesucht.de_ang_liste_PreCall.js" type="text/javascript">
  </script>
  <script src="https://www.googletagservices.com/tag/js/gpt.js">
  </script>
  <script src="//storage.googleapis.com/adtags/wg-gesucht/wg-gesucht.de_ang_liste_AdCall.js" type="text/javascript">
  </script>
  <script>
   console.log('qm init ang list');
  </script>
  <script>
   var site_language          = 'de';
        var current_document_width = $(window).width();
        var domain_base            = 'https://www.wg-gesucht.de/';
        var login_url              = 'https://www.wg-gesucht.de/mein-wg-gesucht.html';
        var user_id                = '';
        var image_folder_path      = 'https://img.wg-gesucht.de/';
        var site_name              = 'WG-Gesucht.de';
        var language_url_prefix    = '';
        var logged_in              = '';

        var conversations_list_url       = 'nachrichten.html';
        var conversation_list_parameters = {
            next_page_url : '',
            current_page  : '1',
            ad_type       : '',
            filter_type   : '',
            filter_ad_id  : '',
            filter_tag_id : ''
        }
  </script>
  <script src="/js/lib/Validation/Validation.lib.tjb1721404928.js">
  </script>
  <script src="/js/lib/Cookies.lib.tjb1632386809.js">
  </script>
  <script src="/js/lib/UserInterface.lib.tjb1690470423.js">
  </script>
  <script src="/js/lib/DataManipulation.lib.tjb1632386809.js">
  </script>
  <script src="/js/lib/Logger.class.tjb1632386809.js">
  </script>
  <script src="/js/lib/TranslationLoader.class.tjb1632386809.js">
  </script>
  <script>
   if (!window.translationLoader) {
            window.translationLoader = TranslationLoader({
                language: site_language,
                min_log_level: '5'
            });
        }
  </script>
  <script src="/js/lib/ApiCaller.class.tjb1708513618.js">
  </script>
  <script>
   if (!window.api_caller) {
            window.api_caller = ApiCaller({
                user_id      :   user_id,
                smp_client   : 'WG-Gesucht',
                min_log_level: '5'
            });
        }
  </script>
  <script src="/js/lib/Services.lib.tjb1726503339.js">
  </script>
  <script src="/js/lib/ProfileManipulation.lib.tjb1632386809.js">
  </script>
  <script src="/js/external_libraries/bootstrap-select-1.13.9/js/bootstrap-select.min.js">
  </script>
  <script src="/js/external_libraries/bootstrap-select-1.13.9/js/i18n/defaults-de_DE.min.js">
  </script>
  <script>
   // Methods startsWith() and endsWith() are not supported by IE, using polyfills
        // String.prototype.startsWith() & String.prototype.endsWith() instead, as they are required for
        // autocomplete city select box, User filters, etc
        //
        // Fix references from Mozilla Developer Network:
        // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/String/startsWith
        // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/String/endsWith
        if (!String.prototype.startsWith) {
            String.prototype.startsWith = function(searchString, position) {
                return this.substr(position || 0, searchString.length) === searchString;
            };
        }

        if (!String.prototype.endsWith) {
            String.prototype.endsWith = function(searchString, position) {
            var subjectString = this.toString();
            if (typeof position !== 'number' || !isFinite(position) || Math.floor(position) !== position || position > subjectString.length) {
                position = subjectString.length;
            }
            position -= searchString.length;
            var lastIndex = subjectString.lastIndexOf(searchString, position);
            return lastIndex !== -1 && lastIndex === position;
          };
        }
  </script>
 </head>
 <body>
  <noscript>
   <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-N9G6Q9V" style="display:none;visibility:hidden" width="0">
   </iframe>
  </noscript>
  <noscript>
   <div class="alert alert-with-icon alert-danger">
    <span class="mdi mdi-alert-circle" style="left: 15px;">
    </span>
    <div class="alert-body">
     <p>
      Bitte beachten Sie, dass Javascript aktiviert sein muss, um alle Funktionen auf  WG-Gesucht nutzen zu können. Ohne Javascript stehen Ihnen einige Funktionen nicht zur Verfügung. Bitte aktivieren Sie Javascript, bevor Sie fortfahren.
     </p>
    </div>
   </div>
  </noscript>
  <script src="/ajax/api/Smp/js/lib/functions.min.tjb1636445899.js">
  </script>
  <script src="/ajax/api/Smp/js/lib/error_handler.min.tjb1632386797.js">
  </script>
  <script>
   var password_contains_word_password             = /^p[a|@|ä|á|à][s|\$|5]{2,}w[o|0|ö|ó|ò]r[d|t]$/ui;
        var password_contains_single_character_repeated = /^(.)\1{7,}$/ui;
        var password_contains_letmein                   = /l[e|3|ë|é|è]tm[e|3|ë|é|è][i|1|ï|í|ì]n/ui;
  </script>
  <script>
   window.status = '';
  </script>
  <script>
   var empty_error               = "";
        var invalid_error             = "";
        var not_enough_error_required = "";
        var invalid_error             = "";
        var not_valid_email           = "";
        var too_short_error           = "";
        var too_long_error            = "";
        var no_match_error            = "";
        var too_small_error           = "";
  </script>
  <div class="position-relative" id="master_wrapper">
   <div class="noprint">
    <div class="noprint">
     <div id="qm_ad_wrapper">
      <!-- QM Superbanner -->
      <div class="noprint" id="qm-leaderboard">
       <div id="div-gpt-ad-189159851654146248-1">
        <script type="text/javascript">
         googletag.cmd.push(function() { googletag.display('div-gpt-ad-189159851654146248-1'); });
        </script>
       </div>
      </div>
      <div class="noprint" id="qm-sky-right">
       <!-- QM Sky Right -->
       <div id="div-gpt-ad-189159851654146248-3">
        <script type="text/javascript">
         googletag.cmd.push(function() { googletag.display('div-gpt-ad-189159851654146248-3'); });
        </script>
       </div>
      </div>
     </div>
    </div>
    <script type="text/javascript">
     console.log('qm ad wrapper loaded');
    </script>
   </div>
   <div class="container" id="site_wrapper">
    <div class="noprint" id="main-nav-wrapper">
     <nav class="navbar navbar-default desktop_nav hidden-xs hidden-sm">
      <div class="navbar-header">
       <a href="https://www.wg-gesucht.de/">
        <img alt="WG-Gesucht.de" class="logo-desktop" src="/img/WGG_logo_nav.png" title="WG-Gesucht.de"/>
       </a>
      </div>
      <div class="nav navbar-nav">
       <div class="dropdown-mega">
        <a href="#">
         Angebote/Gesuche
        </a>
        <div class="dropdown-mega-content">
         <div class="position-relative" style="left: 15%;">
          <div class="dropdown-mega-subcontent">
           <b class="dropdown-mega-content-heading">
            Angebote
           </b>
           <a href="/wg-zimmer-in-Frankfurt-am-Main.41.0.1.0.html">
            WG-Zimmer
           </a>
           <a class="active_nav_sub" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html">
            1-Zimmer-Wohnung
           </a>
           <a href="/wohnungen-in-Frankfurt-am-Main.41.2.1.0.html">
            Wohnung
           </a>
           <a href="/haeuser-in-Frankfurt-am-Main.41.3.1.0.html">
            Haus
           </a>
          </div>
          <div class="dropdown-mega-subcontent">
           <b class="dropdown-mega-content-heading">
            Gesuche
           </b>
           <a href="/wg-zimmer-in-Frankfurt-am-Main-gesucht.41.0.1.0.html">
            WG-Zimmer
           </a>
           <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-gesucht.41.1.1.0.html">
            1-Zimmer-Wohnung
           </a>
           <a href="/wohnungen-in-Frankfurt-am-Main-gesucht.41.2.1.0.html">
            Wohnung
           </a>
           <a href="/haeuser-in-Frankfurt-am-Main-gesucht.41.3.1.0.html">
            Haus
           </a>
          </div>
         </div>
        </div>
       </div>
       <div class="dropdown-mega">
        <a href="#">
         Infos &amp; Ratgeber
        </a>
        <div class="dropdown-mega-content">
         <div class="position-relative" style="left: 30%">
          <div class="dropdown-mega-subcontent">
           <a href="/info/anbieter">
            Anbieter
           </a>
           <a href="/info/magazin">
            Magazin
           </a>
           <a href="/mietrecht.html">
            Mietrecht
           </a>
           <a href="/info/netiquette">
            Netiquette
           </a>
          </div>
          <div class="dropdown-mega-subcontent">
           <a href="/info/schufa-bonitaetscheck">
            SCHUFA
           </a>
           <a href="/info/sicherheit">
            Sicherheit
           </a>
           <a href="/info/wg-suche">
            Suchende
           </a>
           <a href="/info/wg-arten">
            WG-Arten
           </a>
          </div>
          <div class="dropdown-mega-subcontent">
           <a href="/info/wg-ratgeber">
            WG-Ratgeber
           </a>
           <a href="/info/wohnen-in">
            Wohnen in
           </a>
          </div>
         </div>
        </div>
       </div>
       <div class="dropdown-mega">
        <a href="/fuer-immobilienprofis.html" rel="nofollow" target="_blank">
         Für Unternehmen
        </a>
       </div>
       <div class="dropdown-mega">
        <a data-target="#proof_of_credit_modal_nav" data-toggle="modal" href="#">
         SCHUFA-Auskunft
        </a>
       </div>
       <div class="dropdown-mega">
        <a href="#" style="font-weight: 500;">
         Anzeige inserieren
        </a>
        <div class="dropdown-mega-content">
         <div class="position-relative" style="left: 71.5%;">
          <div class="dropdown-mega-subcontent">
           <a href="/get-started.html" rel="nofollow">
            Angebot inserieren
           </a>
           <a href="/gesuch-aufgeben.html" rel="nofollow">
            Gesuch inserieren
           </a>
          </div>
          <a class="btn wgg_darkgray button_shop" data-google-interstitial="false" href="get-started.html">
           Schon ab
           <b>
            29,90€
           </b>
           <br/>
           Exklusive Angebote
           <br/>
           für Immobilien-Profis
          </a>
          <p class="position-relative" style="left: 19%; margin-top: 7px;">
           <a class="black_text_link text-bold" href="#" onclick='fireLoginOrRegisterModalRequest("sign_up");'>
            Kostenfrei registrieren
           </a>
          </p>
         </div>
        </div>
       </div>
       <span class="position-relative cursor-pointer" data-target="#unlock_benefits_modal" data-toggle="modal" style="bottom: 3px;" title="Premium Vorteile freischalten">
        <img src="/img/icons/icon-lock-person.svg"/>
       </span>
      </div>
      <div class="nav navbar-nav navbar-right">
       <div class="dropdown-mini">
        <a href="#" onclick="fireLoginOrRegisterModalRequest('sign_in');">
         Mein Konto
        </a>
       </div>
       <a class="badge wgg_badge-small wgg_primary wgg_round position-relative" href="/nachrichten.html" id="new_messages_counter_main_navigation" style="top: -1px;">
       </a>
      </div>
     </nav>
     <nav class="mobile_nav navbar navbar-default hidden-md hidden-lg">
      <div class="navbar-header">
       <a class="navbar-brand position-relative" href="/" style="top: 5px;">
        <img alt="WG-Gesucht.de" src="/img/WGG_logo_nav_white.png"/>
        <span class="sr-only">
         WG-Gesucht.de
        </span>
       </a>
      </div>
      <div class="navbar-right">
       <span class="position-relative mr10 cursor-pointer" data-target="#unlock_benefits_modal" data-toggle="modal" style="top: 4px;" title="Premium Vorteile freischalten">
        <img src="/img/icons/icon-lock-person-white.svg"/>
       </span>
       <button aria-role="button" class="btn navbar-control mt5" id="burger_toggle" type="button">
        <span aria-hidden="true" class="mdi mdi-menu mdi-24px mdi-top2">
        </span>
        <span class="sr-only">
         Hauptmenü
        </span>
       </button>
      </div>
     </nav>
     <div class="drawer_backdrop hidden-md hidden-lg" id="drawer_backdrop" style="display: none;">
     </div>
     <div class="drawer_menu hidden-md hidden-lg" id="drawer">
      <div class="drawer_header">
       <div class="ml5">
        Schön, dass Sie da sind
        <br/>
        bei
        <b>
         WG-Gesucht.de!
        </b>
       </div>
      </div>
      <div class="drawer_content">
       <a aria-controls="collapseOffersAndRequests" aria-expanded="false" class="menu_item collapsed" data-toggle="collapse" href="#collapseOffersAndRequests" role="button">
        <span>
         Angebote/Gesuche
        </span>
        <i class="mdi mdi-chevron-up mdi-26px">
        </i>
       </a>
       <div class="collapse pl20" id="collapseOffersAndRequests">
        <b class="menu_item">
         Angebote
        </b>
        <a class="menu_item" href="/wg-zimmer-in-Frankfurt-am-Main.41.0.1.0.html">
         WG-Zimmer
        </a>
        <a class="menu_item active_nav_sub" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html">
         1-Zimmer-Wohnung
        </a>
        <a class="menu_item" href="/wohnungen-in-Frankfurt-am-Main.41.2.1.0.html">
         Wohnung
        </a>
        <a class="menu_item" href="/haeuser-in-Frankfurt-am-Main.41.3.1.0.html">
         Haus
        </a>
        <b class="menu_item">
         Gesuche
        </b>
        <a class="menu_item" href="/wg-zimmer-in-Frankfurt-am-Main-gesucht.41.0.1.0.html">
         WG-Zimmer
        </a>
        <a class="menu_item" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-gesucht.41.1.1.0.html">
         1-Zimmer-Wohnung
        </a>
        <a class="menu_item" href="/wohnungen-in-Frankfurt-am-Main-gesucht.41.2.1.0.html">
         Wohnung
        </a>
        <a class="menu_item" href="/haeuser-in-Frankfurt-am-Main-gesucht.41.3.1.0.html">
         Haus
        </a>
       </div>
       <a aria-controls="collapseTipsAndGuides" aria-expanded="false" class="menu_item collapsed" data-toggle="collapse" href="#collapseTipsAndGuides" role="button">
        <span>
         Infos &amp; Ratgeber
        </span>
        <i class="mdi mdi-chevron-up mdi-26px">
        </i>
       </a>
       <div class="collapse pl20" id="collapseTipsAndGuides">
        <a class="menu_item" href="/info/anbieter">
         Anbieter
        </a>
        <a class="menu_item" href="/info/magazin">
         Magazin
        </a>
        <a class="menu_item" href="/mietrecht.html">
         Mietrecht
        </a>
        <a class="menu_item" href="/info/netiquette">
         Netiquette
        </a>
        <a class="menu_item" href="/info/schufa-bonitaetscheck">
         SCHUFA
        </a>
        <a class="menu_item" href="/info/sicherheit">
         Sicherheit
        </a>
        <a class="menu_item" href="/info/wg-suche">
         Suchende
        </a>
        <a class="menu_item" href="/info/wg-arten">
         WG-Arten
        </a>
        <a class="menu_item" href="/info/wg-ratgeber">
         WG-Ratgeber
        </a>
        <a class="menu_item" href="/info/wohnen-in">
         Wohnen in
        </a>
       </div>
       <a class="menu_item" href="/fuer-immobilienprofis.html" rel="nofollow" target="_blank">
        <span>
         Für Unternehmen
        </span>
       </a>
       <a class="menu_item" data-target="#proof_of_credit_modal_nav" data-toggle="modal" href="#" onclick="mobileMenu.toggleDrawer('off');">
        <span>
         SCHUFA-Auskunft
        </span>
       </a>
       <a aria-controls="collapseCreateAd" aria-expanded="false" class="menu_item collapsed" data-toggle="collapse" href="#collapseCreateAd" role="button">
        <span>
         Anzeige inserieren
        </span>
        <i class="mdi mdi-chevron-up mdi-26px">
        </i>
       </a>
       <div class="collapse pl20" id="collapseCreateAd">
        <a class="menu_item" href="/get-started.html">
         Angebot inserieren
        </a>
        <a class="menu_item" href="/gesuch-aufgeben.html">
         Gesuch inserieren
        </a>
       </div>
       <a aria-controls="collapseHelpAndContact" aria-expanded="false" class="menu_item collapsed" data-toggle="collapse" href="#collapseHelpAndContact" role="button">
        <span>
         Hilfe / Kontakt
        </span>
        <i class="mdi mdi-chevron-up mdi-26px">
        </i>
       </a>
       <div class="collapse pl20" id="collapseHelpAndContact">
        <a class="menu_item" data-google-interstitial="false" href="/help-center.html">
         Hilfebereich
        </a>
        <a class="menu_item" data-google-interstitial="false" href="/impressum.html">
         Impressum
        </a>
        <a class="menu_item" href="/ic/online-werbung.html">
         Mediadaten
        </a>
       </div>
       <a class="menu_item" href="#" onclick="mobileMenu.toggleDrawer('off');fireLoginOrRegisterModalRequest('sign_in');">
        <span class="text-orange">
         Anmelden
        </span>
       </a>
       <div class="ad_search" id="ad_search">
        <input class="form-control wgg_input" id="menu_search_ad_id" maxlength="9" name="menu_search_ad_id" placeholder="Anzeigen-ID eingeben" size="25" type="tel"/>
        <i class="mdi mdi-magnify mdi-22px mdi-fw" id="btn_ad_search">
        </i>
       </div>
       <div class="button_shop_wrapper">
        <a class="btn wgg_darkgray button_shop" data-google-interstitial="false" href="get-started.html">
         <b>
          Schon ab 29,90€
         </b>
         - Exklusive
         <br/>
         Angebote für Immobilien-Profis
        </a>
       </div>
      </div>
     </div>
     <script src="/js/Common/MobileMenu.class.tjb1632386809.js">
     </script>
     <script>
      var mobileMenu = MobileMenu({
        visibility: 'closed',
        min_log_level: '5'
    });
     </script>
     <div class="modal fade noprint" id="proof_of_credit_modal_nav" role="dialog" style="margin-top: 200px;">
      <div class="modal-dialog">
       <div class="modal-content p20">
        <div class="modal-header" style="border-bottom: 0;">
         <h4>
          Bonitätsnachweis
          <span aria-label="Schließen" class="mdi mdi-close mdi-26px mdi-lh pull-right cursor-pointer" data-dismiss="modal">
          </span>
         </h4>
        </div>
        <div class="modal-body py40">
         <div class="row">
          <div class="col-md-12">
           <div class="row">
            <div class="col-xs-12 col-sm-8">
             <span>
              Laden Sie Ihre
              <b>
               SCHUFA-Auskunft
              </b>
              direkt hier herunter, um Ihre Bonität unkompliziert und schnell prüfen zu lassen.
             </span>
            </div>
            <div class="col-xs-offset-2 col-xs-8 col-sm-offset-0 col-sm-4">
             <a class="campaign_click btn btn-md wgg_orange-outline btn-block mt10" data-campaign_click_position="pop_up" data-campaign_click_source="main navigation" data-campaign_partner="Schufa" data-campaign_type="schufa_promotion" href="/bonitaetscheck.html?utm_campaign=schufa&amp;utm_source=main_navigation" style="color: black;" target="_blank">
              SCHUFA
             </a>
            </div>
           </div>
           <div class="row mt30">
            <div class="col-xs-12 col-sm-8">
             <span>
              Als kostengünstige Alternative bieten wir den
              <b>
               BonitätsPass
              </b>
              von itsmydata an, mit dem Sie ebenfalls eine sichere Bonitätsprüfung erhalten.
             </span>
            </div>
            <div class="col-xs-offset-2 col-xs-8 col-sm-offset-0 col-sm-4">
             <a class="btn btn-md wgg_orange-outline btn-block no-capitalize mt10" data-campaign_click_position="pop_up" data-campaign_click_source="main navigation" data-campaign_partner="Itsmydata" data-campaign_type="itsmydata_promotion" href="/itsmydata.html" style="color: black;" target="_blank">
              itsmydata
             </a>
            </div>
           </div>
          </div>
         </div>
        </div>
       </div>
      </div>
     </div>
    </div>
    <div class="row noprint">
     <div class="col-md-12 text-center" id="div-gpt-ad-189159851654146248-2">
      <script type="text/javascript">
       googletag.cmd.push(function() { googletag.display('div-gpt-ad-189159851654146248-2'); });
      </script>
      <script type="text/javascript">
       console.log('qm billboard loaded');
      </script>
     </div>
    </div>
    <div class="row my15 noprint" id="ad_blocker_message_container" style="display: none;">
     <div class="col-xs-12">
      <div class="alert alert-with-icon alert-warning mb0" role="alert">
       <span class="mdi mdi-alert">
       </span>
       <div class="alert-body">
        <h4 class="headline alert-primary-headline">
         Aktiver Werbeblocker
        </h4>
        <p>
         In Ihrem Browser ist ein Werbeblocker aktiviert. Bitte beachten Sie, dass je nach Einstellung des Werbeblockers eventuell nicht alle Inhalte der Seite korrekt dargestellt werden können.
        </p>
       </div>
      </div>
     </div>
    </div>
    <a href="https://pubads.g.doubleclick.net/gampad/clk?id=5454900871&amp;iu=/1009105/Klicktracking/TL_Schufa_Erstkontakt" id="ad_blocker_bait" rel="nofollow">
    </a>
    <script>
     var we_need_to_earn_money = 100;
    </script>
    <script src="/js/adsbygoogle.tjb1632386809.js">
    </script>
    <script src="/js/lib/Abd.lib.tjb1632386809.js">
    </script>
    <script>
     $(function() {
                DetectAdBlocker.detectAdBlocker();
            });
    </script>
    <div class="row" id="top_column_wrapper">
     <div class="col-md-12">
      <div class="row noprint" style="padding-top: 6px;">
       <div class="col-md-8">
        <h1 class="headline headline-default">
         1-Zimmer-Wohnungen in Frankfurt am Main: 12645
         <span class="hidden-xs">
          aktive und vermietete Angebote
         </span>
        </h1>
       </div>
      </div>
      <div class="row noprint filter_box visible-sm-block visible-md-block visible-lg-block hidden-xs" id="filterBox">
       <form action="1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html" class="col-xs-12 mt10" id="offer_filter_form" method="get" name="offer_filter_form">
        <input class="csrf_token" name="csrf_token" type="hidden" value=""/>
        <input name="offer_filter" type="hidden" value="1"/>
        <input id="stadt_key" name="stadt_key" type="hidden" value="41"/>
        <input id="city_id" name="city_id" type="hidden" value="41"/>
        <input name="sort_column" type="hidden" value=""/>
        <input name="sort_order" type="hidden" value="0"/>
        <input id="show_deactivated_ads" name="noDeact" type="hidden" value=""/>
        <input id="dFr" name="dFr" type="hidden" value=""/>
        <input id="dTo" name="dTo" type="hidden" value=""/>
        <input id="radLat" name="radLat" type="hidden" value=""/>
        <input id="radLng" name="radLng" type="hidden" value=""/>
        <input id="clear_vu" name="clear_vu" type="hidden" value=""/>
        <div class="row">
         <div class="col-md-4 form-group">
          <div class="position-relative">
           <input autocomplete="off" class="form-control autocomplete wgg_input city_loader_bar" id="autocompinp" name="autocompinp" placeholder="Stadt eingeben" style="cursor: default; position: absolute;" tabindex="1" type="text" value="Frankfurt am Main"/>
           <div class="failed_validation_message" id="autocompinp_IS_EMPTY" style="position: relative; top: 36px; display: inline;">
           </div>
           <input class="form-control autocomplete wgg_input city_loader_bar" disabled="disabled" id="autocomplete-hint" name="country" style="position: relative; border-top-left: 4px; border-bottom-left: 4px;" type="text"/>
           <div class="alert alert-without-icon alert-warning" id="no_cities_found" style="font-size: 13px; position: absolute; top: -18px; display: none; padding: 7px 4px;">
            <div class="alert-body">
             <b>
              Keine Stadt gefunden
             </b>
            </div>
           </div>
           <input id="country_code" name="country_code" type="hidden" value=""/>
           <input id="countrymanuel" name="countrymanuel" type="hidden" value=""/>
           <input id="city_name" name="city_name" type="hidden" value=""/>
          </div>
          <script src="/js/jquery/jquery.autocomplete.min.js">
          </script>
          <script>
           /**
     * Called after a successfull request to the WebService, turns the results into
     * the appropriate object to display all the city names categorized by countryname
     *
     * @param obj response The WebService Response
     *
     * @return obj         City list as object
     */
    function prepareReceivedData(response) {
        response = $.makeArray(JSON.parse(response));
        return {
            suggestions: $.map(response, function(item, counter) {
                return { value: response[counter].city_and_state, data: {
                        'category'    : country_names[response[counter].country_code],
                        'city_id'     : response[counter].city_id,
                        'city_name'   : response[counter].city_name,
                        'country_code': response[counter].country_code
                    }
                };
            })
        };
    }


    /**
     * Displays a no_cities_found error message
     */
    function displayCityNotFoundErrorMessage() {
        $('#stadt_key, #city_id').val('');

        // adjust the width to that of the city_select_box
        var city_width = $('#autocompinp').width();
        $('#no_cities_found').width(city_width).show();

        // if on any page that hasn't got the City label above the select_box
        // change the top value to compensate for the space
        if (!$('#city_label').length) {
            $('#no_cities_found').css('top', '-40px');
        }

        setTimeout(function() {
            $('#no_cities_found').hide();
        }, 2000);
    }


    /**
     * Called on offer and requests list_views where after selecting a new city, a page refresh is expected
     */
    function disableHiddenInputsAndSubmitForm() {
        $('#stadt_key').prop('disabled', true);
        $('#countrymanuel').prop('disabled', true);

                    resetRadialSearchParameters();
            document.offer_filter_form.submit();
            }


    /**
     * Called when the city is changed but a page refresh does not happen. Replace the currency symbol based
     * on the country the city is in.
     *
     * PLEASE NOTE that this function is based on select_currency_based_on_country function found in
     * functions.inc.php, so if something is changed here, it should be changed there as well.
     *
     * @param str country_code The country code
     */
    function changeCurrencyBasedOnCountry(country_code) {
        switch(country_code) {
            case 'ch':
                currency = "CHF";
                break;
            case 'us':
                currency = "\u0024";
                break;
            default:
                currency = "\u20AC";
                break;
        }

        $('.currency_symbol').html(currency);
    }


    /**
     * Called when on wohnungsmarkt/wohnungssuche etc where after selecting a new city a redirect is expected
     *
     * @param str city_name The city name
     * @param str city_id   The city id
     * @param str ad_type   The ad type can be either 'offers' or 'requests'
     */
    function redirectUserToListView(city_name, city_id, ad_type) {
        var categories = $('#categories.selectpicker').val();
        if (typeof categories === 'undefined') {
            categories = getAllCategories();
            $('#categories.selectpicker').val(categories);
        }
        if (categories.length === 0) {
            $('#no_categories_selected').fadeIn(400).delay(2000).fadeOut(400);
            return;
        }

        var url = 'https://www.wg-gesucht.de/';
        var language = 'de';

        var category_url_part = '';

        if (language !== 'de') {
            url += language + '/';
        }

        for (var i = 0; i < categories.length; i++) {
           if (categories[i] == 0){
               url += 'wg-zimmer';
           } else if (categories[i] == 1){
               url += '1-zimmer-wohnungen';
           } else if (categories[i] == 2){
               url += 'wohnungen';
           } else if (categories[i] == 3){
               url += 'haeuser';
           }

           category_url_part += categories[i];
           if (typeof categories[i + 1] != "undefined") {
               url += '-und-';
               category_url_part += '+';
           }
        }

        url += '-in-' + city_name;

        // build the url according to the ad_type
        if (ad_type === 'requests') {
            url += '-gesucht';
        }

        url += '.' + city_id + '.' + category_url_part + '.1.0.html';
        window.location.href = url;
    }


    /**
     * Makes a request to the Location WebService to get a list of districts for a city id
     *
     * @param obj services The services object
     * @param int city_id  The City id
     */
    function fetchDistrictsForCityId(services, city_id) {
        $.when(
            services.location.getDistrictsByCityId(city_id)
        ).done(function(response) {
            var districts = response._embedded.districts;

            if (districts.length == 0) {
                emptyFilterDistricts();
            } else {
                updateFilterDistricts(districts);
            }
        }).fail(function() {
            emptyFilterDistricts();
        });
    }


    /**
     * Repopulates the content of the filter_districts div with data retrieved from
     * the districts webService
     *
     * @param obj districts The districts
     */
    function updateFilterDistricts(districts) {
        var options = "";

        districts.forEach(function(district) {
            options += '<option value=' + district.district_id + ' style="padding: 4px 15px;">' + district.district_name + '</option>'
        });

        $("select[name^=ot]").html(options);
        $("select[name^=ot]").selectpicker('refresh');
    }


    /**
     * Empties the district filter selectbox
     */
    function emptyFilterDistricts() {
        $("select[name^=ot]").empty();
        $("select[name^=ot]").selectpicker('refresh');

        $('<div/>', {
            'style': 'padding: 10px 0;font-weight: bold;',
            'text': translation_lang_filters_districts.fdl_no_suburbs
        }).appendTo($('#filter_districts_list'));
    }


    /**
     * Updates the stadt_key and city_id hidden fields and performs an action
     * based on the city_select_box_action variable
     *
     * @param obj services   The services object
     * @param str suggestion The City name
     */
    function updateSelectBoxValue(suggestion) {
        $('#autocompinp').trigger('blur');

        $('#country_code').val(suggestion.data.country_code);
        $('#countrymanuel').val(suggestion.data.category);

        $('#label_city_name').text(suggestion.data.city_name);

        // remove umlauts from city name, breaks the url
        // Please check the functions.inc.php for a complete list of special characters
        // that need replacement and further instructions
        var city_name = replaceSpecialCharacters(suggestion.data.city_name);
        $('#city_name').val(city_name);

        var city_id = (suggestion.data.city_id);
        $('#stadt_key, #city_id').val(city_id).trigger('change');

        var city_select_box_action = 'form_submit';

        if (city_select_box_action !== '') {
            switch (city_select_box_action) {
                case 'form_submit':
                    disableHiddenInputsAndSubmitForm();
                    break;

                case 'redirect_requests_market':
                    redirectUserToListView(city_name, city_id, 'requests');
                    break;

                case 'redirect_offers_market':
                    redirectUserToListView(city_name, city_id, 'offers');
                    break;

                case 'user_filters_offer':
                    fetchDistrictsForCityId(services, city_id);
                    changeCurrencyBasedOnCountry(suggestion.data.country_code);
                    break;

                case 'user_filters_request':
                    fetchDistrictsForCityId(services, city_id);
                    changeCurrencyBasedOnCountry(suggestion.data.country_code);
                    break;

                case 'create_edit_ad':
                    changeCurrencyBasedOnCountry(suggestion.data.country_code);
                    break;
            }
        }
    }


    /**
     * Function to reset radial search parameters address, latitude, longitude and
     * sort columns if it is set on distance
     */
    function resetRadialSearchParameters() {
        if ($('input[name=sort_column]').val() == '3') {
            $('input[name=sort_column]').val('0');
        }

        $('#radAdd').val('');
        $('#radLat').val('');
        $('#radLng').val('');
    }


    $(function() {
        // turning the $laenderliste array to an object so as to group the results by country
        country_names = {
                            ae: 'Vereinigte Arabische Emirate'
                ,                            am: 'Armenien'
                ,                            ao: 'Angola'
                ,                            ar: 'Argentinien'
                ,                            at: 'Österreich'
                ,                            au: 'Australien'
                ,                            az: 'Aserbaidschan'
                ,                            bd: 'Bangladesch'
                ,                            be: 'Belgien'
                ,                            bf: 'Burkina Faso'
                ,                            bg: 'Bulgarien'
                ,                            bo: 'Bolivien'
                ,                            br: 'Brasilien'
                ,                            by: 'Weißrussland'
                ,                            ca: 'Kanada'
                ,                            cd: 'Demokratische Republik Kongo'
                ,                            cg: 'Republik Kongo'
                ,                            ch: 'Schweiz'
                ,                            ci: 'Elfenbeinküste'
                ,                            cl: 'Chile'
                ,                            cm: 'Kamerun'
                ,                            cn: 'Volksrepublik China'
                ,                            co: 'Kolumbien'
                ,                            cu: 'Kuba'
                ,                            cz: 'Tschechien'
                ,                            de: 'Deutschland'
                ,                            dk: 'Dänemark'
                ,                            do: 'Domenikanische Republik'
                ,                            dz: 'Algerien'
                ,                            ec: 'Ecuador'
                ,                            eg: 'Äqypten'
                ,                            es: 'Spanien'
                ,                            et: 'Äthiopien'
                ,                            fi: 'Finnland'
                ,                            fr: 'Frankreich'
                ,                            gb: 'Vereinigtes Königreich'
                ,                            ge: 'Georgien'
                ,                            gh: 'Ghana'
                ,                            gn: 'Guinea'
                ,                            gr: 'Griechenland'
                ,                            ht: 'Haiti'
                ,                            hk: 'Hongkong'
                ,                            hu: 'Ungarn'
                ,                            id: 'Indonesien'
                ,                            ie: 'Irland'
                ,                            il: 'Israel'
                ,                            in: 'Indien'
                ,                            ir: 'Iran'
                ,                            it: 'Italien'
                ,                            jo: 'Jordanien'
                ,                            jp: 'Japan'
                ,                            ke: 'Kenia'
                ,                            kh: 'Kambodscha'
                ,                            kp: 'Nordkorea'
                ,                            kr: 'Südkorea'
                ,                            kz: 'Kasachstan'
                ,                            lb: 'Libanon'
                ,                            lr: 'Liberia'
                ,                            lu: 'Luxemburg'
                ,                            lv: 'Lettland'
                ,                            ly: 'Libyen'
                ,                            ma: 'Marokko'
                ,                            mg: 'Madagaskar'
                ,                            ml: 'Mali'
                ,                            mm: 'Myanmar'
                ,                            mn: 'Mongolei'
                ,                            mx: 'Mexiko'
                ,                            my: 'Malaysia'
                ,                            mz: 'Mosambik'
                ,                            ng: 'Nigeria'
                ,                            ni: 'Nicaragua'
                ,                            nl: 'Niederlande'
                ,                            no: 'Norwegen'
                ,                            np: 'Nepal'
                ,                            nz: 'Neuseeland'
                ,                            pe: 'Peru'
                ,                            ph: 'Philippinen'
                ,                            pk: 'Pakistan'
                ,                            pl: 'Polen'
                ,                            pt: 'Portugal'
                ,                            ro: 'Rumänien'
                ,                            rs: 'Serbien'
                ,                            ru: 'Russland'
                ,                            rw: 'Ruanda'
                ,                            sa: 'Saudi-Arabien'
                ,                            sd: 'Sudan'
                ,                            se: 'Schweden'
                ,                            sg: 'Singapur'
                ,                            sk: 'Slowakei'
                ,                            sn: 'Senegal'
                ,                            so: 'Somalia'
                ,                            th: 'Thailand'
                ,                            tn: 'Tunesien'
                ,                            tr: 'Türkei'
                ,                            tw: 'Taiwan'
                ,                            tz: 'Tansania'
                ,                            ua: 'Ukraine'
                ,                            ug: 'Uganda'
                ,                            us: 'USA'
                ,                            uy: 'Uruguay'
                ,                            ve: 'Venezuela'
                ,                            vn: 'Vietnam'
                ,                            ye: 'Jemen'
                ,                            za: 'Südafrika'
                ,                            zm: 'Sambia'
                ,                            zu: 'Usbekistan'
                ,                            zw: 'Simbabwe'
                                    };

        $('#autocompinp').devbridgeAutocomplete({
            serviceUrl: "/ajax/getCities.php",
            params: {
                country_parameter: ""
            },
            autoSelectFirst: true,
            groupBy: 'category',
            onSelect: function(suggestion) {
                updateSelectBoxValue(suggestion);
            },
            transformResult: prepareReceivedData,
            onSearchStart: function() {
                $('#autocompinp').parents('form').find(':input[type="submit"]').prop('disabled', true);
            },
            onSearchComplete: function (query, suggestions) {
                $('#autocompinp').parents('form').find(':input[type="submit"]').prop('disabled', false);
                if (suggestions[0].data.city_id.length) {
                    $('#stadt_key, #city_id').val(suggestions[0].data.city_id);
                    $('#country_code').val(suggestions[0].data.country_code);
                }
            },
            onHint: function(hint) {
                $('#autocomplete-hint').val('')
                var user_input = $('#autocompinp').val().toLowerCase();
                var selected   = $('.autocomplete-selected').text().toLowerCase();
                if (selected.startsWith(user_input)) {
                    $('#autocomplete-hint').val(hint);
                }
            },
            onSearchError: function(query, jqXHR, textStatus, errorThrown) {
                if (jqXHR.status === 404 && $('#no_cities_found').is(':hidden')) {
                    displayCityNotFoundErrorMessage();
                }
                $('#autocompinp').parents('form').find(':input[type="submit"]').prop('disabled', false);
            },
        });


        /*
         * Category changed if city is selected redirect at list view
         */
        $('#categories_wrapper').on('change', function() {
            var categories = $('#categories.selectpicker').val();
            var city_id    = $('#stadt_key').val();
            var city_name  = $('#city_name').val();
            if (categories.length !== 0 && city_name) {
                redirectUserToListView(city_name, city_id, 'form_submit');
            }
        });
    });

    $('#autocompinp').on('focus', function() {
        old_value = $(this).val();
        $(this).val('');
    });

    $('#autocompinp').on('blur', function() {
        if (!$(this).val().length) {
            $(this).val(old_value);
        }
    });

    // check for a value in the stadt_key input on form submit
    $('#formPortal').on('submit', function(e) {
        if (!$('#stadt_key').val() && !$('#city_id').val()) {
            e.preventDefault();
            $('body').removeClass('wait');
            displayCityNotFoundErrorMessage();
        }

        var categories = $('#categories.selectpicker').val();
        if (typeof categories === 'undefined') {
            categories = [];
        }
        if (categories.length === 0) {
            e.preventDefault();
            $('#no_categories_selected').fadeIn(400).delay(2000).fadeOut(400);
        }
    });
          </script>
         </div>
         <div class="col-sm-6 col-md-2 hidden-xs form-group position-relative">
          <div class="display-none alert alert-without-icon alert-warning position-absolute no_categories_selected_message" id="no_categories_selected">
           <div class="alert-body">
            <b>
             Bitte wählen sie eine Rubrik.
            </b>
           </div>
          </div>
          <select class="selectpicker" data-size="10" data-style="form-control wgg_select" data-width="100%" id="categories" multiple="" name="categories[]" title="Rubrik">
           <option value="0">
            WG-Zimmer
           </option>
           <option selected="" value="1">
            1-Zimmer-Wohnung
           </option>
           <option value="2">
            Wohnung
           </option>
           <option value="3">
            Haus
           </option>
          </select>
         </div>
         <div class="col-sm-6 col-md-2 form-group">
          <select class="selectpicker" data-size="10" data-style="form-control wgg_select " data-width="100%" id="rent_types" multiple="" name="rent_types[]" title="alle Mietarten">
           <option value="2">
            unbefristet
           </option>
           <option value="1">
            befristet
           </option>
           <option value="3">
            Übernachtung
           </option>
          </select>
          <input id="rent_type_values" type="hidden" value=""/>
         </div>
         <div class="col-sm-6 col-md-2 hidden-xs form-group">
          <div class="wgg_input_icon_group">
           <input class="form-control wgg_input" id="sMin" maxlength="3" name="sMin" placeholder="min. Größe" type="text" value=""/>
           <span class="wgg_input_icon">
            m²
           </span>
          </div>
         </div>
         <div class="col-sm-6 col-md-2 hidden-xs form-group">
          <div class="wgg_input_icon_group">
           <input class="form-control wgg_input" id="rMax" maxlength="4" name="rMax" placeholder="max. Miete" type="text" value=""/>
           <span class="wgg_input_icon currency_symbol">
            €
           </span>
          </div>
         </div>
         <input class="form-control" id="pu" name="pu" type="hidden" value=""/>
        </div>
        <div class="more_filter_wrapper" style="display:none;">
         <div class="row" style="padding-top: 40px;">
          <div class="col-lg-2">
           <h4 class="rent_type_text rent_type_text_0 rent_type_text_2">
            Einzugsdatum
           </h4>
           <h4 class="rent_type_text rent_type_text_1 rent_type_text_3 display-none">
            Datum
           </h4>
          </div>
          <div class="col-lg-10">
           <div class="date_validation alert alert-without-icon alert-danger hide">
            <b class="date_validations date_validation_too_small display-inline-block hide">
             Das Datum liegt zu weit in der Vergangenheit.
            </b>
            <b class="date_validations date_validation_impossible display-inline-block hide">
             Das Datum des Einzugs/Check-Ins darf nicht nach dem des Auszugs/Check-Outs liegen.
            </b>
           </div>
           <div class="row">
            <div class="col-sm-6 col-md-3 form-group">
             <label class="rent_type_text rent_type_text_1 display-none">
              Einzugsdatum
             </label>
             <label class="rent_type_text rent_type_text_0 rent_type_text_2">
              frühestes
             </label>
             <label class="rent_type_text rent_type_text_3 display-none">
              Check-In
             </label>
             <div class="wgg_input_icon_group">
              <input autocomplete="off" class="form-control wgg_input cursor-pointer" id="date_from_input" type="text" value=""/>
              <span class="mdi mdi-calendar-month mdi-18px cursor-pointer wgg_input_icon" onclick="$('#date_from_input').trigger('focus');">
              </span>
             </div>
            </div>
            <div class="col-sm-6 col-md-3 form-group mietart_is_1_or_3" style="display:none;">
             <label>
              Toleranz
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="dFrDe" name="hidden_dFrDe" tabindex="2" title="egal">
              <option class="wgg_select_placeholder_option" value="">
               egal
              </option>
              <option value="0">
               +/- 0 Tage
              </option>
              <option value="1">
               +/- 1 Tag
              </option>
              <option value="7">
               +/- 1 Woche
              </option>
              <option value="31">
               +/- 1 Monat
              </option>
             </select>
            </div>
            <div class="col-sm-6 col-md-3 form-group">
             <label class="rent_type_text rent_type_text_1 display-none">
              Auszugsdatum
             </label>
             <label class="rent_type_text rent_type_text_0 rent_type_text_2">
              spätestes
             </label>
             <label class="rent_type_text rent_type_text_3 display-none">
              Check-Out
             </label>
             <div class="wgg_input_icon_group">
              <input autocomplete="off" class="form-control wgg_input cursor-pointer" id="date_to_input" type="text" value=""/>
              <span class="mdi mdi-calendar-month mdi-18px cursor-pointer wgg_input_icon" onclick="$('#date_to_input').trigger('focus');">
              </span>
             </div>
            </div>
            <div class="col-sm-6 col-md-3 form-group mietart_is_1_or_3" style="display:none;">
             <label>
              Toleranz
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="dToDe" name="hidden_dToDe" tabindex="3" title="egal">
              <option class="wgg_select_placeholder_option" value="">
               egal
              </option>
              <option value="0">
               +/- 0 Tage
              </option>
              <option value="1">
               +/- 1 Tag
              </option>
              <option value="7">
               +/- 1 Woche
              </option>
              <option value="31">
               +/- 1 Monat
              </option>
             </select>
            </div>
           </div>
          </div>
         </div>
         <div class="row" style="padding-top: 40px;">
          <div class="col-lg-2">
           <h4>
            Stadtteile / Umkreis
           </h4>
          </div>
          <div class="col-lg-10">
           <div class="row">
            <div class="col-md-6 form-group">
             <label>
              Stadtteile
             </label>
             <select class="selectpicker" data-actions-box="true" data-deselect-all-text="KEINE AUSWÄHLEN" data-dropup-auto="false" data-live-search="true" data-select-all-text="ALLE AUSWÄHLEN" data-size="10" data-style="form-control wgg_select" data-width="100%" multiple="" name="ot[]" title="egal">
              <option value="992">
               Altstadt
              </option>
              <option value="993">
               Bahnhofsviertel
              </option>
              <option value="994">
               Bergen-Enkheim
              </option>
              <option value="995">
               Berkersheim
              </option>
              <option value="996">
               Bockenheim
              </option>
              <option value="997">
               Bonames
              </option>
              <option value="999">
               Bornheim
              </option>
              <option value="1000">
               Dornbusch
              </option>
              <option value="1001">
               Eckenheim
              </option>
              <option value="1002">
               Eschersheim
              </option>
              <option value="1003">
               Fechenheim
              </option>
              <option value="1004">
               Flughafen
              </option>
              <option value="85041">
               Frankfurter Berg
              </option>
              <option value="85042">
               Gallus
              </option>
              <option value="1006">
               Gallusviertel
              </option>
              <option value="1007">
               Ginnheim
              </option>
              <option value="1008">
               Goldstein
              </option>
              <option value="1009">
               Griesheim
              </option>
              <option value="1011">
               Gutleutviertel
              </option>
              <option value="1013">
               Harheim
              </option>
              <option value="1014">
               Hausen
              </option>
              <option value="1015">
               Heddernheim
              </option>
              <option value="1016">
               Höchst
              </option>
              <option value="1018">
               Innenstadt
              </option>
              <option value="1019">
               Kalbach
              </option>
              <option value="1027">
               Nied
              </option>
              <option value="1028">
               Nieder-Erlenbach
              </option>
              <option value="1029">
               Nieder-Eschbach
              </option>
              <option value="1030">
               Niederrad
              </option>
              <option value="1031">
               Niederursel
              </option>
              <option value="1032">
               Nordend-Ost
              </option>
              <option value="1033">
               Nordend-West
              </option>
              <option value="1034">
               Oberrad
              </option>
              <option value="1035">
               Ostend
              </option>
              <option value="1037">
               Praunheim
              </option>
              <option value="1038">
               Preungesheim
              </option>
              <option value="1039">
               Riederwald
              </option>
              <option value="1040">
               Rödelheim
              </option>
              <option value="1042">
               Sachsenhausen
              </option>
              <option value="1043">
               Schwanheim
              </option>
              <option value="1044">
               Seckbach
              </option>
              <option value="1045">
               Sindlingen
              </option>
              <option value="1046">
               Sossenheim
              </option>
              <option value="1047">
               Unterliederbach
              </option>
              <option value="1048">
               Westend-Nord
              </option>
              <option value="1049">
               Westend-Süd
              </option>
              <option value="1051">
               Zeilsheim
              </option>
             </select>
            </div>
            <div class="col-sm-7 col-md-4 form-group">
             <label>
              Adresse
             </label>
             <input class="form-control wgg_input" id="radAdd" name="radAdd" placeholder="Straße, Stadtteil oder Ort" type="text" value=""/>
            </div>
            <div class="col-sm-5 col-md-2 form-group">
             <label>
              max. Entfernung
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="radDis" name="radDis" title="egal">
              <option class="wgg_select_placeholder_option" selected="" value="">
               egal
              </option>
              <option value="500">
               0,5 km
              </option>
              <option value="1000">
               1,0 km
              </option>
              <option value="2000">
               2,0 km
              </option>
              <option value="3000">
               3,0 km
              </option>
              <option value="4000">
               4,0 km
              </option>
              <option value="5000">
               5,0 km
              </option>
              <option value="10000">
               10,0 km
              </option>
              <option value="15000">
               15,0 km
              </option>
              <option value="20000">
               20,0 km
              </option>
              <option value="50000">
               50,0 km
              </option>
             </select>
            </div>
           </div>
          </div>
         </div>
         <div class="row category_changed category_is_0 hidden" style="padding-top: 40px;">
          <div class="col-lg-2">
           <h4>
            WG-Details
           </h4>
          </div>
          <div class="col-lg-10">
           <div class="row">
            <div class="col-sm-6 col-lg-3 form-group">
             <label>
              Bewohner
             </label>
             <select class="selectpicker" data-size="10" data-style="form-control wgg_select " data-width="100%" id="wgFla" multiple="" name="wgFla[]" title="Geschlecht egal">
              <option value="1">
               Frauen
              </option>
              <option value="2">
               Männer
              </option>
              <option value="4">
               Divers
              </option>
             </select>
            </div>
            <div class="col-sm-6 col-lg-3 form-group">
             <label>
              Gesucht
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="wgSea" name="wgSea" tabindex="4" title="Geschlecht egal">
              <option class="wgg_select_placeholder_option" selected="" value="">
               Geschlecht egal
              </option>
              <option value="1">
               Frau
              </option>
              <option value="2">
               Mann
              </option>
              <option value="3">
               Divers
              </option>
             </select>
            </div>
            <div class="col-sm-6 col-lg-3 form-group">
             <label>
              WG-Größe
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="wgMnF" name="wgMnF" tabindex="5" title="egal">
              <option class="wgg_select_placeholder_option" selected="" value="">
               egal
              </option>
              <option value="1">
               2er
              </option>
              <option value="2">
               3er
              </option>
              <option value="3">
               4er
              </option>
              <option value="4">
               5er
              </option>
              <option value="5">
               6er
              </option>
              <option value="6">
               7er
              </option>
              <option value="7">
               8er
              </option>
              <option value="8">
               9er
              </option>
             </select>
            </div>
            <div class="col-sm-6 col-lg-3 form-group">
             <label>
              bis
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="wgMxT" name="wgMxT" tabindex="6" title="egal">
              <option class="wgg_select_placeholder_option" selected="" value="">
               egal
              </option>
              <option value="1">
               2er
              </option>
              <option value="2">
               3er
              </option>
              <option value="3">
               4er
              </option>
              <option value="4">
               5er
              </option>
              <option value="5">
               6er
              </option>
              <option value="6">
               7er
              </option>
              <option value="7">
               8er
              </option>
              <option value="8">
               9er
              </option>
             </select>
            </div>
            <div class="col-xs-12 col-sm-6 form-group">
             <label id="wg_art">
              WG-Art/en
             </label>
             <select class="selectpicker" data-actions-box="true" data-deselect-all-text="KEINE AUSWÄHLEN" data-dropup-auto="false" data-live-search="true" data-select-all-text="ALLE AUSWÄHLEN" data-size="10" data-style="form-control wgg_select" data-width="100%" multiple="" name="wgArt[]" title="egal">
              <option value="6">
               Berufstätigen-WG
              </option>
              <option value="12">
               gemischte WG
              </option>
              <option value="1">
               Studenten-WG
              </option>
              <option value="11">
               keine Zweck-WG
              </option>
              <option value="0">
               Zweck-WG
              </option>
              <option value="2">
               Frauen-WG
              </option>
              <option value="19">
               Internationals welcome
              </option>
              <option value="16">
               LGBTQIA+
              </option>
              <option value="4">
               Business-WG
              </option>
              <option value="15">
               Vegetarisch/Vegan
              </option>
              <option value="14">
               Mehrgenerationen
              </option>
              <option value="9">
               WG mit Kindern
              </option>
              <option value="7">
               Azubi-WG
              </option>
              <option value="3">
               Männer-WG
              </option>
              <option value="18">
               Alleinerziehende
              </option>
              <option value="5">
               Wohnheim
              </option>
              <option value="10">
               Verbindung
              </option>
              <option value="17">
               Wohnen für Hilfe
              </option>
              <option value="13">
               Plus-WG
              </option>
              <option value="8">
               Senioren-WG
              </option>
              <option value="20">
               inklusive WG
              </option>
              <option value="21">
               funktionale WG
              </option>
              <option value="22">
               WG-Neugründung
              </option>
             </select>
            </div>
            <div class="col-xs-3 col-sm-2 col-md-2 form-group">
             <label>
              Mein Alter
             </label>
             <input class="form-control wgg_input" id="wgAge" maxlength="2" name="wgAge" size="4" type="text" value=""/>
            </div>
            <div class="col-xs-9 col-sm-4 col-md-4 form-group">
             <label>
              Rauchen
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="wgSmo" name="wgSmo" tabindex="7" title="egal">
              <option class="wgg_select_placeholder_option" selected="" value="">
               egal
              </option>
              <option value="1">
               erlaubt
              </option>
              <option value="2">
               nicht erwünscht
              </option>
              <option value="3">
               im eigenen Zimmer
              </option>
              <option value="4">
               auf dem Balkon
              </option>
             </select>
            </div>
           </div>
          </div>
         </div>
         <div class="row" style="padding-top: 40px; padding-bottom: 40px;">
          <div class="col-lg-2">
           <h4>
            Weitere Merkmale
           </h4>
          </div>
          <div class="col-lg-10">
           <div class="row">
            <div class="col-sm-4 form-group category_changed category_is_2 category_is_3 hidden">
             <label>
              Zimmeranzahl
             </label>
             <div class="wgg_input_double_icon_group" data-max="9" data-min="2" data-step="0.5" id="rmMin">
              <span class="mdi mdi-minus-circle-outline mdi-18px wgg_pre_input_icon cursor-pointer">
              </span>
              <input class="form-control text-center wgg_input numeric_input" tabindex="8" type="text" value=""/>
              <input name="rmMin" type="hidden" value=""/>
              <span class="mdi mdi-plus-circle-outline mdi-18px cursor-pointer wgg_post_input_icon">
              </span>
             </div>
            </div>
            <div class="col-sm-4 form-group category_changed category_is_2 category_is_3 hidden">
             <label>
              bis
             </label>
             <div class="wgg_input_double_icon_group" data-max="9" data-min="2" data-step="0.5" id="rmMax">
              <span class="mdi mdi-minus-circle-outline mdi-18px wgg_pre_input_icon cursor-pointer">
              </span>
              <input class="form-control text-center wgg_input numeric_input" tabindex="9" type="text" value=""/>
              <input name="rmMax" type="hidden" value=""/>
              <span class="mdi mdi-plus-circle-outline mdi-18px cursor-pointer wgg_post_input_icon">
              </span>
             </div>
            </div>
            <div class="col-sm-4 form-group">
             <label for="fur">
              Möbliert
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="fur" name="fur" title="egal">
              <option class="wgg_select_placeholder_option" selected="" value="">
               egal
              </option>
              <option value="1">
               Ja
              </option>
              <option value="2">
               Nein
              </option>
             </select>
            </div>
            <div class="col-sm-4 form-group">
             <label for="pet">
              Haustiere erlaubt
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="pet" name="pet" title="egal">
              <option class="wgg_select_placeholder_option" selected="" value="">
               egal
              </option>
              <option value="1">
               Ja
              </option>
              <option value="2">
               Nein
              </option>
             </select>
            </div>
            <div class="col-sm-4 form-group">
             <label>
              Neue Angebote seit
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="sin" name="sin" title="egal">
              <option class="wgg_select_placeholder_option" selected="" value="">
               egal
              </option>
              <option value="1">
               letzten 3 Tagen
              </option>
              <option value="2">
               letzter Woche
              </option>
              <option value="3">
               letzten 2 Wochen
              </option>
              <option value="4">
               letzten 3 Wochen
              </option>
              <option value="5">
               letztem Monat
              </option>
              <option value="6">
               letzten 2 Monaten
              </option>
              <option value="7">
               letzten 3 Monaten
              </option>
             </select>
            </div>
            <div class="col-sm-4 form-group">
             <label>
              Tauschangebot
              <span aria-hidden="true" class="mdi mdi-autorenew mdi-16px mdi-lh mdi-vm">
              </span>
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="exc" name="exc" title="egal">
              <option class="wgg_select_placeholder_option" selected="" value="">
               egal
              </option>
              <option value="1">
               Ja
              </option>
              <option value="2">
               Nein
              </option>
             </select>
            </div>
            <div class="col-sm-4 form-group category_changed category_is_1 category_is_2 category_is_3 display-block">
             <label for="kit">
              Küche
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="kit" name="kit" title="egal">
              <option class="wgg_select_placeholder_option" selected="" value="">
               egal
              </option>
              <option value="1">
               Ja
              </option>
              <option value="2">
               Nein
              </option>
             </select>
            </div>
            <div class="col-sm-4 form-group category_changed category_is_0 category_is_1 category_is_2 display-block">
             <label for="flo">
              Etage
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="flo" name="flo" title="egal">
              <option class="wgg_select_placeholder_option" selected="" value="">
               egal
              </option>
              <option value="8">
               Keller
              </option>
              <option value="9">
               Tiefparterre
              </option>
              <option value="1">
               EG
              </option>
              <option value="10">
               Hochparterre
              </option>
              <option value="2">
               1. OG
              </option>
              <option value="3">
               2. OG
              </option>
              <option value="4">
               3. OG
              </option>
              <option value="5">
               4. OG
              </option>
              <option value="6">
               5. OG
              </option>
              <option value="7">
               höher als 5. OG
              </option>
              <option value="11">
               Dachgeschoss
              </option>
             </select>
            </div>
            <div class="col-xs-12">
             <div class="row">
              <div class="col-sm-4 col-md-4 form-group">
               <label for="han">
                <input id="han" name="han" type="checkbox" value="1"/>
                Barrierefrei
               </label>
              </div>
              <div class="col-sm-4 col-md-4 form-group">
               <label for="img_only">
                <input id="img_only" name="img_only" type="checkbox" value="1"/>
                mit Fotos
               </label>
              </div>
              <div class="col-sm-4 col-md-4 form-group">
               <label for="gar">
                <input id="gar" name="gar" type="checkbox" value="1"/>
                Garten
               </label>
              </div>
              <div class="col-sm-4 col-md-4 form-group">
               <label for="bal_or_ter">
                <input id="bal_or_ter" name="bal_or_ter" type="checkbox" value="1"/>
                Balkon/Terrasse
               </label>
              </div>
              <div class="col-sm-4 col-md-4 form-group">
               <label for="onl_tour">
                <input id="onl_tour" name="onl_tour" type="checkbox" value="1"/>
                Online-Besichtigung möglich
               </label>
              </div>
              <div class="col-sm-4 col-md-4 form-group category_changed category_is_2 category_is_3 hidden">
               <label for="ff">
                <input id="ff" name="ff" type="checkbox" value="1"/>
                WG geeignet
               </label>
              </div>
             </div>
            </div>
           </div>
           <script src="/js/Asset/HalfRoomInput.class.js">
           </script>
           <script>
            $(function() {
        // Number of Rooms
        window.halfRoomInputMin = HalfRoomInput({
            selector     : '#rmMin',
            language     : site_language,
            required     : false,
            min_log_level: '5'
        });

        window.halfRoomInputMax = HalfRoomInput({
            selector     : '#rmMax',
            language     : site_language,
            required     : false,
            min_log_level: '5'
        });
    });
           </script>
          </div>
         </div>
        </div>
        <div class="row">
         <div class="col-sm-4 col-md-4 form-group">
          <a class="show_more_filters" href="#">
           <span aria-hidden="true" class="mdi mdi-24px mdi-lh mdi-fw mdi-vm mdi-chevron-down">
           </span>
           Weitere Filter
          </a>
          <a class="hide_filters" href="#" style="display:none;">
           <span aria-hidden="true" class="mdi mdi-24px mdi-lh mdi-fw mdi-vm mdi-chevron-up">
           </span>
           Weniger Filter
          </a>
         </div>
         <div class="col-sm-8 col-md-5">
          <div class="display-none" id="airbnb_label">
           <div class="row">
            <div class="col-xs-9 text-right">
             <a href="" rel="nofollow" target="_blank">
              <span class="" id="universal_airbnb_textlink">
               Unterkunft für die ersten Tage in Frankfurt am Main buchen
              </span>
              <span class="display-none" id="short_term_dates_airbnb_textlink">
               Unterkunft von 01.10.2024
                                                                                 in Frankfurt am Main
              </span>
             </a>
            </div>
            <div class="col-xs-3">
             <label class="setting_switch">
              <input id="airbnb_enabled" name="airbnb_enabled" onclick="toggleFormTarget()" type="checkbox" value="airbnb"/>
              <span class="setting_switch_slider round">
              </span>
             </label>
            </div>
           </div>
          </div>
          <div class="display-none" id="booking_label">
           <div class="row">
            <div class="col-xs-9 text-right">
             <a href="" id="booking_link" rel="nofollow" target="_blank">
              Unterkünfte in Frankfurt am Main finden mit Booking.com
             </a>
            </div>
            <div class="col-xs-3">
             <label class="setting_switch">
              <input id="booking_enabled" name="booking_enabled" onclick="toggleFormTarget()" type="checkbox" value="booking"/>
              <span class="setting_switch_slider round">
              </span>
             </label>
            </div>
           </div>
          </div>
         </div>
         <div class="col-sm-12 col-md-3 text-right">
          <button class="btn btn-md wgg_tertiary display-none" id="reset_filter" type="button">
           Filter entfernen
          </button>
          <button class="filter_submit_button btn btn-md wgg_blue hidden-xs" onclick="setTimeout(function () { window.PartnerSearch.performPartnerSearch() }, 10)" type="submit">
           Filter anwenden
          </button>
         </div>
        </div>
        <div class="row">
         <div class="filter_set_buttons col-xs-12" style="padding-top:8px;">
         </div>
        </div>
       </form>
      </div>
      <link href="/assets/css/jquery-ui.min.css" rel="stylesheet"/>
      <script src="/js/jquery/jquery-ui/jquery-ui.min.js">
      </script>
      <script src="/js/external_libraries/twemoji.min.js">
      </script>
      <script src="/js/lib/TextTools.lib.tjb1714564289.js">
      </script>
      <script src="/js/Location/Photon.class.tjb1721404928.js">
      </script>
      <script>
       window.photon = Photon({
        language: site_language,
        min_log_level: '5'
    });
      </script>
      <script src="/js/lib/PartnerMapping.lib.tjb1632386809.js">
      </script>
      <script src="/js/Partner/PartnerSearch.class.tjb1697813907.js">
      </script>
      <script>
       var date_format      = 'dd.mm.yy';
    var day_names        = ['So', 'Mo', 'Di', 'Mi', 'Do', 'Fr', 'Sa'];
    var month_names      = ['Januar', 'Februar', 'März', 'April', 'Mai', 'Juni', 'Juli', 'August', 'September', 'Oktober', 'November', 'Dezember'];
    var today_text       = 'Heute';
    var close_text       = 'Fertig';
    var clear_filter_url = 'https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?clear_filter=1';

    var short_term_airbnb_textlink_parts = {
        short_term_airbnb_textlink_1 : 'Unterkunft von ',
        short_term_airbnb_textlink_2 : ' bis ',
        short_term_airbnb_textlink_3 : ' in ',
        city_name : 'Frankfurt am Main'
    }

    var mobile_layout = '';

    var checkin_date  = null;
    if ($('#dFr').val() !== '') {
        checkin_date = new Date($('#dFr').val() * 1000);
    }

    var checkout_date  = null;
    if ($('#dFr').val() !== '') {
        checkout_date = new Date($('#dTo').val() * 1000);
    }

    window.PartnerSearch = PartnerSearch({
        view: 'offer_list',
        mobile_layout: mobile_layout,
        categories: $('#categories.selectpicker').val(),
        city_id: '41',
        city_name: replaceSpecialCharacters($('#autocompinp').val()),
        checkin_date: checkin_date,
        checkout_date: checkout_date,
        min_log_level: '5'
    });

    window.PartnerSearch.pickPartnerSearch();

    // Update the booking link if Booking is the displayed advertiser
    window.PartnerSearch.addBookingLink();

    $('#categories.selectpicker').on('change', function() {
        window.PartnerSearch.updateState({
            categories: $(this).val()
        });
        window.PartnerSearch.addBookingLink();
    });
      </script>
      <script src="/js/filters/offers_list_view.tjb1697813907.js">
      </script>
     </div>
    </div>
    <div class="row" id="main_content">
     <div class="col-xs-12 col-md-8 col-md-push-4" id="main_column">
      <script>
       // Hide/Show listing via a user click (id's sorted
     run_show_hide_ad = false;      listeView = false;
      </script>
      <div class="row noprint mb10">
       <div class="col-sm-5 hidden-xs dropdown">
        <button aria-expanded="true" class="btn btn-sm wgg_white dropdown-toggle" data-toggle="dropdown" id="dropdownMenu1" type="button">
         Eintragsdatum
         <span class="caret">
         </span>
        </button>
        <ul aria-labelledby="dropdownMenu1" class="dropdown-menu" role="menu">
         <li role="presentation">
          <a href="#" onclick="window.location='https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?sort_column=1&amp;sort_order=0';" role="menuitem" tabindex="-1">
           Max. Miete
          </a>
         </li>
         <li role="presentation">
          <a href="#" onclick="window.location='https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?sort_column=2&amp;sort_order=0';" role="menuitem" tabindex="-1">
           Min. Größe
          </a>
         </li>
         <li role="presentation">
          <a href="#" onclick="window.location='https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?sort_column=4&amp;sort_order=0';" role="menuitem" tabindex="-1">
           frei ab
          </a>
         </li>
         <li role="presentation">
          <a href="#" onclick="window.location='https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?sort_column=5&amp;sort_order=0';" role="menuitem" tabindex="-1">
           frei bis
          </a>
         </li>
        </ul>
       </div>
       <div class="col-sm-7 hidden-xs">
        <div class="btn-group btn-group-sm pull-right" data-toggle="buttons" role="group">
         <label class="btn wgg_white" onclick="window.location='1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.0.0.html';">
          <a class="link-grey" href="1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.0.0.html" title="Listenansicht">
           <span alt="Listenansicht" aria-hidden="true" class="mdi mdi-view-sequential mdi-16px mdi-lh mdi-vm" title="Listenansicht">
           </span>
           <span style="font-weight: normal;">
            Liste
           </span>
          </a>
         </label>
         <label class="btn wgg_white" onclick="window.location='1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.3.0.html';">
          <a class="link-grey" href="1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.3.0.html" rel="nofollow" title="Galerieansicht">
           <span alt="Galerieansicht" aria-hidden="true" class="mdi mdi-view-grid mdi-14px mdi-lh" title="Galerieansicht">
           </span>
           <span style="font-weight: normal;">
            Galerie
           </span>
          </a>
         </label>
        </div>
       </div>
      </div>
      <div class="mt10 noprint" id="partners_wrapper">
       <div class="clicked_partner wgg_card housinganywhere_ad noprint">
        <div class="row">
         <div class="col-sm-4 card_image">
          <a class="partners campaign_click" data-advertiser_partner="HousingAnywhere" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="HousingAnywhere" data-campaign_type="inlist_ads" data-category="1-Zimmer-Wohnung" data-city_id="41" data-city_name="Frankfurt am Main" data-country_code="de" data-display_language="de" data-google-interstitial="false" data-partner_category="1" data-partner_id="2" data-partner_position="1" data-partner_price="610" data-partner_rent_type="0" data-partner_tranking_link="c_1_r_0_lt_detail_ii_2_ti_1_pi_3_si_2_ts_wg_www_opn_dom_pt1_Frankfurt am Main_dl_de_s_www" data-partner_view="detail" data-rent-type="All rent types" href="https://housinganywhere.com/de/s/Frankfurt-am-Main--Deutschland?utm_source=wg-gesucht&amp;utm_medium=affiliate&amp;affiliate_partner_id=32473&amp;utm_campaign=top-placement&amp;utm_content=frankfurt&amp;bedroomCount=1&amp;categories=studio-for-rent&amp;categories=apartment-for-rent&amp;utm_term=website" rel="nofollow" style="background-image: url(img/kooperationen/housing_anywhere/flat_3.png);" target="_blank">
          </a>
         </div>
         <div class="col-sm-8 card_body" style="background-color: #fff;">
          <div class="row">
           <div class="col-sm-12">
            <h3 class="truncate_title" title="Schönes 1-Zimmer-Apartment in neu gebauter Wohnanlage mittel- oder langfristig frei">
             <a class="partners campaign_click" data-advertiser_partner="HousingAnywhere" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="HousingAnywhere" data-campaign_type="inlist_ads" data-category="1-Zimmer-Wohnung" data-city_id="41" data-city_name="Frankfurt am Main" data-country_code="de" data-display_language="de" data-google-interstitial="false" data-partner_category="1" data-partner_id="2" data-partner_position="1" data-partner_price="610" data-partner_rent_type="0" data-partner_tranking_link="c_1_r_0_lt_detail_ii_2_ti_1_pi_3_si_2_ts_wg_www_opn_dom_pt1_Frankfurt am Main_dl_de_s_www" data-partner_view="detail" data-rent-type="All rent types" href="https://housinganywhere.com/de/s/Frankfurt-am-Main--Deutschland?utm_source=wg-gesucht&amp;utm_medium=affiliate&amp;affiliate_partner_id=32473&amp;utm_campaign=top-placement&amp;utm_content=frankfurt&amp;bedroomCount=1&amp;categories=studio-for-rent&amp;categories=apartment-for-rent&amp;utm_term=website" rel="nofollow" target="_blank">
              Schönes 1-Zimmer-Apartment in neu gebauter Wohnanlage mittel- oder langfristig frei
             </a>
            </h3>
           </div>
           <div class="col-sm-12">
            <span>
             Wohnen im Szeneviertel
            </span>
           </div>
          </div>
          <div class="row middle">
           <div class="col-xs-6">
            <b>
             ab
            </b>
            <b>
             <span>
              610 €
             </span>
            </b>
            <b>
            </b>
           </div>
           <div class="col-xs-6 partner_secondary_text">
            kurzfristig frei
           </div>
          </div>
          <div class="row pt60">
           <div class="col-sm-12 flex_space_between">
            <span>
             Beispielanzeige von HousingAnywhere*
            </span>
            <a class="detailansicht partners campaign_click" data-advertiser_partner="HousingAnywhere" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="HousingAnywhere" data-campaign_type="inlist_ads" data-category="1-Zimmer-Wohnung" data-city_id="41" data-city_name="Frankfurt am Main" data-country_code="de" data-display_language="de" data-google-interstitial="false" data-partner_category="1" data-partner_id="2" data-partner_position="1" data-partner_price="610" data-partner_rent_type="0" data-partner_tranking_link="c_1_r_0_lt_detail_ii_2_ti_1_pi_3_si_2_ts_wg_www_opn_dom_pt1_Frankfurt am Main_dl_de_s_www" data-partner_view="detail" data-rent-type="All rent types" href="https://housinganywhere.com/de/s/Frankfurt-am-Main--Deutschland?utm_source=wg-gesucht&amp;utm_medium=affiliate&amp;affiliate_partner_id=32473&amp;utm_campaign=top-placement&amp;utm_content=frankfurt&amp;bedroomCount=1&amp;categories=studio-for-rent&amp;categories=apartment-for-rent&amp;utm_term=website" rel="nofollow" style="color: #898989;" target="_blank">
             Anzeige
            </a>
           </div>
          </div>
         </div>
        </div>
       </div>
       <script src="/ajax/api/Smp/js/Partners.tjb1697813907.js">
       </script>
      </div>
      <span id="back_to_ad_11347490">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11347490">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Bockenheim.11347490.html">
            Ganzes Studio in Frankfurt
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11347490);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="11347490" id="liste-details-ad-11347490">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Bockenheim.11347490.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/38/a6b3f74f993c625f9aeb84920e871d0038b3929c83f1929d3644fec1b79a2ee7_a71f1e37e4bb11dd7f2ac74800820f853c56d42b55459b093e9c372c.small.jpg);">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Ganzes Studio in Frankfurt">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Bockenheim.11347490.html">
             Ganzes Studio in Frankfurt
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="11347490" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-11347490 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11347490">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Bockenheim |
                        
                        Klüberstraße-10 Westend-S...
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            1140 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           05.12.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            21 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img alt="Spotahome, S.L.U" class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2023/31/307a78b53168db591d4587144203009ba6c23a6422abdf012f3570a66de7c572_96962e5dd0d0e5afcf55343d1752995429131e1d6c0dd5e8a0343b95e92f1c4f_spotahome_logo.sized.sized.png" src="https://img.wg-gesucht.de/media/up/2023/31/307a78b53168db591d4587144203009ba6c23a6422abdf012f3570a66de7c572_96962e5dd0d0e5afcf55343d1752995429131e1d6c0dd5e8a0343b95e92f1c4f_spotahome_logo.sized.thumb.png"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziert
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Spotahome
             </span>
             <span style="color: #218700;">
              Online: 58 Minuten
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Bockenheim.11347490.html">
          <b>
           Ganzes Studio in Frankfurt
          </b>
         </a>
         <br/>
         <div>
          <b>
           1140 € |
          </b>
          <b>
           21 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Bockenheim |
                
                Klüberstraße-10 Westend-S...
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    05.12.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/11347490.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_11351848">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11351848">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11351848.html">
            Studio-Apartment zu vermieten in Frankfurt
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11351848);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="11351848" id="liste-details-ad-11351848">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11351848.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/39/f444dae64365ef64ed27a8d4923596968be357e4d0d9a72b42e6cff629ac9fa7_e4b25fad15b748baa102c1769c892f6543a03e1389e749c2e95ec730.small.jpg);">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Studio-Apartment zu vermieten in Frankfurt">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11351848.html">
             Studio-Apartment zu vermieten in Frankfurt
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="11351848" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-11351848 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11351848">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Heddernheim |
                        
                        Marie-Curie-Straße 20
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            769 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           01.10.2024
          </div>
          <div class="col-xs-3 text-right">
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img alt="Spotahome, S.L.U" class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2023/31/307a78b53168db591d4587144203009ba6c23a6422abdf012f3570a66de7c572_96962e5dd0d0e5afcf55343d1752995429131e1d6c0dd5e8a0343b95e92f1c4f_spotahome_logo.sized.sized.png" src="https://img.wg-gesucht.de/media/up/2023/31/307a78b53168db591d4587144203009ba6c23a6422abdf012f3570a66de7c572_96962e5dd0d0e5afcf55343d1752995429131e1d6c0dd5e8a0343b95e92f1c4f_spotahome_logo.sized.thumb.png"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziert
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Spotahome
             </span>
             <span style="color: #218700;">
              Online: 1 Stunde
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11351848.html">
          <b>
           Studio-Apartment zu vermieten in Frankfurt
          </b>
         </a>
         <br/>
         <div>
          <b>
           769 € |
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Heddernheim |
                
                Marie-Curie-Straße 20
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    01.10.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/11351848.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_11341327">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11341327">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Sachsenhausen.11341327.html">
            1,5 Zimmer Wohnung am Schweizer Platz
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11341327);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="11341327" id="liste-details-ad-11341327">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Sachsenhausen.11341327.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/38/3a5afb39cefe0e3120253ce1075ef66908a76d89e0f7fd3ed3b981cabc1de7be_172671776748594670216748553612.small.JPEG);">
         </a>
         <div class="card_image_features">
          <span class="card_image_feature_background card_image_feature_online_tour">
           <span class="mdi mdi-cellphone mdi-16px mr5">
           </span>
           Online-Besichtigung
          </span>
         </div>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="1,5 Zimmer Wohnung am Schweizer Platz">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Sachsenhausen.11341327.html">
             1,5 Zimmer Wohnung am Schweizer Platz
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="11341327" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-11341327 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11341327">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Sachsenhausen |
                        
                        Schweizer Straße
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            800 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           01.10.2024
                    
                                            - 24.10.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            44 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Valerio
             </span>
             <span style="color: #218700;">
              Online: 1 Stunde
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Sachsenhausen.11341327.html">
          <b>
           1,5 Zimmer Wohnung am Schweizer Platz
          </b>
         </a>
         <br/>
         <div>
          <b>
           800 € |
          </b>
          <b>
           44 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Sachsenhausen |
                
                Schweizer Straße
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    01.10.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/11341327.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_11365796">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11365796">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11365796.html">
            Studio-Apartment zu vermieten in Frankfurt
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11365796);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="11365796" id="liste-details-ad-11365796">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11365796.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/40/611562fd6403b46be7d7f6ebe23ad928889c75d050717a723024bf895960ffca_3edbe1a2589b81379fd859eb246b66fe952cabfc2d73a568aea532e9.small.jpg);">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Studio-Apartment zu vermieten in Frankfurt">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11365796.html">
             Studio-Apartment zu vermieten in Frankfurt
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="11365796" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-11365796 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11365796">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Heddernheim |
                        
                        Marie-Curie-Straße 20
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            784 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           01.10.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            16 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img alt="Spotahome, S.L.U" class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2023/31/307a78b53168db591d4587144203009ba6c23a6422abdf012f3570a66de7c572_96962e5dd0d0e5afcf55343d1752995429131e1d6c0dd5e8a0343b95e92f1c4f_spotahome_logo.sized.sized.png" src="https://img.wg-gesucht.de/media/up/2023/31/307a78b53168db591d4587144203009ba6c23a6422abdf012f3570a66de7c572_96962e5dd0d0e5afcf55343d1752995429131e1d6c0dd5e8a0343b95e92f1c4f_spotahome_logo.sized.thumb.png"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziert
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Spotahome
             </span>
             <span style="color: #218700;">
              Online: 2 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11365796.html">
          <b>
           Studio-Apartment zu vermieten in Frankfurt
          </b>
         </a>
         <br/>
         <div>
          <b>
           784 € |
          </b>
          <b>
           16 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Heddernheim |
                
                Marie-Curie-Straße 20
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    01.10.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/11365796.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_11336791">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11336791">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Nordend-West.11336791.html">
            Top Nordend Lage! - Ab 15.02.2025 - Großes + nagelneu möbliertes 1-Zimmer Studio mit großem Balkon
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11336791);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="11336791" id="liste-details-ad-11336791">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Nordend-West.11336791.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/38/b3ce72fd9147b09c8e37a87a31c50a738ca3836d4407e958401c837e60074ae4_1_Der_Wohnbereich__1_.small.jpg);">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Top Nordend Lage! - Ab 15.02.2025 - Großes + nagelneu möbliertes 1-Zimmer Studio mit großem Balkon">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Nordend-West.11336791.html">
             Top Nordend Lage! - Ab 15.02.2025 - Großes + nagelneu möbliertes 1-Zimmer Studio mit großem Balkon
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="11336791" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-11336791 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11336791">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Nordend-West |
                        
                        Leimenrode
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            1650 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           15.02.2025
                    
                                            - 01.11.2033
          </div>
          <div class="col-xs-3 text-right">
           <b>
            49 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img alt="We rooms" class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.sized.jpg" src="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.thumb.jpg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziert
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Alexander Seufert
             </span>
             <span style="color: #218700;">
              Online: 3 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Nordend-West.11336791.html">
          <b>
           Top Nordend Lage! - Ab 15.02.2025 - Großes + nagelneu möbliertes 1-Zimmer Studio mit großem Balkon
          </b>
         </a>
         <br/>
         <div>
          <b>
           1650 € |
          </b>
          <b>
           49 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Nordend-West |
                
                Leimenrode
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    15.02.2025
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/11336791.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_11365485">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11365485">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?asset_id=11365485&amp;pu=22446810&amp;sort_column=1&amp;sort_order=0">
            Zimmer mit eigenem Bad und Kochzeile, voll möbliert 30qm
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11365485);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item cursor-pointer" data-id="11365485" data-url="/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?asset_id=11365485&amp;pu=22446810&amp;sort_column=1&amp;sort_order=0" id="liste-details-ad-11365485">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a class="campaign_click" data-campaign_click_position="6" data-campaign_click_source="list_view_detail" data-campaign_partner="Wunderflats" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?asset_id=11365485&amp;pu=22446810&amp;sort_column=1&amp;sort_order=0" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/40/f3edbe59f9cb09e7b6436a7c46d472f1774f1ba25b0593ca0d5ba78e8c2c98a4_H55dCON_UX5X8sHG1DrA1_large.small.jpg);" target="_blank">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Zimmer mit eigenem Bad und Kochzeile, voll möbliert 30qm">
            <a class="campaign_click" data-campaign_click_position="6" data-campaign_click_source="list_view_detail" data-campaign_partner="Wunderflats" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?asset_id=11365485&amp;pu=22446810&amp;sort_column=1&amp;sort_order=0" target="_blank">
             Zimmer mit eigenem Bad und Kochzeile, voll möbliert 30qm
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="11365485" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-11365485 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11365485">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Hausen |
                        
                        Heerstraße
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            700 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           02.12.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            30 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img class="avatar" src="/img/placeholder/no_profile_image_company.svg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziertes Unternehmen
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Wunderflats GmbH
             </span>
             <span style="color: #218700;">
              Online: 1 Stunde
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?asset_id=11365485&amp;pu=22446810&amp;sort_column=1&amp;sort_order=0">
          <b>
           Zimmer mit eigenem Bad und Kochzeile, voll möbliert 30qm
          </b>
         </a>
         <br/>
         <div>
          <b>
           700 € |
          </b>
          <b>
           30 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Hausen |
                
                Heerstraße
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    02.12.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/11365485.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_11335331">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11335331">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.11335331.html">
            Neubau 2020! - Ab 07.12.2024 - Schick möbliertes 1-Zimmer Apartment mit Balkon &amp; Parkettboden- ze...
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11335331);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="11335331" id="liste-details-ad-11335331">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.11335331.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/38/3a4f773ae86b8616312e1b87c8c50783a68a49351cb84f65f8a96b1e381608bd_1_Wohn_und_Schlafbereich__1_.small.jpg);">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Neubau 2020! - Ab 07.12.2024 - Schick möbliertes 1-Zimmer Apartment mit Balkon &amp; Parkettboden- zentr. Ostend Lage">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.11335331.html">
             Neubau 2020! - Ab 07.12.2024 - Schick möbliertes 1-Zimmer Apartment mit Balkon &amp; Parkettboden- zentr. Ostend Lage
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="11335331" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-11335331 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11335331">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Ostend |
                        
                        Grusonstrasse
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            1500 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           07.12.2024
                    
                                            - 31.12.2033
          </div>
          <div class="col-xs-3 text-right">
           <b>
            36 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img alt="We rooms" class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.sized.jpg" src="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.thumb.jpg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziert
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Alexander Seufert
             </span>
             <span style="color: #218700;">
              Online: 3 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.11335331.html">
          <b>
           Neubau 2020! - Ab 07.12.2024 - Schick möbliertes 1-Zimmer Apartment mit Balkon &amp; Parkettboden- ze...
          </b>
         </a>
         <br/>
         <div>
          <b>
           1500 € |
          </b>
          <b>
           36 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Ostend |
                
                Grusonstrasse
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    07.12.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/11335331.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_7299984">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-7299984">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Westend-Sued.7299984.html">
            Ab 01.11.2024 - sonniges und großes 1-Zimmer-Apartment in Top Lage im Frankfurter Westend
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 7299984);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="7299984" id="liste-details-ad-7299984">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Westend-Sued.7299984.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2019/22/c19831684e1ee2fa6db04599794fec4150451e8954c86679fbea7bb911d22a0c_We_Rooms_1.small.jpg);">
         </a>
         <div class="card_image_features">
          <span class="card_image_feature_background card_image_feature_online_tour">
           <span class="mdi mdi-cellphone mdi-16px mr5">
           </span>
           Online-Besichtigung
          </span>
         </div>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Ab 01.11.2024 - sonniges und großes 1-Zimmer-Apartment in Top Lage im Frankfurter Westend">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Westend-Sued.7299984.html">
             Ab 01.11.2024 - sonniges und großes 1-Zimmer-Apartment in Top Lage im Frankfurter Westend
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="7299984" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-7299984 mdi mdi-heart-outline icon-fav-empty" id="to-fav-7299984">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Westend-Süd |
                        
                        Feuerbacher Straße 00
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            1500 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           01.11.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            31 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img alt="We rooms" class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.sized.jpg" src="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.thumb.jpg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziert
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Alexander Seufert
             </span>
             <span style="color: #218700;">
              Online: 3 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Westend-Sued.7299984.html">
          <b>
           Ab 01.11.2024 - sonniges und großes 1-Zimmer-Apartment in Top Lage im Frankfurter Westend
          </b>
         </a>
         <br/>
         <div>
          <b>
           1500 € |
          </b>
          <b>
           31 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Westend-Süd |
                
                Feuerbacher Straße 00
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    01.11.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/7299984.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_11335185">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11335185">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Roedelheim.11335185.html">
            Ab 15.02.2025 - gemütlich möbliertes 1 Zimmer Apartment in Frankfurt Rödelheim
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11335185);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="11335185" id="liste-details-ad-11335185">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Roedelheim.11335185.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/38/ca0a59a394a4615891e003f54aafb3cfca51d3cac878f646edaeefa4a1f452fd_1_Zimmeransicht__1_.small.jpg);">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Ab 15.02.2025 - gemütlich möbliertes 1 Zimmer Apartment in Frankfurt Rödelheim">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Roedelheim.11335185.html">
             Ab 15.02.2025 - gemütlich möbliertes 1 Zimmer Apartment in Frankfurt Rödelheim
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="11335185" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-11335185 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11335185">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Rödelheim |
                        
                        Am Hopfengarten
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            700 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           15.02.2025
                    
                                            - 01.11.2033
          </div>
          <div class="col-xs-3 text-right">
           <b>
            17 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img alt="We rooms" class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.sized.jpg" src="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.thumb.jpg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziert
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Alexander Seufert
             </span>
             <span style="color: #218700;">
              Online: 3 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Roedelheim.11335185.html">
          <b>
           Ab 15.02.2025 - gemütlich möbliertes 1 Zimmer Apartment in Frankfurt Rödelheim
          </b>
         </a>
         <br/>
         <div>
          <b>
           700 € |
          </b>
          <b>
           17 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Rödelheim |
                
                Am Hopfengarten
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    15.02.2025
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/11335185.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <a class="text-decoration-none campaign_click" data-campaign_click_position="block5" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggplus_promotion" href="/wgg-plus-info.html" target="_blank">
       <div class="panel wgg_plus_teaser">
        <div class="row">
         <div class="col-sm-6">
          <h3 class="text-black font-26px ml5 mb5 mt10 wgg_plus_teaser_heading">
           Höhere Reichweite
           <span class="hidden-xs">
            mit
           </span>
          </h3>
          <div class="hidden-sm hidden-md hidden-lg text-center text-black font-18px my20">
           <b>
            mit
           </b>
          </div>
          <img class="img-responsive wgg_plus_teaser_image" src="/img/wgg_plus_logo.png"/>
         </div>
         <div class="col-sm-offset-1 col-sm-5">
          <p class="font-18px text-black wgg_plus_teaser_text">
           Profitieren Sie von der täglichen Aktualisierung Ihres Gesuchs, das so häufiger erscheint.
          </p>
          <span class="hidden-xs orange_text_link text-bold font-18px">
           Mehr erfahren
          </span>
          <button class="hidden-sm hidden-md hidden-lg btn wgg_gray btn-lg btn-block" style="text-transform: none;" type="button">
           Mehr erfahren
          </button>
         </div>
        </div>
       </div>
      </a>
      <span id="back_to_ad_6899614">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-6899614">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.6899614.html">
            Ab 01.01.2025 - modern möbliertes Doppelzimmer im 4. OG - zentrale Ostendlage - nähe Main und EZB
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 6899614);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="6899614" id="liste-details-ad-6899614">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.6899614.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2018/41/a21a4285958d5011ca3054c03e4647f3d0d0b3e8a6da20a04b776c75c6eb62c3_WeRooms_89.small.jpg);">
         </a>
         <div class="card_image_features">
          <span class="card_image_feature_background card_image_feature_online_tour">
           <span class="mdi mdi-cellphone mdi-16px mr5">
           </span>
           Online-Besichtigung
          </span>
         </div>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Ab 01.01.2025 - modern möbliertes Doppelzimmer im 4. OG - zentrale Ostendlage - nähe Main und EZB">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.6899614.html">
             Ab 01.01.2025 - modern möbliertes Doppelzimmer im 4. OG - zentrale Ostendlage - nähe Main und EZB
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="6899614" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-6899614 mdi mdi-heart-outline icon-fav-empty" id="to-fav-6899614">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Ostend |
                        
                        Uhlandstraße 4.OG li
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            1200 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           01.01.2025
          </div>
          <div class="col-xs-3 text-right">
           <b>
            30 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img alt="We rooms" class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.sized.jpg" src="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.thumb.jpg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziert
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Alexander Seufert
             </span>
             <span style="color: #218700;">
              Online: 3 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.6899614.html">
          <b>
           Ab 01.01.2025 - modern möbliertes Doppelzimmer im 4. OG - zentrale Ostendlage - nähe Main und EZB
          </b>
         </a>
         <br/>
         <div>
          <b>
           1200 € |
          </b>
          <b>
           30 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Ostend |
                
                Uhlandstraße 4.OG li
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    01.01.2025
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/6899614.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_7673952">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-7673952">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Bahnhofsviertel.7673952.html">
            Ab 15.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 7673952);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="7673952" id="liste-details-ad-7673952">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Bahnhofsviertel.7673952.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2023/18/3670ba336f4ca09132474971521cad28d1a6f8881bf0ecbb3e9dff86cc49e1d9_Screenshot_2023_05_05_141440.small.jpg);">
         </a>
         <div class="card_image_features">
          <span class="card_image_feature_background card_image_feature_online_tour">
           <span class="mdi mdi-cellphone mdi-16px mr5">
           </span>
           Online-Besichtigung
          </span>
         </div>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Ab 15.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Bahnhofsviertel.7673952.html">
             Ab 15.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="7673952" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-7673952 mdi mdi-heart-outline icon-fav-empty" id="to-fav-7673952">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Bahnhofsviertel |
                        
                        Taunusstr. HH 2OG rechts
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            860 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           15.11.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            16 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img alt="We rooms" class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.sized.jpg" src="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.thumb.jpg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziert
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Alexander Seufert
             </span>
             <span style="color: #218700;">
              Online: 3 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Bahnhofsviertel.7673952.html">
          <b>
           Ab 15.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
          </b>
         </a>
         <br/>
         <div>
          <b>
           860 € |
          </b>
          <b>
           16 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Bahnhofsviertel |
                
                Taunusstr. HH 2OG rechts
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    15.11.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/7673952.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_11306130">
      </span>
      <div class="mb20 text-center">
       <div id="div-gpt-ad-189159851654146248-oop6">
        <script type="text/javascript">
         googletag.cmd.push(function()
                        { googletag.display('div-gpt-ad-189159851654146248-oop6'); }
                        );
        </script>
       </div>
      </div>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11306130">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Bahnhofsviertel.11306130.html">
            Ab 01.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11306130);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="11306130" id="liste-details-ad-11306130">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Bahnhofsviertel.11306130.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/36/643b413064403a87a3c50fd0638d250490326825eae3d55f7a3b080a1ee75737_1_Ansicht_Apartment__5_.small.jpg);">
         </a>
         <div class="card_image_features">
          <span class="card_image_feature_background card_image_feature_online_tour">
           <span class="mdi mdi-cellphone mdi-16px mr5">
           </span>
           Online-Besichtigung
          </span>
         </div>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Ab 01.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Bahnhofsviertel.11306130.html">
             Ab 01.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="11306130" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-11306130 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11306130">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Bahnhofsviertel |
                        
                        Taunusstr. HH 2OG links
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            850 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           01.11.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            19 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img alt="We rooms" class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.sized.jpg" src="https://img.wg-gesucht.de/media/up/2022/17/3846c711339811ab55593d814d0b2d6918819f3f91749decb8489b93ce022396_Ansprechpartner.thumb.jpg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziert
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Alexander Seufert
             </span>
             <span style="color: #218700;">
              Online: 3 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Bahnhofsviertel.11306130.html">
          <b>
           Ab 01.11.2024 - schick möbliertes 1-Zimmer-Apartment - zentraler Lage im Bahnhofsviertel
          </b>
         </a>
         <br/>
         <div>
          <b>
           850 € |
          </b>
          <b>
           19 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Bahnhofsviertel |
                
                Taunusstr. HH 2OG links
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    01.11.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/11306130.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_5973364">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-5973364">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Bahnhofsviertel.5973364.html">
            Grosses 1 Zi Apartment in zentraler, charmanter Liegenschaft (App. 1.2)
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 5973364);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="5973364" id="liste-details-ad-5973364">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Bahnhofsviertel.5973364.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/37/1b4ccaafef843d3f6a5c47d5744b890063ddf2fb3a7e225a24dd6f89a56b9b20_ML_Apt_1.2_Blick_in_Raum_neu_9.24.small.jpg);">
         </a>
         <div class="card_image_features">
          <span class="card_image_feature_background card_image_feature_online_tour">
           <span class="mdi mdi-cellphone mdi-16px mr5">
           </span>
           Online-Besichtigung
          </span>
         </div>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Grosses 1 Zi Apartment in zentraler, charmanter Liegenschaft (App. 1.2)">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Bahnhofsviertel.5973364.html">
             Grosses 1 Zi Apartment in zentraler, charmanter Liegenschaft (App. 1.2)
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="5973364" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-5973364 mdi mdi-heart-outline icon-fav-empty" id="to-fav-5973364">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Bahnhofsviertel |
                        
                        Mainzer Landstrasse 125
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            1350 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           01.12.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            35 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Michael
             </span>
             <span style="color: #218700;">
              Online: 4 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Bahnhofsviertel.5973364.html">
          <b>
           Grosses 1 Zi Apartment in zentraler, charmanter Liegenschaft (App. 1.2)
          </b>
         </a>
         <br/>
         <div>
          <b>
           1350 € |
          </b>
          <b>
           35 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Bahnhofsviertel |
                
                Mainzer Landstrasse 125
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    01.12.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/5973364.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_8975411">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-8975411">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Nordend-Ost.8975411.html">
            Wunderschönes Apartment in perfekter Nordend Lage
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 8975411);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="8975411" id="liste-details-ad-8975411">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Nordend-Ost.8975411.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2021/41/9b42fe075d2f445bbfd0b12d420c5513cccc9834347ea367845586c966225be6_IMG_20200426_WA0005.small.jpg);">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Wunderschönes Apartment in perfekter Nordend Lage">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Nordend-Ost.8975411.html">
             Wunderschönes Apartment in perfekter Nordend Lage
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="8975411" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-8975411 mdi mdi-heart-outline icon-fav-empty" id="to-fav-8975411">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Nordend-Ost |
                        
                        Rohrbachstraße 24
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            1200 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           15.10.2024
                    
                                            - 15.10.2025
          </div>
          <div class="col-xs-3 text-right">
           <b>
            38 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              S. Jennewein
             </span>
             <span style="color: #218700;">
              Online: 9 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Nordend-Ost.8975411.html">
          <b>
           Wunderschönes Apartment in perfekter Nordend Lage
          </b>
         </a>
         <br/>
         <div>
          <b>
           1200 € |
          </b>
          <b>
           38 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Nordend-Ost |
                
                Rohrbachstraße 24
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    15.10.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/8975411.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_8627792">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-8627792">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Westend-Sued.8627792.html">
            Zwischenmiete in perfekter Lage
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 8627792);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="8627792" id="liste-details-ad-8627792">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Westend-Sued.8627792.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2022/36/ac8cef31d2b93f0ba7d333b53697ec64fbd6e3f0b848168708838dea7224214c_166249196077077011759.small.JPEG);">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Zwischenmiete in perfekter Lage">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Westend-Sued.8627792.html">
             Zwischenmiete in perfekter Lage
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="8627792" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-8627792 mdi mdi-heart-outline icon-fav-empty" id="to-fav-8627792">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Westend-Süd |
                        
                        Kronberger Straße 50
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            850 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           21.10.2024
                    
                                            - 31.08.2025
          </div>
          <div class="col-xs-3 text-right">
           <b>
            34 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img alt="Daniel M." class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2022/38/c0ea99eb8c226f36cc51591383a4a3a539e4dc8bf41d8bd72457622bb278942f_user_photo_1663781621428428.sized.jpeg" src="https://img.wg-gesucht.de/media/up/2022/38/c0ea99eb8c226f36cc51591383a4a3a539e4dc8bf41d8bd72457622bb278942f_user_photo_1663781621428428.thumb.jpeg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Daniel M.
             </span>
             <span style="color: #218700;">
              Online: 11 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Westend-Sued.8627792.html">
          <b>
           Zwischenmiete in perfekter Lage
          </b>
         </a>
         <br/>
         <div>
          <b>
           850 € |
          </b>
          <b>
           34 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Westend-Süd |
                
                Kronberger Straße 50
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    21.10.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/8627792.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_8906999">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-8906999">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Hausen.8906999.html">
            One Bedroom fully furnished very specious Flat in Frankfurt Hausen
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 8906999);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="8906999" id="liste-details-ad-8906999">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Hausen.8906999.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2021/36/dd4892f410b64f04c42c78b66cea39f44482786c398e310d4a0bb2c060bdae3d_163094903872472460246.small.JPEG);">
         </a>
         <div class="card_image_features">
          <span class="card_image_feature_background card_image_feature_online_tour">
           <span class="mdi mdi-cellphone mdi-16px mr5">
           </span>
           Online-Besichtigung
          </span>
         </div>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="One Bedroom fully furnished very specious Flat in Frankfurt Hausen">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Hausen.8906999.html">
             One Bedroom fully furnished very specious Flat in Frankfurt Hausen
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="8906999" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-8906999 mdi mdi-heart-outline icon-fav-empty" id="to-fav-8906999">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Hausen |
                        
                        Gross Nelkenstrasse, Hausen
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            860 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           15.11.2024
                    
                                            - 31.12.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            36 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Kapil Mittal
             </span>
             <span style="color: #218700;">
              Online: 12 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Hausen.8906999.html">
          <b>
           One Bedroom fully furnished very specious Flat in Frankfurt Hausen
          </b>
         </a>
         <br/>
         <div>
          <b>
           860 € |
          </b>
          <b>
           36 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Hausen |
                
                Gross Nelkenstrasse, Hausen
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    15.11.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/8906999.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_11010540">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11010540">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?asset_id=11010540&amp;pu=19158680&amp;sort_column=1&amp;sort_order=0">
            Saubere 1-Zimmer-Wohnung in Frankfurt am Main zu vermieten
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11010540);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item cursor-pointer" data-id="11010540" data-url="/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?asset_id=11010540&amp;pu=19158680&amp;sort_column=1&amp;sort_order=0" id="liste-details-ad-11010540">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a class="campaign_click" data-campaign_click_position="16" data-campaign_click_source="list_view_detail" data-campaign_partner="Spotahome, S.L.U" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?asset_id=11010540&amp;pu=19158680&amp;sort_column=1&amp;sort_order=0" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/20/a82c9020637410279146ffda1dec44c2f56664d17ee412b8f7a5996f8aa6afde_a5c51b0204e3514b4ee44ecc1140e07fe9fa31ec7e6740a0e6a79c97.small.jpg);" target="_blank">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Saubere 1-Zimmer-Wohnung in Frankfurt am Main zu vermieten">
            <a class="campaign_click" data-campaign_click_position="16" data-campaign_click_source="list_view_detail" data-campaign_partner="Spotahome, S.L.U" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?asset_id=11010540&amp;pu=19158680&amp;sort_column=1&amp;sort_order=0" target="_blank">
             Saubere 1-Zimmer-Wohnung in Frankfurt am Main zu vermieten
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="11010540" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-11010540 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11010540">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Innenstadt |
                        
                        Eckenheimer Landstraße 172
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            669 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           01.01.2026
          </div>
          <div class="col-xs-3 text-right">
           <b>
            14 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img class="avatar" src="/img/placeholder/no_profile_image_company.svg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziertes Unternehmen
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Spotahome
             </span>
             <span style="color: #218700;">
              Online: 1 Stunde
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html?asset_id=11010540&amp;pu=19158680&amp;sort_column=1&amp;sort_order=0">
          <b>
           Saubere 1-Zimmer-Wohnung in Frankfurt am Main zu vermieten
          </b>
         </a>
         <br/>
         <div>
          <b>
           669 € |
          </b>
          <b>
           14 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Innenstadt |
                
                Eckenheimer Landstraße 172
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    01.01.2026
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/11010540.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_11092458">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11092458">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Sachsenhausen.11092458.html">
            Sie suchen? Wir haben Ihr neues Zuhause...
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11092458);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="11092458" id="liste-details-ad-11092458">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Sachsenhausen.11092458.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/27/3f0fd9b243c3aa58ea40279e231904b8e4edb027f0bbb988bab1acc231eb5fbe_IMG_7105.small.jpg);">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Sie suchen? Wir haben Ihr neues Zuhause...">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Sachsenhausen.11092458.html">
             Sie suchen? Wir haben Ihr neues Zuhause...
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="11092458" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-11092458 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11092458">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Sachsenhausen |
                        
                        Tucholskystraße 79
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            1440 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           30.09.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            36 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziert
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Herr Eichler
             </span>
             <span style="color: #218700;">
              Online: 12 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Sachsenhausen.11092458.html">
          <b>
           Sie suchen? Wir haben Ihr neues Zuhause...
          </b>
         </a>
         <br/>
         <div>
          <b>
           1440 € |
          </b>
          <b>
           36 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Sachsenhausen |
                
                Tucholskystraße 79
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    30.09.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/11092458.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_11364382">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11364382">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.11364382.html">
            One-bedroom apartment with great location - short-term rent
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11364382);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="11364382" id="liste-details-ad-11364382">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.11364382.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/40/789d6327d6ed11f6e711a6dd8f0d2e2fe25f41be55a7db00c2293f5a56b8c1d2_172770827623494674227623444159.small.JPEG);">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="One-bedroom apartment with great location - short-term rent">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.11364382.html">
             One-bedroom apartment with great location - short-term rent
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="11364382" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-11364382 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11364382">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Ostend |
                        
                        Königswarterstraße
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            800 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           03.10.2024
                    
                                            - 27.10.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            50 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Eve Wang
             </span>
             <span style="color: #218700;">
              Online: 13 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.11364382.html">
          <b>
           One-bedroom apartment with great location - short-term rent
          </b>
         </a>
         <br/>
         <div>
          <b>
           800 € |
          </b>
          <b>
           50 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Ostend |
                
                Königswarterstraße
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    03.10.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/11364382.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_10911782">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-10911782">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.10911782.html">
            Single room | Shared Bathroom &amp; Kitchen
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 10911782);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="10911782" id="liste-details-ad-10911782">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.10911782.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/11/6ac6e97b3db598f0c0053d50530a07e1923d23c930fe0eb178f66679a6dcbc73_171069512285994674632285928488.small.JPEG);">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Single room | Shared Bathroom &amp; Kitchen">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.10911782.html">
             Single room | Shared Bathroom &amp; Kitchen
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="10911782" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-10911782 mdi mdi-heart-outline icon-fav-empty" id="to-fav-10911782">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Ostend |
                        
                        königswarterstraße 11
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            410 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           01.11.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            15 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img alt="Tawonga Tsokodayi" class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2018/32/0156dd498e3a5b46d4cd69af8c8af7eebb53fb32f86484c193762a7690d5d17e_IMG_5233.sized.JPG" src="https://img.wg-gesucht.de/media/up/2018/32/0156dd498e3a5b46d4cd69af8c8af7eebb53fb32f86484c193762a7690d5d17e_IMG_5233.thumb.JPG"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Tawonga Tsokodayi
             </span>
             <span style="color: #218700;">
              Online: 15 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Ostend.10911782.html">
          <b>
           Single room | Shared Bathroom &amp; Kitchen
          </b>
         </a>
         <br/>
         <div>
          <b>
           410 € |
          </b>
          <b>
           15 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Ostend |
                
                königswarterstraße 11
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    01.11.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/10911782.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_9275556">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-9275556">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Griesheim.9275556.html">
            Tolle 1-Zimmerwohnung in Ffm-Griesheim  ("Studentenbude")
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 9275556);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="9275556" id="liste-details-ad-9275556">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Griesheim.9275556.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2022/14/2b891fb177b9fa1f385ffda12aa09aa32566db8975a65982c665fbdf08476dd6_20220331_155626.small.jpg);">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title='Tolle 1-Zimmerwohnung in Ffm-Griesheim  ("Studentenbude")'>
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Griesheim.9275556.html">
             Tolle 1-Zimmerwohnung in Ffm-Griesheim  ("Studentenbude")
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="9275556" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-9275556 mdi mdi-heart-outline icon-fav-empty" id="to-fav-9275556">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Griesheim |
                        
                        Alt-Griesheim 22
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            370 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           01.11.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            31 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziert
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Bruno
             </span>
             <span style="color: #218700;">
              Online: 16 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Griesheim.9275556.html">
          <b>
           Tolle 1-Zimmerwohnung in Ffm-Griesheim  ("Studentenbude")
          </b>
         </a>
         <br/>
         <div>
          <b>
           370 € |
          </b>
          <b>
           31 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Griesheim |
                
                Alt-Griesheim 22
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    01.11.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/9275556.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <span id="back_to_ad_10644431">
      </span>
      <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-10644431">
       <div class="panel-body" style="padding: 0 15px;">
        <div class="row" style="display: flex; align-items: center;">
         <div class="col-xs-10">
          <h4 class="headline headline-list-view truncate_title">
           <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Sachsenhausen.10644431.html">
            Sie suchen? Wir haben Ihr neues Zuhause...
           </a>
          </h4>
         </div>
         <div align="right" class="col-xs-2">
          <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 10644431);" title="einblenden">
          </span>
         </div>
        </div>
       </div>
      </div>
      <div class="wgg_card offer_list_item" data-id="10644431" id="liste-details-ad-10644431">
       <div class="row">
        <div class="col-sm-4 card_image">
         <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Sachsenhausen.10644431.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/23/d3ea227c313f1b49b2ce65a1bc23bd9c2eb6e84bd59a154f429d4408749b72e7_IMG_2085.small.jpg);">
         </a>
        </div>
        <div class="col-sm-8 card_body">
         <div class="row noprint">
          <div class="col-sm-12 flex_space_between">
           <h3 class="truncate_title noprint" title="Sie suchen? Wir haben Ihr neues Zuhause...">
            <a href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Sachsenhausen.10644431.html">
             Sie suchen? Wir haben Ihr neues Zuhause...
            </a>
           </h3>
           <div class="asset_favourite cursor-pointer" data-ad_id="10644431" data-ad_type="0" data-favourite_status="0">
            <span aria-hidden="true" class="fav-button-10644431 mdi mdi-heart-outline icon-fav-empty" id="to-fav-10644431">
            </span>
           </div>
          </div>
          <div class="col-xs-11">
           <span>
            1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Sachsenhausen |
                        
                        Letzter Hasenpfad 13
           </span>
          </div>
         </div>
         <div class="row noprint middle">
          <div class="col-xs-3">
           <b>
            1525 €
           </b>
          </div>
          <div class="col-xs-5 text-center">
           01.10.2024
          </div>
          <div class="col-xs-3 text-right">
           <b>
            48 m²
           </b>
          </div>
         </div>
         <div class="row noprint bottom">
          <div class="col-xs-2">
           <img class="avatar" src="/img/placeholder/no_profile_image_unisex.svg"/>
          </div>
          <div class="col-xs-9">
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between">
             <span>
              <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
               Verifiziert
               <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
               </span>
              </a>
             </span>
             <span>
             </span>
            </div>
           </div>
           <div class="row noprint">
            <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
             <span class="ml5">
              Herr Eichler
             </span>
             <span style="color: #218700;">
              Online: 17 Stunden
             </span>
            </div>
           </div>
          </div>
          <div class="col-xs-1 text-center p0">
           <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
           </span>
          </div>
         </div>
        </div>
        <div class="printonly">
         <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Sachsenhausen.10644431.html">
          <b>
           Sie suchen? Wir haben Ihr neues Zuhause...
          </b>
         </a>
         <br/>
         <div>
          <b>
           1525 € |
          </b>
          <b>
           48 m²
          </b>
         </div>
         <div>
          1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Sachsenhausen |
                
                Letzter Hasenpfad 13
         </div>
         <div style="margin-bottom:10px;">
          <b>
           Verfügbar:
                    01.10.2024
          </b>
         </div>
         <div style="margin-bottom:10px;">
          <i>
           Diese Anzeige ist erreichbar unter:
          </i>
          https://www.wg-gesucht.de/10644431.html
         </div>
         <div style="border-top: 2px solid #ddd; margin-bottom:10px">
         </div>
        </div>
       </div>
      </div>
      <h3 class="headline headline-default mt50 mb20">
       Weitere Angebote von verifizierten Anbietern
      </h3>
      <div class="premium_user_extra_list">
       <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11365485">
        <div class="panel-body" style="padding: 0 15px;">
         <div class="row" style="display: flex; align-items: center;">
          <div class="col-xs-10">
           <h4 class="headline headline-list-view truncate_title">
            <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Hausen.11365485.html">
             Zimmer mit eigenem Bad und Kochzeile, voll möbliert 30qm
            </a>
           </h4>
          </div>
          <div align="right" class="col-xs-2">
           <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11365485);" title="einblenden">
           </span>
          </div>
         </div>
        </div>
       </div>
       <div class="wgg_card offer_list_item" data-id="11365485" id="liste-details-ad-11365485">
        <div class="row">
         <div class="col-sm-4 card_image">
          <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Wunderflats" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Hausen.11365485.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/40/f3edbe59f9cb09e7b6436a7c46d472f1774f1ba25b0593ca0d5ba78e8c2c98a4_H55dCON_UX5X8sHG1DrA1_large.small.jpg);">
          </a>
         </div>
         <div class="col-sm-8 card_body">
          <div class="row noprint">
           <div class="col-sm-12 flex_space_between">
            <h3 class="truncate_title noprint" title="Zimmer mit eigenem Bad und Kochzeile, voll möbliert 30qm">
             <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Wunderflats" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Hausen.11365485.html">
              Zimmer mit eigenem Bad und Kochzeile, voll möbliert 30qm
             </a>
            </h3>
            <div class="asset_favourite cursor-pointer" data-ad_id="11365485" data-ad_type="0" data-favourite_status="0">
             <span aria-hidden="true" class="fav-button-11365485 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11365485">
             </span>
            </div>
           </div>
           <div class="col-xs-11">
            <span>
             1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Hausen |
                        
                        Heerstraße
            </span>
           </div>
          </div>
          <div class="row noprint middle">
           <div class="col-xs-3">
            <b>
             700 €
            </b>
           </div>
           <div class="col-xs-5 text-center">
            02.12.2024
           </div>
           <div class="col-xs-3 text-right">
            <b>
             30 m²
            </b>
           </div>
          </div>
          <div class="row noprint bottom">
           <div class="col-xs-2">
            <img class="avatar" src="/img/placeholder/no_profile_image_company.svg"/>
           </div>
           <div class="col-xs-9">
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between">
              <span>
               <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
                Verifiziertes Unternehmen
                <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
                </span>
               </a>
              </span>
              <span>
              </span>
             </div>
            </div>
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
              <span class="ml5">
               Wunderflats GmbH
              </span>
              <span style="color: #218700;">
               Online: 3 Stunden
              </span>
             </div>
            </div>
           </div>
           <div class="col-xs-1 text-center p0">
            <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
            </span>
           </div>
          </div>
         </div>
         <div class="printonly">
          <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Hausen.11365485.html">
           <b>
            Zimmer mit eigenem Bad und Kochzeile, voll möbliert 30qm
           </b>
          </a>
          <br/>
          <div>
           <b>
            700 € |
           </b>
           <b>
            30 m²
           </b>
          </div>
          <div>
           1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Hausen |
                
                Heerstraße
          </div>
          <div style="margin-bottom:10px;">
           <b>
            Verfügbar:
                    02.12.2024
           </b>
          </div>
          <div style="margin-bottom:10px;">
           <i>
            Diese Anzeige ist erreichbar unter:
           </i>
           https://www.wg-gesucht.de/11365485.html
          </div>
          <div style="border-top: 2px solid #ddd; margin-bottom:10px">
          </div>
         </div>
        </div>
       </div>
       <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11312619">
        <div class="panel-body" style="padding: 0 15px;">
         <div class="row" style="display: flex; align-items: center;">
          <div class="col-xs-10">
           <h4 class="headline headline-list-view truncate_title">
            <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11312619.html">
             Studio-Apartment zu vermieten in Frankfurt
            </a>
           </h4>
          </div>
          <div align="right" class="col-xs-2">
           <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11312619);" title="einblenden">
           </span>
          </div>
         </div>
        </div>
       </div>
       <div class="wgg_card offer_list_item" data-id="11312619" id="liste-details-ad-11312619">
        <div class="row">
         <div class="col-sm-4 card_image">
          <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Spotahome, S.L.U" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11312619.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/36/a22b596413a7170bfc7adc7440938bc8b28a89341f6d7a7acc019412eee1c2f7_e4b25fad15b748baa102c1769c892f6543a03e1389e749c2e95ec730.small.jpg);">
          </a>
         </div>
         <div class="col-sm-8 card_body">
          <div class="row noprint">
           <div class="col-sm-12 flex_space_between">
            <h3 class="truncate_title noprint" title="Studio-Apartment zu vermieten in Frankfurt">
             <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Spotahome, S.L.U" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11312619.html">
              Studio-Apartment zu vermieten in Frankfurt
             </a>
            </h3>
            <div class="asset_favourite cursor-pointer" data-ad_id="11312619" data-ad_type="0" data-favourite_status="0">
             <span aria-hidden="true" class="fav-button-11312619 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11312619">
             </span>
            </div>
           </div>
           <div class="col-xs-11">
            <span>
             1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Heddernheim |
                        
                        Marie-Curie-Straße 20
            </span>
           </div>
          </div>
          <div class="row noprint middle">
           <div class="col-xs-3">
            <b>
             815 €
            </b>
           </div>
           <div class="col-xs-5 text-center">
            01.10.2024
           </div>
           <div class="col-xs-3 text-right">
           </div>
          </div>
          <div class="row noprint bottom">
           <div class="col-xs-2">
            <img class="avatar" src="/img/placeholder/no_profile_image_company.svg"/>
           </div>
           <div class="col-xs-9">
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between">
              <span>
               <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
                Verifiziertes Unternehmen
                <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
                </span>
               </a>
              </span>
              <span>
              </span>
             </div>
            </div>
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
              <span class="ml5">
               Spotahome
              </span>
              <span style="color: #218700;">
               Online: 1 Stunde
              </span>
             </div>
            </div>
           </div>
           <div class="col-xs-1 text-center p0">
            <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
            </span>
           </div>
          </div>
         </div>
         <div class="printonly">
          <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11312619.html">
           <b>
            Studio-Apartment zu vermieten in Frankfurt
           </b>
          </a>
          <br/>
          <div>
           <b>
            815 € |
           </b>
          </div>
          <div>
           1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Heddernheim |
                
                Marie-Curie-Straße 20
          </div>
          <div style="margin-bottom:10px;">
           <b>
            Verfügbar:
                    01.10.2024
           </b>
          </div>
          <div style="margin-bottom:10px;">
           <i>
            Diese Anzeige ist erreichbar unter:
           </i>
           https://www.wg-gesucht.de/11312619.html
          </div>
          <div style="border-top: 2px solid #ddd; margin-bottom:10px">
          </div>
         </div>
        </div>
       </div>
       <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11127198">
        <div class="panel-body" style="padding: 0 15px;">
         <div class="row" style="display: flex; align-items: center;">
          <div class="col-xs-10">
           <h4 class="headline headline-list-view truncate_title">
            <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Oberrad.11127198.html">
             (Verfügbar 1-24 Monate) - Gemütliches Studio im Herzen Frankfurt-Sachsenhausen
            </a>
           </h4>
          </div>
          <div align="right" class="col-xs-2">
           <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11127198);" title="einblenden">
           </span>
          </div>
         </div>
        </div>
       </div>
       <div class="wgg_card offer_list_item" data-id="11127198" id="liste-details-ad-11127198">
        <div class="row">
         <div class="col-sm-4 card_image">
          <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Homelike" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Oberrad.11127198.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/29/7611a429477e8b05c71376b57c792a3cb1286daa3deb9ed30ebcd61d059a8cd5_homelike_05_2Fuploads_2Fe909346bede945fcfab892bc180b30f3c36c70beb6d0aea64ae449423bd92eb0.small.jpeg);">
          </a>
         </div>
         <div class="col-sm-8 card_body">
          <div class="row noprint">
           <div class="col-sm-12 flex_space_between">
            <h3 class="truncate_title noprint" title="(Verfügbar 1-24 Monate) - Gemütliches Studio im Herzen Frankfurt-Sachsenhausen">
             <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Homelike" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Oberrad.11127198.html">
              (Verfügbar 1-24 Monate) - Gemütliches Studio im Herzen Frankfurt-Sachsenhausen
             </a>
            </h3>
            <div class="asset_favourite cursor-pointer" data-ad_id="11127198" data-ad_type="0" data-favourite_status="0">
             <span aria-hidden="true" class="fav-button-11127198 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11127198">
             </span>
            </div>
           </div>
           <div class="col-xs-11">
            <span>
             1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Oberrad |
                        
                        Hainer Weg
            </span>
           </div>
          </div>
          <div class="row noprint middle">
           <div class="col-xs-3">
            <b>
             1050 €
            </b>
           </div>
           <div class="col-xs-5 text-center">
            11.10.2024
                    
                                            - 31.07.2025
           </div>
           <div class="col-xs-3 text-right">
            <b>
             29 m²
            </b>
           </div>
          </div>
          <div class="row noprint bottom">
           <div class="col-xs-2">
            <img alt="Homelike" class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2021/11/9262f94fb0245dd4cc5ec475691acf92f9354d8bc97b62a850944ec08671ff41_homelike2.sized.png" src="https://img.wg-gesucht.de/media/up/2021/11/9262f94fb0245dd4cc5ec475691acf92f9354d8bc97b62a850944ec08671ff41_homelike2.thumb.png"/>
           </div>
           <div class="col-xs-9">
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between">
              <span>
               <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
                Verifiziertes Unternehmen
                <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
                </span>
               </a>
              </span>
              <span>
              </span>
             </div>
            </div>
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
              <span class="ml5">
               Homelike Internet GmbH
              </span>
              <span style="color: #218700;">
               Online: 3 Tage
              </span>
             </div>
            </div>
           </div>
           <div class="col-xs-1 text-center p0">
            <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
            </span>
           </div>
          </div>
         </div>
         <div class="printonly">
          <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Oberrad.11127198.html">
           <b>
            (Verfügbar 1-24 Monate) - Gemütliches Studio im Herzen Frankfurt-Sachsenhausen
           </b>
          </a>
          <br/>
          <div>
           <b>
            1050 € |
           </b>
           <b>
            29 m²
           </b>
          </div>
          <div>
           1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Oberrad |
                
                Hainer Weg
          </div>
          <div style="margin-bottom:10px;">
           <b>
            Verfügbar:
                    11.10.2024
           </b>
          </div>
          <div style="margin-bottom:10px;">
           <i>
            Diese Anzeige ist erreichbar unter:
           </i>
           https://www.wg-gesucht.de/11127198.html
          </div>
          <div style="border-top: 2px solid #ddd; margin-bottom:10px">
          </div>
         </div>
        </div>
       </div>
       <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11144265">
        <div class="panel-body" style="padding: 0 15px;">
         <div class="row" style="display: flex; align-items: center;">
          <div class="col-xs-10">
           <h4 class="headline headline-list-view truncate_title">
            <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Niederrad.11144265.html">
             (Verfügbar 1-24 Monate) - Boardingapartment für 2 Personen - komplett möbliert und ausgestattet
            </a>
           </h4>
          </div>
          <div align="right" class="col-xs-2">
           <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11144265);" title="einblenden">
           </span>
          </div>
         </div>
        </div>
       </div>
       <div class="wgg_card offer_list_item" data-id="11144265" id="liste-details-ad-11144265">
        <div class="row">
         <div class="col-sm-4 card_image">
          <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Homelike" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Niederrad.11144265.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/29/5be46f817f8b0291ec9d4ed7d815ac71901e015e45d7abc5a3d2ba7ef8b756fe_homelike_05_2Fuploads_2Fe32f08d9d74b0af3f74fec0323b399a1bf74bf478aac5fd63a2d3c0b7422d376.small.jpeg);">
          </a>
         </div>
         <div class="col-sm-8 card_body">
          <div class="row noprint">
           <div class="col-sm-12 flex_space_between">
            <h3 class="truncate_title noprint" title="(Verfügbar 1-24 Monate) - Boardingapartment für 2 Personen - komplett möbliert und ausgestattet">
             <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Homelike" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Niederrad.11144265.html">
              (Verfügbar 1-24 Monate) - Boardingapartment für 2 Personen - komplett möbliert und ausgestattet
             </a>
            </h3>
            <div class="asset_favourite cursor-pointer" data-ad_id="11144265" data-ad_type="0" data-favourite_status="0">
             <span aria-hidden="true" class="fav-button-11144265 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11144265">
             </span>
            </div>
           </div>
           <div class="col-xs-11">
            <span>
             1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Niederrad |
                        
                        Triftstraße
            </span>
           </div>
          </div>
          <div class="row noprint middle">
           <div class="col-xs-3">
            <b>
             1470 €
            </b>
           </div>
           <div class="col-xs-5 text-center">
            01.11.2024
                    
                                            - 31.07.2025
           </div>
           <div class="col-xs-3 text-right">
            <b>
             33 m²
            </b>
           </div>
          </div>
          <div class="row noprint bottom">
           <div class="col-xs-2">
            <img alt="Homelike" class="cursor-pointer avatar" data-featherlight="https://img.wg-gesucht.de/media/up/2021/11/9262f94fb0245dd4cc5ec475691acf92f9354d8bc97b62a850944ec08671ff41_homelike2.sized.png" src="https://img.wg-gesucht.de/media/up/2021/11/9262f94fb0245dd4cc5ec475691acf92f9354d8bc97b62a850944ec08671ff41_homelike2.thumb.png"/>
           </div>
           <div class="col-xs-9">
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between">
              <span>
               <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
                Verifiziertes Unternehmen
                <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
                </span>
               </a>
              </span>
              <span>
              </span>
             </div>
            </div>
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
              <span class="ml5">
               Homelike Internet GmbH
              </span>
              <span style="color: #898989;">
               Online: 12.09.2024
              </span>
             </div>
            </div>
           </div>
           <div class="col-xs-1 text-center p0">
            <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
            </span>
           </div>
          </div>
         </div>
         <div class="printonly">
          <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Niederrad.11144265.html">
           <b>
            (Verfügbar 1-24 Monate) - Boardingapartment für 2 Personen - komplett möbliert und ausgestattet
           </b>
          </a>
          <br/>
          <div>
           <b>
            1470 € |
           </b>
           <b>
            33 m²
           </b>
          </div>
          <div>
           1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Niederrad |
                
                Triftstraße
          </div>
          <div style="margin-bottom:10px;">
           <b>
            Verfügbar:
                    01.11.2024
           </b>
          </div>
          <div style="margin-bottom:10px;">
           <i>
            Diese Anzeige ist erreichbar unter:
           </i>
           https://www.wg-gesucht.de/11144265.html
          </div>
          <div style="border-top: 2px solid #ddd; margin-bottom:10px">
          </div>
         </div>
        </div>
       </div>
       <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11297375">
        <div class="panel-body" style="padding: 0 15px;">
         <div class="row" style="display: flex; align-items: center;">
          <div class="col-xs-10">
           <h4 class="headline headline-list-view truncate_title">
            <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11297375.html">
             Penthouse-Studio-Wohnung in Frankfurt zu vermieten
            </a>
           </h4>
          </div>
          <div align="right" class="col-xs-2">
           <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11297375);" title="einblenden">
           </span>
          </div>
         </div>
        </div>
       </div>
       <div class="wgg_card offer_list_item" data-id="11297375" id="liste-details-ad-11297375">
        <div class="row">
         <div class="col-sm-4 card_image">
          <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Spotahome, S.L.U" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11297375.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/35/05e4761e7ba1e712fc076221079ab978c68f1aea1adb440951d772e58a74338d_889b6a1026d14ca7f6682566a41d4ad66b0a66dffcbc7f2ff5f4962c.small.jpg);">
          </a>
         </div>
         <div class="col-sm-8 card_body">
          <div class="row noprint">
           <div class="col-sm-12 flex_space_between">
            <h3 class="truncate_title noprint" title="Penthouse-Studio-Wohnung in Frankfurt zu vermieten">
             <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Spotahome, S.L.U" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11297375.html">
              Penthouse-Studio-Wohnung in Frankfurt zu vermieten
             </a>
            </h3>
            <div class="asset_favourite cursor-pointer" data-ad_id="11297375" data-ad_type="0" data-favourite_status="0">
             <span aria-hidden="true" class="fav-button-11297375 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11297375">
             </span>
            </div>
           </div>
           <div class="col-xs-11">
            <span>
             1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Heddernheim |
                        
                        Marie-Curie-Straße 20
            </span>
           </div>
          </div>
          <div class="row noprint middle">
           <div class="col-xs-3">
            <b>
             952 €
            </b>
           </div>
           <div class="col-xs-5 text-center">
            01.10.2024
           </div>
           <div class="col-xs-3 text-right">
            <b>
             23 m²
            </b>
           </div>
          </div>
          <div class="row noprint bottom">
           <div class="col-xs-2">
            <img class="avatar" src="/img/placeholder/no_profile_image_company.svg"/>
           </div>
           <div class="col-xs-9">
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between">
              <span>
               <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
                Verifiziertes Unternehmen
                <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
                </span>
               </a>
              </span>
              <span>
              </span>
             </div>
            </div>
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
              <span class="ml5">
               Spotahome
              </span>
              <span style="color: #218700;">
               Online: 2 Stunden
              </span>
             </div>
            </div>
           </div>
           <div class="col-xs-1 text-center p0">
            <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
            </span>
           </div>
          </div>
         </div>
         <div class="printonly">
          <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11297375.html">
           <b>
            Penthouse-Studio-Wohnung in Frankfurt zu vermieten
           </b>
          </a>
          <br/>
          <div>
           <b>
            952 € |
           </b>
           <b>
            23 m²
           </b>
          </div>
          <div>
           1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Heddernheim |
                
                Marie-Curie-Straße 20
          </div>
          <div style="margin-bottom:10px;">
           <b>
            Verfügbar:
                    01.10.2024
           </b>
          </div>
          <div style="margin-bottom:10px;">
           <i>
            Diese Anzeige ist erreichbar unter:
           </i>
           https://www.wg-gesucht.de/11297375.html
          </div>
          <div style="border-top: 2px solid #ddd; margin-bottom:10px">
          </div>
         </div>
        </div>
       </div>
       <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11289752">
        <div class="panel-body" style="padding: 0 15px;">
         <div class="row" style="display: flex; align-items: center;">
          <div class="col-xs-10">
           <h4 class="headline headline-list-view truncate_title">
            <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Dornbusch.11289752.html">
             Studio in Frankfurt am Main
            </a>
           </h4>
          </div>
          <div align="right" class="col-xs-2">
           <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11289752);" title="einblenden">
           </span>
          </div>
         </div>
        </div>
       </div>
       <div class="wgg_card offer_list_item" data-id="11289752" id="liste-details-ad-11289752">
        <div class="row">
         <div class="col-sm-4 card_image">
          <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Spotahome, S.L.U" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Dornbusch.11289752.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/35/8b084e8128530d760106362872923018eec1244317d60a31754360c17a8df742_6f5bbb1b8cecd0e879795477c7f243782838ca2379de582f71e5a694.small.jpg);">
          </a>
         </div>
         <div class="col-sm-8 card_body">
          <div class="row noprint">
           <div class="col-sm-12 flex_space_between">
            <h3 class="truncate_title noprint" title="Studio in Frankfurt am Main">
             <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Spotahome, S.L.U" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Dornbusch.11289752.html">
              Studio in Frankfurt am Main
             </a>
            </h3>
            <div class="asset_favourite cursor-pointer" data-ad_id="11289752" data-ad_type="0" data-favourite_status="0">
             <span aria-hidden="true" class="fav-button-11289752 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11289752">
             </span>
            </div>
           </div>
           <div class="col-xs-11">
            <span>
             1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Dornbusch |
                        
                        Leerbachstraße 101
            </span>
           </div>
          </div>
          <div class="row noprint middle">
           <div class="col-xs-3">
            <b>
             1300 €
            </b>
           </div>
           <div class="col-xs-5 text-center">
            01.10.2024
           </div>
           <div class="col-xs-3 text-right">
            <b>
             25 m²
            </b>
           </div>
          </div>
          <div class="row noprint bottom">
           <div class="col-xs-2">
            <img class="avatar" src="/img/placeholder/no_profile_image_company.svg"/>
           </div>
           <div class="col-xs-9">
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between">
              <span>
               <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
                Verifiziertes Unternehmen
                <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
                </span>
               </a>
              </span>
              <span>
              </span>
             </div>
            </div>
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
              <span class="ml5">
               Spotahome
              </span>
              <span style="color: #218700;">
               Online: 1 Stunde
              </span>
             </div>
            </div>
           </div>
           <div class="col-xs-1 text-center p0">
            <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
            </span>
           </div>
          </div>
         </div>
         <div class="printonly">
          <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Dornbusch.11289752.html">
           <b>
            Studio in Frankfurt am Main
           </b>
          </a>
          <br/>
          <div>
           <b>
            1300 € |
           </b>
           <b>
            25 m²
           </b>
          </div>
          <div>
           1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Dornbusch |
                
                Leerbachstraße 101
          </div>
          <div style="margin-bottom:10px;">
           <b>
            Verfügbar:
                    01.10.2024
           </b>
          </div>
          <div style="margin-bottom:10px;">
           <i>
            Diese Anzeige ist erreichbar unter:
           </i>
           https://www.wg-gesucht.de/11289752.html
          </div>
          <div style="border-top: 2px solid #ddd; margin-bottom:10px">
          </div>
         </div>
        </div>
       </div>
       <div class="panel panel-default panel-hidden display-none list-details-ad-border noprint" id="liste-details-ad-hidden-11010005">
        <div class="panel-body" style="padding: 0 15px;">
         <div class="row" style="display: flex; align-items: center;">
          <div class="col-xs-10">
           <h4 class="headline headline-list-view truncate_title">
            <a class="detailansicht" href="1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11010005.html">
             Studio-Apartment zu vermieten in Frankfurt
            </a>
           </h4>
          </div>
          <div align="right" class="col-xs-2">
           <span class="mdi mdi-eye mdi-18px mdi-dark cursor-pointer" onclick="show_hide_ad('show', 11010005);" title="einblenden">
           </span>
          </div>
         </div>
        </div>
       </div>
       <div class="wgg_card offer_list_item" data-id="11010005" id="liste-details-ad-11010005">
        <div class="row">
         <div class="col-sm-4 card_image">
          <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Spotahome, S.L.U" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11010005.html" style="background-image: url(https://img.wg-gesucht.de/media/up/2024/20/bca2f1c7ccbeb958931e4b289b9d37798e629518c6d875f6ad1b18fb34e8f016_3edbe1a2589b81379fd859eb246b66fe952cabfc2d73a568aea532e9.small.jpg);">
          </a>
         </div>
         <div class="col-sm-8 card_body">
          <div class="row noprint">
           <div class="col-sm-12 flex_space_between">
            <h3 class="truncate_title noprint" title="Studio-Apartment zu vermieten in Frankfurt">
             <a class="campaign_click" data-campaign_click_position="1" data-campaign_click_source="list_view_detail" data-campaign_partner="Spotahome, S.L.U" data-campaign_type="premium_ads" data-category="1-Zimmer-Wohnungen" data-city_id="41" data-city_name="Frankfurt am Main" data-rent-type="All rent types" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11010005.html">
              Studio-Apartment zu vermieten in Frankfurt
             </a>
            </h3>
            <div class="asset_favourite cursor-pointer" data-ad_id="11010005" data-ad_type="0" data-favourite_status="0">
             <span aria-hidden="true" class="fav-button-11010005 mdi mdi-heart-outline icon-fav-empty" id="to-fav-11010005">
             </span>
            </div>
           </div>
           <div class="col-xs-11">
            <span>
             1-Zimmer-Wohnung 
                         |

                                                                                    Frankfurt am Main
                            
                            Heddernheim |
                        
                        Marie-Curie-Straße 20
            </span>
           </div>
          </div>
          <div class="row noprint middle">
           <div class="col-xs-3">
            <b>
             729 €
            </b>
           </div>
           <div class="col-xs-5 text-center">
            01.10.2025
           </div>
           <div class="col-xs-3 text-right">
            <b>
             16 m²
            </b>
           </div>
          </div>
          <div class="row noprint bottom">
           <div class="col-xs-2">
            <img class="avatar" src="/img/placeholder/no_profile_image_company.svg"/>
           </div>
           <div class="col-xs-9">
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between">
              <span>
               <a class="campaign_click label_verified ml5" data-campaign_click_position="verified label" data-campaign_click_source="list view" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" href="/fuer-immobilienprofis.html">
                Verifiziertes Unternehmen
                <span class="mdi mdi-16px mdi-vm mdi-fw mdi-lh mdi-check-circle-outline">
                </span>
               </a>
              </span>
              <span>
              </span>
             </div>
            </div>
            <div class="row noprint">
             <div class="col-sm-12 flex_space_between" style="min-height: 18px;">
              <span class="ml5">
               Spotahome
              </span>
              <span style="color: #218700;">
               Online: 2 Stunden
              </span>
             </div>
            </div>
           </div>
           <div class="col-xs-1 text-center p0">
            <span class="mdi mdi-20px mdi-lh mdi-top2 mdi-close cursor-pointer" onclick='fireLoginOrRegisterModalRequest("sign_in");' title="ausblenden">
            </span>
           </div>
          </div>
         </div>
         <div class="printonly">
          <a class="detailansicht" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main-Heddernheim.11010005.html">
           <b>
            Studio-Apartment zu vermieten in Frankfurt
           </b>
          </a>
          <br/>
          <div>
           <b>
            729 € |
           </b>
           <b>
            16 m²
           </b>
          </div>
          <div>
           1-Zimmer-Wohnung 
                 |

                                                            Frankfurt am Main
                    
                    Heddernheim |
                
                Marie-Curie-Straße 20
          </div>
          <div style="margin-bottom:10px;">
           <b>
            Verfügbar:
                    01.10.2025
           </b>
          </div>
          <div style="margin-bottom:10px;">
           <i>
            Diese Anzeige ist erreichbar unter:
           </i>
           https://www.wg-gesucht.de/11010005.html
          </div>
          <div style="border-top: 2px solid #ddd; margin-bottom:10px">
          </div>
         </div>
        </div>
       </div>
      </div>
      <div class="row noprint">
       <div class="col-xs-9 col-sm-12 col-md-9">
        <div class="p0" id="assets_list_pagination">
        </div>
       </div>
       <div class="hidden-xs col-sm-9 hidden-md hidden-lg">
        <a class="btn btn-md wgg_orange position-relative pull-left" href="https://www.wg-gesucht.de/mein-wg-gesucht-filter.html?f-add=0">
         <span aria-hidden="true" class="mdi mdi-alarm">
         </span>
         Neue Angebote per E-Mail
        </a>
       </div>
       <div class="col-xs-3">
        <a class="pull-right btn-iconbtn" href="#" onclick="window.print();return false;" title="Liste drucken" type="button">
         <span class="mdi mdi-printer mdi-18px mdi-lh">
         </span>
        </a>
       </div>
      </div>
      <div class="noprint" style="margin-bottom:8px;">
       <br/>
       <div class="noprint">
        <h3 class="headline headline-default">
         Zimmer  in Frankfurt am Main / 1-Zimmer-Wohnungen in Frankfurt am Main / Zimmer  Frankfurt am Main
        </h3>
        <div class="row">
         <div class="col-xs-12">
          <a href="https://www.wg-gesucht.de/angebot-aufgeben.html">
           Jetzt kostenlos Zimmer  inserieren in Frankfurt am Main!
          </a>
          <br/>
          Sie suchen ein Zimmer  in Frankfurt am Main oder eine 1-Zimmer-Wohnung in Frankfurt am Main? Dann sind Sie hier genau richtig.                                     Klicken Sie auf ein Angebot und Sie erhalten genauere Informationen über die 1-Zimmer-Wohnung in Frankfurt am Main.                                Um Ihre Chancen bei der Zimmer oder Wohnungssuche zu erhöhen, geben Sie einfach ein kostenloses Zimmer-Gesuch unter "
          <a href="https://www.wg-gesucht.de/gesuch-aufgeben.html">
           Gesuch aufgeben
          </a>
          " auf.  Dazu wählen Sie als Stadt "Frankfurt am Main", als Rubrik "1-Zimmer-Wohnung" und anschließend die Mietart aus. Viel Erfolg bei der Zimmer oder Wohnungssuche wünscht Ihnen
          <b>
           WG-Gesucht.de
          </b>
          !
          <br/>
          <br/>
          Sie haben eine 1-Zimmer-Wohnung in Frankfurt am Main zu vergeben und suchen einen netten Mieter? Dann können Sie hier
          <a href="https://www.wg-gesucht.de/angebot-aufgeben.html">
           kostenlos eine 1 Zimmer Wohnung inserieren
          </a>
          .
         </div>
        </div>
       </div>
      </div>
      <span class="shadow noprint hidden position-absolute" id="infobox_tausch" style="background:#FFFFFF; border:1px solid #009900; width:280px; padding: 0; z-index:2;">
       <div style="background:#009900; padding:3px; color:#FFFFFF;">
        <b>
         Hinweis
        </b>
       </div>
       <br/>
       <div style="padding:3px;">
        Wenn Sie keine Tauschangebote angezeigt bekommen möchten, nutzen Sie bitte den entsprechenden Filter. Klicken Sie rechts in der Schnellsuche bei "Tauschangebot" auf "Nein".
        <br/>
        <br/>
        <strong>
         Ihr
         <br/>
         WG-Gesucht | Team
        </strong>
        <br/>
       </div>
      </span>
      <script src="/js/ang_ges_list_views.min.tjb1632386809.js">
      </script>
      <script>
       $(function() {
        $('.city_radial_search').removeClass('.city_radial_search_selected');
        $('.city_radial_search[data-kilometer=' + 10 + ']').addClass('city_radial_search_selected');

        $("#radial_search").insertBefore($(".panel-deactivated").first());

        if (0 == '1') {
            scrollToElementTop('radial_search');
        }

        $('#navToggleFilter').on('click', function() {
            $(this).hide();
            $('#filterBox').toggleClass("hidden-xs visible-xs-block");
            window.scrollTo(0, 0);
        });

        // when the user scrolls past the apply filter panel hide it and show 'filter' button
        $(document).on('scroll', function() {
            if ($('#filterBox').hasClass('visible-xs-block')) {
                var height = $('#filterBox').height();
                var scroll = $(this).scrollTop();
                if (scroll > height) {
                    $('#filterBox').toggleClass("hidden-xs visible-xs-block");
                    $('#navToggleFilter').show();
                    window.scrollTo(0,0);
                }
            }
        });

        // Add a history state with a hash on the clicked ad, so that clicking on the browser / device back button returns it on the url
        $('.offer_list_item').on('click', function(e) {
            // list item redirects should not mess with browser history (eg exclusive list)
            if (typeof $(this).data('url') !== 'undefined') {
                return;
            }

            var clicked_offer_id = $(this).data('id');
            // Hackfix for Firefox: Set the hash right below, because once a hash is initialized,
            // the following code related to "back to the ad" (scrolling / show advertisement below) works just fine
            location.hash = '#random';
            // Splitting the url so the hashes don't stack
            window.history.replaceState(null, null, window.location.href.split('#')[0] + "#back_to_ad_" + clicked_offer_id);

            var url = $(this).data('url');
            if (url && $(e.target).attr('id') !== 'to-fav-' + clicked_offer_id) {
                location.href = url;
            }
        });

        // This is used to move to the hash location when coming back from an ad using the browser / device back button
        if (window.location.href.indexOf('#back_to_ad') !== -1) {
            window.history.scrollRestoration = "manual";

            // If the hash #back_to_ad_ is ever changed, the substring's value below should also be updated so that the ad id is taken through it correctly
            hash_ad_id = location.hash.substring(12);

            // Disable back to ad for now
            // $('.airbnb_ad').first().insertAfter('[data-id=' + hash_ad_id + ']');

            hash_string = '#' + window.location.href.split('#')[1];
            goToHash();

            // Safari needs a timeout for this to work
            var is_safari = /^((?!chrome|android).)*safari/i.test(navigator.userAgent);
            if (is_safari != false) {
                setTimeout(goToHash, 500);
            }

            // Remove the hash from url and replace the current url at hisotry
            window.history.pushState(null, null, window.location.href.split('#')[0]);
        }

        // Passes filters into the user's filters
        base_create_email_alert_url = $(".create_new_email_alert").attr("href");

        $(".create_new_email_alert").attr("href", base_create_email_alert_url + convertFiltersToQueryParameters('offer_filter_form'));

        $('#offer_filter_form input, #offer_filter_form select').on('change', function() {
            $(".create_new_email_alert").attr("href", base_create_email_alert_url + convertFiltersToQueryParameters('offer_filter_form'));
        });
    });


    /**
     * Scrolls page to hash location. The hash string needs to be emptied first for the 'jump' to work.
     */
    function goToHash() {
        location.hash = '';
        location.hash = hash_string;
    }
      </script>
      <div class="noprint">
       <hr/>
       <small>
        * Partner-Anzeige - Weitere Informationen und Angebote auf der Seite des Anbieters
       </small>
      </div>
      <link href="/assets/css/SimplePagination/SimplePagination.min.css" rel="stylesheet" type="text/css"/>
      <script src="/js/external_libraries/pagination/simplePagination.min.js">
      </script>
      <script src="/js/Asset/FilteredAssetsList.class.tjb1649676772.js">
      </script>
      <script>
       $(function() {
        if (!window.filteredAssetsList) {
            window.filteredAssetsList = FilteredAssetsList({
                current_page_number    : '1',
                total_assets           : '12645',
                pro_user_exclusive_list: '',
                min_log_level          : '5'
            });
        }
    });
      </script>
     </div>
     <div class="col-xs-12 col-md-4 col-md-pull-8 noprint" id="rhs_column">
      <div class="panel panel-rhs-default noprint">
       <div class="panel-heading">
        <h4 class="panel-title">
         Meine Favoriten
         <span aria-hidden="true" class="pull-right mdi mdi-26px mdi-lh mdi-vm mdi-chevron-down">
         </span>
         <span aria-hidden="true" class="pull-right hidden mdi mdi-26px mdi-lh mdi-vm mdi-chevron-up">
         </span>
         <span class="sr-only">
          Einblenden
         </span>
        </h4>
       </div>
       <div class="panel-body">
        <div class="row mb10">
         <div class="col-xs-12" id="favourites_box">
          <a class="rhs_box_link" href="/favoriten.html?act=liste&amp;type=0">
           Anzeigen auf Liste
          </a>
          <a href="/favoriten.html?act=liste">
           <span class="badge wgg_badge-number" id="favourites_counter">
            0
           </span>
          </a>
          <span class="display-none position-relative pull-right" id="favourites_box_success" style="color:green; bottom: 3px;">
           gespeichert
          </span>
         </div>
        </div>
        <div class="row">
         <div class="col-xs-12 text-right">
          <a class="btn btn-sm wgg_gray" href="#" id="delete_favourites">
           Leeren
          </a>
          <a class="btn btn-sm wgg_gray" id="save_favourites">
           Speichern
          </a>
         </div>
        </div>
       </div>
       <input class="csrf_token" name="csrf_token" type="hidden" value=""/>
      </div>
      <script>
       $(function() {
        $('#save_favourites').on('click', function(e) {
            if (!logged_in) {
                fireLoginOrRegisterModalRequest('sign_in');
                return;
            }

            favourites.saveFavourites();
        });

        $('#delete_favourites').on('click', function(e) {
            if (!logged_in) {
                FavouritesManipulation.deleteFavouritesFromDom();
                favourites.clearFavouritesCookies();
                return;
            }

            favourites.deleteAllFavourites();
        });
    });
      </script>
      <div class="panel panel-rhs-default hidden-xs hidden-sm">
       <div class="panel-heading">
        <h4 class="panel-title">
         Suchauftrag einrichten
         <span aria-hidden="true" class="pull-right mdi mdi-26px mdi-lh mdi-vm mdi-chevron-down">
         </span>
         <span aria-hidden="true" class="pull-right hidden mdi mdi-26px mdi-lh mdi-vm mdi-chevron-up">
         </span>
         <span class="sr-only">
          Einblenden
         </span>
        </h4>
       </div>
       <div class="panel-body">
        Erhalten Sie passende Angebote zu Ihrer Suche in Frankfurt am Main bequem per E-Mail.
        <div class="text-right mt10">
         <a class="btn btn-md btn-icon wgg_orange create_new_email_alert" href="https://www.wg-gesucht.de/mein-wg-gesucht-filter.html?f-add=0">
          <span aria-hidden="true" class="mdi mdi-alarm">
          </span>
          Neue Angebote per E-Mail
         </a>
        </div>
       </div>
      </div>
      <div class="panel panel-rhs-default">
       <div class="panel-heading">
        <h4 class="panel-title">
         Anzeigensuche
         <span aria-hidden="true" class="pull-right mdi mdi-26px mdi-lh mdi-vm mdi-chevron-down">
         </span>
         <span aria-hidden="true" class="pull-right hidden mdi mdi-26px mdi-lh mdi-vm mdi-chevron-up">
         </span>
         <span class="sr-only">
          Einblenden
         </span>
        </h4>
       </div>
       <div class="panel-body position-relative" id="search_asset_form">
        <div class="display-block form-inline">
         <input class="form-control wgg_input" id="searched_asset_id" maxlength="9" name="searched_asset_id" placeholder="Anzeigennummer eingeben" size="25" type="tel"/>
         <input class="btn btn-sm wgg_gray FR mt-xs-5" disabled="" id="ad_search_submit" type="button" value="Suchen"/>
        </div>
        <div class="hidden" id="ad_search_error">
         <p class="text-danger mt5">
          Es wurde keine Anzeige mit der Nummer "
          <span id="ad_search_error_id">
          </span>
          " gefunden.
          <br/>
          Bitte überprüfen Sie Ihre Eingabe.
         </p>
        </div>
       </div>
      </div>
      <script src="/js/Asset/SearchAsset.class.tjb1632386809.js">
      </script>
      <script>
       $(function() {
        if(!window.searchAsset){
            window.searchAsset = SearchAsset({
                min_log_level: '5'
            });
        }
    });
      </script>
      <div style="width: 300px; margin: 10px auto;">
       <!-- /1009105/d_MR_AG_liste_LHS1 -->
       <div id="div-gpt-ad-1579038499204-0" style="width: 300px; height: 250px;">
        <script>
         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1579038499204-0'); });
        </script>
       </div>
      </div>
      <div class="panel panel-rhs-default">
       <div class="panel-heading">
        <h4 class="panel-title">
         Meine Filter
         <span aria-hidden="true" class="pull-right mdi mdi-26px mdi-lh mdi-vm mdi-chevron-down">
         </span>
         <span aria-hidden="true" class="display-none pull-right mdi mdi-26px mdi-lh mdi-vm mdi-chevron-up">
         </span>
         <span class="sr-only">
          Einblenden
         </span>
        </h4>
       </div>
       <div class="panel-body">
        <div class="pull-right">
         <span class="rhs_box_link" onclick='fireLoginOrRegisterModalRequest("sign_in", "/mein-wg-gesucht-filter.html");'>
          erstellen/ändern
         </span>
        </div>
        <div style="padding-top: 10px">
         <div style="padding-top: 15px;">
          Bitte
          <span class="rhs_box_link" onclick='fireLoginOrRegisterModalRequest("sign_in");'>
           loggen
          </span>
          Sie sich ein oder
          <span class="rhs_box_link" onclick='fireLoginOrRegisterModalRequest("sign_up");'>
           registrieren
          </span>
          Sie sich, um Ihre persönlichen Suchfilter zu nutzen.
         </div>
        </div>
       </div>
      </div>
      <div class="panel panel-rhs-default">
       <div class="panel-heading">
        <h4 class="panel-title">
         Bundesländer
         <span aria-hidden="true" class="pull-right mdi mdi-26px mdi-lh mdi-vm mdi-chevron-down">
         </span>
         <span aria-hidden="true" class="pull-right hidden mdi mdi-26px mdi-lh mdi-vm mdi-chevron-up">
         </span>
         <span class="sr-only">
          Einblenden
         </span>
        </h4>
       </div>
       <div class="panel-body">
        <ul class="ul-quickfilter">
         <li>
          <a href="/staedte-in-baden-wuerttemberg.4.html">
           Baden-Württemberg
          </a>
         </li>
         <li>
          <a href="/staedte-in-bayern.3.html">
           Bayern
          </a>
         </li>
         <li>
          <a href="/staedte-in-berlin.5.html">
           Berlin
          </a>
         </li>
         <li>
          <a href="/staedte-in-brandenburg.6.html">
           Brandenburg
          </a>
         </li>
         <li>
          <a href="/staedte-in-bremen.8.html">
           Bremen
          </a>
         </li>
         <li>
          <a href="/staedte-in-hamburg.15.html">
           Hamburg
          </a>
         </li>
         <li>
          <a href="/staedte-in-hessen.10.html">
           Hessen
          </a>
         </li>
         <li>
          <a href="/staedte-in-mecklenburg-vorpommern.14.html">
           Mecklenburg-Vorpommern
          </a>
         </li>
         <li>
          <a href="/staedte-in-niedersachsen.7.html">
           Niedersachsen
          </a>
         </li>
         <li>
          <a href="/staedte-in-nordrhein-westfalen.2.html">
           Nordrhein-Westfalen
          </a>
         </li>
         <li>
          <a href="/staedte-in-rheinland-pfalz.16.html">
           Rheinland-Pfalz
          </a>
         </li>
         <li>
          <a href="/staedte-in-saarland.17.html">
           Saarland
          </a>
         </li>
         <li>
          <a href="/staedte-in-sachsen.9.html">
           Sachsen
          </a>
         </li>
         <li>
          <a href="/staedte-in-sachsen-anhalt.11.html">
           Sachsen-Anhalt
          </a>
         </li>
         <li>
          <a href="/staedte-in-schleswig-holstein.13.html">
           Schleswig-Holstein
          </a>
         </li>
         <li>
          <a href="/staedte-in-thueringen.12.html">
           Thüringen
          </a>
         </li>
        </ul>
       </div>
      </div>
      <div class="panel panel-rhs-default">
       <div class="panel-heading">
        <h4 class="panel-title">
         <div>
          Service dazubuchen
          <small class="position-relative" style="font-size:0.6em; bottom:5px;">
           1
          </small>
         </div>
         <span aria-hidden="true" class="pull-right mdi mdi-26px mdi-lh mdi-vm mdi-chevron-down">
         </span>
         <span aria-hidden="true" class="pull-right hidden mdi mdi-26px mdi-lh mdi-vm mdi-chevron-up">
         </span>
         <span class="sr-only">
          Einblenden
         </span>
        </h4>
       </div>
       <div class="panel-body">
        <a class="rhs_box_link" href="/moving_service.html?tracking_view=moving_service_long" rel="nofollow" target="_blank">
         Jetzt Umzugsfirma beauftragen
        </a>
       </div>
      </div>
      <div style="width: 300px; margin: 0 auto 10px auto;">
       <div id="div-gpt-ad-189159851654146248-4">
        <script type="text/javascript">
         googletag.cmd.push(function() { googletag.display('div-gpt-ad-189159851654146248-4'); });
        </script>
       </div>
       <script type="text/javascript">
        console.log('qm mr list loaded');
       </script>
      </div>
      <div class="noprint hidden-xs hidden-sm 41">
       <div class="panel panel-rhs-default">
        <div class="panel-heading">
         <h4 class="panel-title">
          Besuche die WG-Gesucht.de Facebook-Gruppe für Frankfurt
         </h4>
        </div>
        <div class="panel-body">
         <div class="row" style="margin-top: -15px;">
          <a href="https://www.facebook.com/wggesucht.frankfurt.main/" rel="nofollow" target="_blank">
           <img class="img-responsive" src="/img/fb_group_teaser/frankfurt.jpg"/>
          </a>
         </div>
         <br/>
         <a class="btn btn-fb pull-right" href="https://www.facebook.com/wggesucht.frankfurt.main/" rel="nofollow" target="_blank">
          <span class="mdi mdi-open-in-new mdi-vm">
          </span>
          Zimmer und Wohnungen in Frankfurt
         </a>
        </div>
       </div>
      </div>
     </div>
    </div>
   </div>
   <div class="noprint container" id="breadcrumb_wrapper" style="background: #fff;">
    <div class="row">
     <div class="col-xs-12">
      <ol class="breadcrumb noprint">
       <li>
        <a href="https://www.wg-gesucht.de/">
         Start
        </a>
       </li>
       <li>
        <a href="https://www.wg-gesucht.de/wohnraumangebote.html">
         Wohnungsmarkt Frankfurt am Main
        </a>
       </li>
      </ol>
     </div>
    </div>
   </div>
   <div class="noprint container mb20" id="bottom_links_wrapper">
    <div class="row">
     <div class="col-xs-12">
      <hr class="hr-divider mb40 hidden-xs"/>
     </div>
    </div>
    <div class="row">
     <div class="col-sm-3 hidden-xs">
      <ul class="ul-bottomlinks">
       <li>
        <h4>
         Wohnung
        </h4>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Berlin.8.2.1.0.html">
         2 Raum Wohnung Berlin
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Berlin.8.2.1.0.html">
         Wohnungen Berlin
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Bonn.13.2.1.0.html">
         Wohnungen Bonn
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Braunschweig.16.2.1.0.html">
         Wohnungen Braunschweig
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Bremen.17.2.1.0.html">
         Wohnungen Bremen
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Darmstadt.23.2.1.0.html">
         Wohnungen Darmstadt
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Dresden.27.2.1.0.html">
         Wohnungen Dresden
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Duesseldorf.30.2.1.0.html">
         Wohnungen Düsseldorf
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Frankfurt.41.2.1.0.html">
         Wohnungen Frankfurt
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Giessen.47.2.1.0.html">
         Wohnungen Giessen
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Goettingen.49.2.1.0.html">
         Wohnungen Göttingen
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Hamburg.55.2.1.0.html">
         Wohnungen Hamburg
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Hannover.57.2.1.0.html">
         Wohnungen Hannover
        </a>
       </li>
      </ul>
     </div>
     <div class="col-sm-3 hidden-xs">
      <ul class="ul-bottomlinks">
       <li>
        <h4>
         Bundesländer
        </h4>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-baden-wuerttemberg.4.html">
         Baden-Württemberg
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-bayern.3.html">
         Bayern
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-berlin.5.html">
         Berlin
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-brandenburg.6.html">
         Brandenburg
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-bremen.8.html">
         Bremen
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-hamburg.15.html">
         Hamburg
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-hessen.10.html">
         Hessen
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-mecklenburg-vorpommern.14.html">
         Mecklenburg-Vorpommern
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-niedersachsen.7.html">
         Niedersachsen
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-nordrhein-westfalen.2.html">
         Nordrhein-Westfalen
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-rheinland-pfalz.16.html">
         Rheinland-Pfalz
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-saarland.17.html">
         Saarland
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-sachsen.9.html">
         Sachsen
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-sachsen-anhalt.11.html">
         Sachsen-Anhalt
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-schleswig-holstein.13.html">
         Schleswig-Holstein
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/staedte-in-thueringen.12.html">
         Thüringen
        </a>
       </li>
      </ul>
     </div>
     <div class="col-sm-3 hidden-xs">
      <ul class="ul-bottomlinks">
       <li>
        <h4>
         Wohnungsmarkt
        </h4>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Dresden.27.2.1.0.html">
         2 Raum Wohnung Dresden
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Heidelberg.59.2.1.0.html">
         Wohnungen Heidelberg
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Jena.66.2.1.0.html">
         Wohnungen Jena
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Koeln.73.2.1.0.html">
         Wohnungen Köln
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Koeln-gesucht.73.2.1.4.html">
         Wohnung in Köln
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Leipzig.77.2.1.0.html">
         Wohnungen Leipzig
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Lueneburg.82.2.1.0.html">
         Wohnungen Lüneburg
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Mainz.84.2.1.0.html">
         Wohnungen Mainz
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Mannheim.85.2.1.0.html">
         Wohnungen Mannheim
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Muenchen.90.2.1.0.html">
         Wohnungen München
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Berlin.8.2.1.0.html">
         Wohnungen in Berlin
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Nuernberg.96.2.1.0.html">
         Wohnungen Nürnberg
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Tuebingen.127.2.1.0.html">
         Wohnungen Tübingen
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Stuttgart.124.2.1.0.html">
         Wohnungen Stuttgart
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungen-in-Leipzig.77.2.1.0.html">
         3 Raum Wohnung Leipzig
        </a>
       </li>
      </ul>
     </div>
     <div class="col-sm-3 hidden-xs">
      <ul class="ul-bottomlinks">
       <li>
        <h4>
         Weitere Länder
        </h4>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="/federal-states-in-Switzerland.ch.html?country_code=ch">
         Schweiz
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="/federal-states-in-Austria.at.html?country_code=at">
         Österreich
        </a>
       </li>
      </ul>
      <br/>
      <ul class="ul-bottomlinks">
       <li>
        <h4>
         Wohnungsübersicht
        </h4>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/">
         WG
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wg-zimmer-in-Berlin.8.0.1.0.html">
         WG Berlin
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wg-zimmer-in-Berlin.8.0.1.94.html">
         Berlin WG
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wg-zimmer-in-Berlin.8.0.1.95.html">
         Zimmer in Berlin
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wg-zimmer-in-Koeln.73.0.1.0.html">
         WG Köln
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/ic/immobilie-inserieren.html">
         Immobilie inserieren
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/mietwohnung.html">
         Mietwohnung
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/wohnungssuche.html">
         Wohnungssuche
        </a>
       </li>
       <li class="li-bottom-link">
        <a class="a-bottom-link" href="https://www.wg-gesucht.de/ic/wohnungsmarkt.html">
         Wohnungsmarkt
        </a>
       </li>
      </ul>
     </div>
    </div>
    <br/>
    <br/>
    <div class="text-center mb20 noprint" id="ros_bottom" style="width: 100%;">
     <div id="WGG_d_Bigsize_ROS_bottom" style="width:728px; height:90px; margin: 0; padding:0;">
     </div>
    </div>
    <script type="text/javascript">
     var OX_ads = OX_ads || [];
                        OX_ads.push({
                         slot_id: "WGG_d_Bigsize_ROS_bottom",
                         auid: "540890071"
                        });
    </script>
    <script src="//wg-gesucht-d.openx.net/w/1.0/jstag" type="text/javascript">
    </script>
   </div>
   <div class="noprint container" id="footer_wrapper">
    <div class="footer_links_section">
     <div class="row">
      <div class="col-xs-12 visible-xs-block">
       <div class="footer_image_wrapper">
        <img class="img-responsive footer_image" src="/img/icons/CO2-Seal-Icon.png"/>
       </div>
      </div>
      <div class="col-sm-8">
       <div class="row">
        <div class="col-xs-12">
         <div class="footer_link_group mb30">
          <a class="footer_link footer_strong_link" data-google-interstitial="false" href="/help-center.html">
           Hilfebereich
          </a>
          <span class="footer_link_pipe">
           |
          </span>
          <a class="footer_link footer_strong_link" data-google-interstitial="false" href="/impressum.html">
           Impressum
          </a>
          <span class="footer_link_pipe">
           |
          </span>
          <a class="footer_link footer_strong_link" data-google-interstitial="false" href="/agb.html">
           AGB
          </a>
          <span class="footer_link_pipe">
           |
          </span>
          <a class="footer_link footer_strong_link" href="/ic/online-werbung.html">
           Mediadaten
          </a>
          <span class="footer_link_pipe">
           |
          </span>
          <a class="footer_link footer_strong_link" href="/datenschutz.html">
           Datenschutzinformation
          </a>
          <span class="footer_link_pipe">
           |
          </span>
          <a class="footer_link footer_strong_link" href="/?cmpscreencustom">
           Cookie-Einstellungen
          </a>
         </div>
        </div>
        <div class="col-xs-12">
         <div class="footer_link_group">
          <a class="footer_link" href="/fuer-immobilienprofis.html" target="_blank">
           Professionelle und gewerbliche Nutzung
          </a>
          <span class="footer_link_pipe">
           |
          </span>
          <a class="footer_link" href="/artikel/pressespiegel">
           Pressespiegel
          </a>
          <span class="footer_link_pipe">
           |
          </span>
          <a class="footer_link" href="/passworterinnerung.html">
           Passwort vergessen?
          </a>
          <span class="footer_link_pipe">
           |
          </span>
          <a class="footer_link" href="/contact.html?section=suggestion">
           Feedback
          </a>
          <br class="hidden-xs"/>
          <span class="hidden-sm hidden-md hidden-lg footer_link_pipe">
           |
          </span>
          <a class="footer_link" href="/wohnraumangebote.html">
           Angebote lesen
          </a>
          <span class="footer_link_pipe">
           |
          </span>
          <a class="footer_link" href="/angebot-aufgeben.html">
           Angebot aufgeben
          </a>
          <span class="footer_link_pipe">
           |
          </span>
          <a class="footer_link" href="/wohnraumgesuche.html">
           Gesuche lesen
          </a>
          <span class="footer_link_pipe">
           |
          </span>
          <a class="footer_link" href="/gesuch-aufgeben.html">
           Gesuch aufgeben
          </a>
         </div>
        </div>
       </div>
      </div>
      <div class="col-sm-4 hidden-xs">
       <div class="footer_image_wrapper">
        <img class="img-responsive footer_image" src="/img/icons/CO2-Seal-Icon.png"/>
       </div>
      </div>
     </div>
    </div>
    <div class="footer_icons_section">
     <div class="row">
      <div class="col-md-4 col-sm-5">
       <div class="footer_icons_group">
        <b class="mr20">
         Folge uns
        </b>
        <a href="https://www.instagram.com/wggesuchtde/" target="_blank">
         <img class="footer_social_icon" src="/img/icons/icon-instagram.png"/>
        </a>
        <a href="https://www.facebook.com/wggesucht.de/" target="_blank">
         <img class="footer_social_icon" src="/img/icons/icon-facebook.png"/>
        </a>
        <a href="https://www.youtube.com/wggesuchtdefindyourhome/" target="_blank">
         <img class="footer_social_icon" src="/img/icons/icon-youtube.png"/>
        </a>
        <a href="https://www.pinterest.com/wggesuchtde/" target="_blank">
         <img class="footer_social_icon" src="/img/icons/icon-pinterest.png"/>
        </a>
       </div>
      </div>
      <div class="col-md-4 col-sm-5">
       <div class="footer_icons_group">
        <a href="https://itunes.apple.com/de/app/wg-gesucht-de-find-your-home/id1084293678?mt=8" target="_blank">
         <img class="footer_store_icon" src="/img/icons/icon-ios.png"/>
        </a>
        <a href="https://play.google.com/store/apps/details?id=com.wggesucht.android&amp;hl=de" target="_blank">
         <img class="footer_store_icon" src="/img/icons/icon-android.png"/>
        </a>
       </div>
      </div>
      <div class="col-md-4 col-sm-2">
       <div class="footer_language_selection language_wrapper mt5">
        <span class="mdi mdi-web mdi-lh footer_language_icon">
        </span>
        <div class="dropup noprint display-inline">
         <span aria-expanded="true" class="text-uppercase cursor-pointer dropdown-toggle footer_selected_language" data-toggle="dropdown">
          de
          <span class="caret" style="margin-bottom: 3px;">
          </span>
         </span>
         <ul class="dropdown-menu" role="menu">
          <li role="presentation">
           <a class="language_flag footer_selected_language_option" href="/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html" onclick="deleteCookie('site_language');" role="menuitem">
            Deutsch
           </a>
          </li>
          <li role="presentation">
           <a class="language_flag" href="/en/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html" onclick="setCookie('site_language', 'en', 3650, '/');" role="menuitem">
            English
           </a>
          </li>
          <li role="presentation">
           <a class="language_flag" href="/es/1-zimmer-wohnungen-in-Frankfurt-am-Main.41.1.1.0.html" onclick="setCookie('site_language', 'es', 3650, '/');" role="menuitem">
            Español
           </a>
          </li>
         </ul>
        </div>
       </div>
      </div>
     </div>
    </div>
   </div>
  </div>
  <script>
   (function($){$.fn.unveil=function(threshold,callback){var $w=$(window),th=threshold||0,retina=window.devicePixelRatio>1,attrib=retina?"data-src-retina":"data-src",images=this,loaded;this.one("unveil",function(){var source=this.getAttribute(attrib);source=source||this.getAttribute("data-src");if(source){this.setAttribute("src",source);if(typeof callback==="function")callback.call(this)}});function unveil(){var inview=images.filter(function(){var $e=$(this);if($e.is(":hidden"))return;var wt=$w.scrollTop(),
                wb=wt+$w.height(),et=$e.offset().top,eb=et+$e.height();return eb>=wt-th&&et<=wb+th});loaded=inview.trigger("unveil");images=images.not(loaded)}$w.on("scroll.unveil resize.unveil lookup.unveil",unveil);unveil();return this}})(window.jQuery||window.Zepto);
            
            $(function() {
                $("img").unveil(200);
            });
  </script>
  <script>
   // Hide/Show RHS box content in mobile mode
        var rhs_mobile_mode = false;
        $('.panel-rhs-default .panel-heading').on('click', function(){
            if ($(this).nextAll('.panel-body').css("display") == "none") {
                rhs_mobile_mode = true;
            }

            if (rhs_mobile_mode == true) {
                $(this).toggleClass('panel-heading-bottom-border');
                $(this).find('h4 .mdi-chevron-down, h4 .mdi-chevron-up').toggle().removeClass("hidden");
                $(this).nextAll('.panel-body').slideToggle();
            }
        });
  </script>
  <script>
   $(function () {
                if ($(window).height() < 520) {
                    $('#cmpbox').css('overflow-y', 'scroll');
                }
            });
  </script>
  <script src="/js/external_libraries/emailCrypt.min.js">
  </script>
  <script>
   window.onbeforeunload = null;
  </script>
  <div class="ajax_loader_gif display-none">
   <img alt="" class="loaderLogo sk-rotating-plane" src="/img/icons/loading.png"/>
  </div>
  <div aria-labelledby="server_error_modal_label" class="modal fade noprint" id="server_error_modal" role="dialog" style="z-index: 1234567860;" tabindex="-1">
   <div class="position-relative modal-dialog modal-sm" role="document">
    <div class="position-relative modal-content" style="top: 100px;">
     <div class="modal-header">
      <button aria-label="Schließen" class="close visible-xs-block visible-sm-block" data-dismiss="modal" type="button">
       <span aria-hidden="true">
        ×
       </span>
      </button>
      <h4 class="modal-title text-info text-uppercase" id="server_error_modal_label">
       Entschuldigung, das hätte nicht passieren dürfen.
      </h4>
     </div>
     <div class="modal-body row" id="server_error_modal_error_body" style="margin: 0;">
      Dieser Dienst ist vorübergehend nicht verfügbar. Wir arbeiten an einer Lösung, bitte versuchen Sie es später erneut.
      <br/>
      <br/>
      Vielen Dank für Ihre Geduld.
     </div>
     <div class="modal-footer">
      <button class="btn btn-block wgg_blue" data-dismiss="modal" type="button">
       OK
      </button>
     </div>
    </div>
   </div>
  </div>
  <script>
   $('#server_error_modal').on('hidden.bs.modal', function (e) {
        e.preventDefault();
        window.location.reload(true);
    });
  </script>
  <div aria-labelledby="bad_request_modal_label" class="modal fade noprint" id="bad_request_modal" role="dialog" style="z-index: 99999;" tabindex="-1">
   <div class="position-relative modal-dialog modal-sm" role="document">
    <div class="position-relative modal-content" style="top: 100px;">
     <div class="modal-header">
      <button aria-label="Schließen" class="close visible-xs-block visible-sm-block" data-dismiss="modal" type="button">
       <span aria-hidden="true">
        ×
       </span>
      </button>
      <h4 class="modal-title text-info text-uppercase" id="bad_request_modal_label">
       Wir entschuldigen uns für die Unannehmlichkeiten.
      </h4>
     </div>
     <div class="modal-body row" id="bad_request_modal_error_body" style="margin: 0;">
      Dieser Dienst ist temporär nicht verfügbar. Wir arbeiten an einer Lösung, bitte versuchen Sie es später noch einmal.
      <br/>
      <br/>
      Vielen Dank für Ihr Verständnis.
     </div>
     <div class="modal-footer">
      <button class="btn btn-block wgg_blue" data-dismiss="modal" type="button">
       OK
      </button>
     </div>
    </div>
   </div>
  </div>
  <script>
   $('#bad_request_modal').on('hidden.bs.modal', function (e) {
        e.preventDefault();
        window.location.reload(true);
    });
  </script>
  <div aria-labelledby="time_out_modal_label" class="modal fade noprint" id="time_out_modal" role="dialog" style="z-index: 1234567860;" tabindex="-1">
   <div class="position-relative modal-dialog modal-sm" role="document">
    <div class="position-relative modal-content" style="top: 100px;">
     <div class="modal-header">
      <button aria-label="Schließen" class="close visible-xs-block visible-sm-block" data-dismiss="modal" type="button">
       <span aria-hidden="true">
        ×
       </span>
      </button>
      <h4 class="modal-title text-info text-uppercase" id="time_out_modal_label">
       Ihre Anfrage scheint abgelaufen zu sein.
      </h4>
     </div>
     <div class="modal-body row" id="time_out_modal_error_body" style="margin: 0;">
      Wenn Sie diese Nachricht schließen, wird die Seite automatisch erneut geladen. Versuchen Sie es anschließend bitte erneut.
      <br/>
      <br/>
      Vielen Dank für ihr Verständnis.
     </div>
     <div class="modal-footer">
      <button class="btn btn-block wgg_blue" data-dismiss="modal" type="button">
       OK
      </button>
     </div>
    </div>
   </div>
  </div>
  <script>
   $('#time_out_modal').on('hidden.bs.modal', function (e) {
        e.preventDefault();
        window.location.reload(true);
    });
  </script>
  <div aria-labelledby="register-modal_label" class="modal fade noprint" id="register_modal" role="dialog" style="z-index: 1234567860;" tabindex="-1">
   <div class="position-relative modal-dialog modal-lg" role="document" style="min-width: 360px;">
    <div class="position-relative modal-content">
     <div class="modal-header p15" style="border: none;">
      <button aria-label="Close" class="close mt0" data-dismiss="modal" type="button">
       <i class="mdi mdi-close">
       </i>
      </button>
     </div>
     <div class="modal-body p0">
      <div class="user_register_data">
       <ul class="nav nav-tabs register_popup_tabs">
        <li class="register_popup_tab active" data-value="0" id="register_private_tab">
         <span>
          Privat
         </span>
        </li>
        <li class="register_popup_tab" data-value="1" id="register_company_tab">
         <span>
          Unternehmen
         </span>
        </li>
       </ul>
       <div class="register_main_box px30 py20">
        <div class="display-none" id="company_user_register_form">
         <form action="#" class="register_company" id="register_company" method="post">
          <div class="row py15 display-flex">
           <div class="col-md-6 hidden-sm hidden-xs px40">
            <h4 class="text-orange m0 mb5 company_register_welcome_text">
             Willkommen in unserem Unternehmensbereich!
            </h4>
            <p class="m0 company_register_welcome_text">
             Melden Sie sich jetzt an und profitieren Sie von exklusiven Funktionen. Gerne beraten wir Sie auch persönlich:
             <a class="light_blue_text_link display-inline-block" href="tel:+49 89 215 286 821">
              +49 89 215 286 821
             </a>
            </p>
            <img class="img-responsive position-absolute" src="/img/register-sofa.png" style="bottom: 15px; left: 15px; max-width: calc(100% + 10px);"/>
           </div>
           <div class="col-md-6 col-sm-12 col-xs-12">
            <div class="form-group">
             <label for="cu_company_name">
              Firmenname *
             </label>
             <input class="form-control wgg_input" id="cu_company_name" maxlength="100" name="company_name" placeholder="Firmenname" tabindex="10" type="text" value=""/>
             <div class="failed_validation_message" id="cu_company_name_failed">
             </div>
            </div>
            <div class="form-group dropdown">
             <label for="cu_gender-dropdown-menu">
              Anrede *
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="cu_user_title" name="title" tabindex="11" title="Anrede">
              <option value="2">
               Frau
              </option>
              <option value="1">
               Herr
              </option>
              <option value="3">
               keine Angabe
              </option>
             </select>
             <div class="failed_validation_message" id="cu_user_title_failed">
             </div>
            </div>
            <div class="row">
             <div class="col-md-6">
              <div class="form-group">
               <label for="cu_first_name">
                Vorname *
               </label>
               <input class="form-control wgg_input" id="cu_first_name" maxlength="50" name="first_name" placeholder="Vorname" tabindex="12" type="text" value=""/>
               <div class="failed_validation_message" id="cu_first_name_failed">
               </div>
              </div>
             </div>
             <div class="col-md-6">
              <div class="form-group">
               <label for="cu_last_name">
                Nachname *
               </label>
               <input class="form-control wgg_input" id="cu_last_name" maxlength="50" name="last_name" placeholder="Nachname" tabindex="13" type="text" value=""/>
               <div class="failed_validation_message" id="cu_last_name_failed">
               </div>
              </div>
             </div>
            </div>
            <div class="form-group">
             <label for="cu_email">
              E-Mail-Adresse *
             </label>
             <input class="form-control wgg_input" id="cu_email" maxlength="191" name="email" oninput="invalidEmailCheck(this, 'Bitte füllen Sie dieses Feld aus.', 'Bitte geben Sie eine gültige E-Mail-Adresse ein.')" oninvalid="invalidEmailCheck(this, 'Bitte füllen Sie dieses Feld aus.', 'Bitte geben Sie eine gültige E-Mail-Adresse ein.')" placeholder="E-Mail-Adresse" required="" tabindex="14" title="Bitte füllen Sie dieses Feld aus." type="email" value=""/>
             <div class="password_missing failed_validation_message" id="cu_email_failed">
             </div>
            </div>
            <div class="form-group">
             <label for="cu_password">
              Passwort (8 - 64 Zeichen) *
             </label>
             <div class="wgg_input_icon_group">
              <input autocapitalize="off" class="form-control wgg_input password password_paste password_live_check" data-title="" data-toggle="tooltip" id="cu_password" maxlength="64" name="password" oninput="passwordMaxCharactersLiveCheck(this)" placeholder="Passwort" tabindex="15" type="password" value=""/>
              <span class="mdi mdi-eye mdi-18px cursor-pointer wgg_input_icon" id="show_pass_cu_button" onclick="showPassword('cu_password', 'show_pass_cu_button'); showPassword('cu_password_2')" title="">
              </span>
             </div>
             <div class="failed_validation_message" id="cu_password_failed">
             </div>
            </div>
            <div class="form-group">
             <label for="cu_password_2">
              Passwort wiederholen *
             </label>
             <input autocapitalize="off" class="form-control wgg_input" id="cu_password_2" maxlength="64" name="password_2" placeholder="Passwort" tabindex="16" type="password" value=""/>
             <div class="failed_validation_message" id="cu_password_2_failed">
             </div>
            </div>
            <div id="cu_register-form-pwd-container">
             <div class="cu_reg-form-pwstrength-viewport-progress">
             </div>
            </div>
            <div class="form-group checkbox">
             <label for="cu_i_agree" style="color: #555;">
              <input id="cu_i_agree" name="i_agree" tabindex="17" type="checkbox" value="1"/>
              Ich habe die
              <a class="light_blue_text_link" data-google-interstitial="false" href="/agb.html" rel="nofollow" target="_blank">
               AGB zur Kenntnis genommen und akzeptiere sie
              </a>
              .
             </label>
             <div class="failed_validation_message" id="cu_i_agree_failed">
             </div>
            </div>
            <div class="form-group register_next_btn">
             <div class="btn btn-block wgg_orange" tabindex="18">
              WEITER
              <span class="mdi mdi-chevron-right mdi-22px mdi-lh mdi-top5">
              </span>
             </div>
            </div>
            <div class="px10">
             Account bereits vorhanden?
             <a class="orange_text_link" href="#" id="cu_hide_register_show_login" tabindex="19">
              Login
             </a>
            </div>
           </div>
          </div>
          <input name="user_type" type="hidden" value="1"/>
          <input name="language_setting" type="hidden" value="de"/>
          <input class="redirection_url" type="hidden" value=""/>
         </form>
         <ul class="display-none noprint">
          <li id="cu_user_title_IS_EMPTY">
           Bitte wählen Sie eine Anrede aus.
          </li>
          <li id="cu_user_title_INVALID">
           Bitte wählen Sie eine Anrede aus.
          </li>
          <li id="cu_user_title_UNKNOWN">
           Bitte wählen Sie eine Anrede aus.
          </li>
          <li id="cu_first_name_IS_EMPTY">
           Bitte geben Sie den Vornamen des Ansprechpartners an.
          </li>
          <li id="cu_first_name_INVALID">
           Bitte geben Sie einen gültigen Vornamen ein.
          </li>
          <li id="cu_first_name_TOO_LONG">
           Der Vorname darf höchstens 50 Zeichen lang sein.
          </li>
          <li id="cu_last_name_IS_EMPTY">
           Bitte geben Sie den Nachnamen des Ansprechpartners an.
          </li>
          <li id="cu_last_name_INVALID">
           Bitte geben Sie einen gültigen Nachnamen ein.
          </li>
          <li id="cu_last_name_TOO_LONG">
           Der Nachname darf höchstens 50 Zeichen lang sein.
          </li>
          <li id="cu_company_name_IS_EMPTY">
           Bitte geben Sie einen Firmennamen an.
          </li>
          <li id="cu_company_name_TOO_LONG">
           Der Firmenname darf höchstens 100 Zeichen lang sein.
          </li>
          <li id="cu_email_IS_EMPTY">
           Bitte geben Sie Ihre E-Mail-Adresse an.
          </li>
          <li id="cu_email_DUPLICATED">
           Die angegebene E-Mail-Adresse ist bereits bei WG-Gesucht.de registriert.
          </li>
          <li id="cu_email_INVALID">
           Bitte geben Sie eine gültige E-Mail-Adresse an.
          </li>
          <li id="cu_email_TOO_LONG">
           Ihre Eingabe ist zu lang, bitte geben Sie höchstens 191 Zeichen ein.
          </li>
          <li id="cu_password_IS_EMPTY">
           Bitte geben Sie ein Passwort ein und wiederholen Sie es im Feld unten.
          </li>
          <li id="cu_password_TOO_SHORT">
           Ihre Eingabe ist zu kurz, bitte geben Sie mindestens 8 Zeichen ein.
          </li>
          <li id="cu_password_TOO_LONG">
           Ihre Eingabe ist zu lang, bitte geben Sie höchstens 64 Zeichen ein.
          </li>
          <li id="cu_password_NO_MATCH">
           Ihre eingetragenen Passwörter stimmen nicht überein.
          </li>
          <li id="cu_password_UNSAFE">
           Das eingegebene Passwort ist sehr unsicher. Bitte wählen Sie ein anderes Passwort.
          </li>
          <li id="cu_i_agree_IS_EMPTY">
           Bitte bestätigen Sie unsere AGB.
          </li>
          <li id="cu_i_agree_INVALID">
           Bitte bestätigen Sie unsere AGB.
          </li>
         </ul>
        </div>
        <script>
         jQuery(document).ready(function () {
        "use strict";

        var options = {};
        options.ui = {
            container: "#cu_register-form-pwd-container",
            showVerdictsInsideProgressBar: true,
            bootstrap3: true,
            viewports: {
                progress: ".cu_reg-form-pwstrength-viewport-progress",
            }
        };
        options.common = {
            minChar: 1
        };
        options.rules = {
            activated: {
                wordRepetitions: true
            }
        };
        options.i18n = {
            t: function (key) {
                var result = translation_lang_verdicts[key];

                return result === key ? '' : result;
            }
        };

        $("#cu_password").pwstrength(options);

        $("#cu_password").pwstrength("addRule", "unsafePasswordsRegexes", function (options, word, score) {
            if (word.match(password_contains_word_password) ||
                word.match(password_contains_single_character_repeated) ||
                word.match(password_contains_letmein)
            ) {
                return score;
            }
            return 0;
        }, -100, true);
    });

    $('#cu_user_title').on('change', function() {
        $(this).closest('.form-group').removeClass('has-error');
        $('#cu_user_title_failed').hide();
    });

    $('#cu_hide_register_show_login').on('click', function() {
        $('#register_modal').modal('hide');
        redirection_url = $('.redirection_url').val();
        setTimeout(function() {
            fireLoginOrRegisterModalRequest('sign_in', redirection_url);
        }, 400);
    });
        </script>
        <div id="private_user_register_form">
         <form action="#" class="register_private" id="register_private" method="post">
          <div class="row py15 display-flex">
           <div class="col-md-6 hidden-sm hidden-xs px40">
            <h4 class="text-orange m0 mb5">
             Schön, dass Sie vorbeischauen!
            </h4>
            <p class="m0">
             Melden Sie sich jetzt an und finden Sie Ihr neues Zuhause oder den idealen Mieter.
            </p>
            <img class="img-responsive position-absolute" src="/img/register-sofa.png" style="bottom: 15px; left: 15px; max-width: calc(100% + 10px);"/>
           </div>
           <div class="col-md-6 col-sm-12 col-xs-12">
            <div class="form-group dropdown">
             <label for="pu_gender-dropdown-menu">
              Anrede *
             </label>
             <select class="selectpicker" data-style="form-control wgg_select" data-width="100%" id="pu_user_title" name="title" tabindex="20" title="Anrede">
              <option value="2">
               Frau
              </option>
              <option value="1">
               Herr
              </option>
              <option value="3">
               keine Angabe
              </option>
             </select>
             <div class="failed_validation_message" id="pu_user_title_failed">
             </div>
            </div>
            <div class="row">
             <div class="col-md-6">
              <div class="form-group">
               <label for="pu_first_name">
                Vorname *
               </label>
               <input class="form-control wgg_input" id="pu_first_name" maxlength="50" name="first_name" placeholder="Vorname" tabindex="21" type="text" value=""/>
               <div class="failed_validation_message" id="pu_first_name_failed">
               </div>
              </div>
             </div>
             <div class="col-md-6">
              <div class="form-group">
               <label for="pu_last_name">
                Nachname *
               </label>
               <input class="form-control wgg_input" id="pu_last_name" maxlength="50" name="last_name" placeholder="Nachname" tabindex="22" type="text" value=""/>
               <div class="failed_validation_message" id="pu_last_name_failed">
               </div>
              </div>
             </div>
            </div>
            <div class="form-group">
             <label for="pu_email">
              E-Mail-Adresse *
             </label>
             <input class="form-control wgg_input" id="pu_email" maxlength="191" name="email" oninput="invalidEmailCheck(this, 'Bitte füllen Sie dieses Feld aus.', 'Bitte geben Sie eine gültige E-Mail-Adresse ein.')" oninvalid="invalidEmailCheck(this, 'Bitte füllen Sie dieses Feld aus.', 'Bitte geben Sie eine gültige E-Mail-Adresse ein.')" placeholder="E-Mail-Adresse" required="" tabindex="23" title="Bitte füllen Sie dieses Feld aus." type="email" value=""/>
             <div class="password_missing failed_validation_message" id="pu_email_failed">
             </div>
            </div>
            <div class="form-group">
             <label for="pu_password">
              Passwort (8 - 64 Zeichen) *
             </label>
             <div class="wgg_input_icon_group">
              <input autocapitalize="off" class="form-control wgg_input password password_paste password_live_check" data-title="" data-toggle="tooltip" id="pu_password" maxlength="64" name="password" oninput="passwordMaxCharactersLiveCheck(this)" placeholder="Passwort" tabindex="24" type="password" value=""/>
              <span class="mdi mdi-eye mdi-18px cursor-pointer wgg_input_icon" id="show_pass_pu_button" onclick="showPassword('pu_password', 'show_pass_pu_button'); showPassword('pu_password_2')" title="">
              </span>
             </div>
             <div class="failed_validation_message" id="pu_password_failed">
             </div>
            </div>
            <div class="form-group">
             <label for="pu_password_2">
              Passwort wiederholen *
             </label>
             <input autocapitalize="off" class="form-control wgg_input" id="pu_password_2" maxlength="64" name="password_2" placeholder="Passwort" tabindex="25" type="password" value=""/>
             <div class="failed_validation_message" id="pu_password_2_failed">
             </div>
            </div>
            <div id="pu_register-form-pwd-container">
             <div class="pu_reg-form-pwstrength-viewport-progress">
             </div>
            </div>
            <div class="form-group checkbox">
             <label for="pu_i_agree" style="color: #555;">
              <input id="pu_i_agree" name="i_agree" tabindex="26" type="checkbox" value="1"/>
              Ich habe die
              <a class="light_blue_text_link" data-google-interstitial="false" href="/agb.html" rel="nofollow" target="_blank">
               AGB zur Kenntnis genommen und akzeptiere sie
              </a>
              .
             </label>
             <div class="failed_validation_message" id="pu_i_agree_failed">
             </div>
            </div>
            <div class="form-group register_next_btn pt15">
             <div class="btn btn-block wgg_orange" tabindex="27">
              WEITER
              <span class="mdi mdi-chevron-right mdi-22px mdi-lh mdi-top5">
              </span>
             </div>
            </div>
            <div class="px10">
             Account bereits vorhanden?
             <a class="orange_text_link" href="#" id="pu_hide_register_show_login" tabindex="28">
              Login
             </a>
            </div>
           </div>
          </div>
          <input name="user_type" type="hidden" value="0"/>
          <input name="language_setting" type="hidden" value="de"/>
          <input class="redirection_url" type="hidden" value=""/>
          <ul class="display-none noprint">
           <li id="pu_user_title_IS_EMPTY">
            Bitte wählen Sie eine Anrede aus.
           </li>
           <li id="pu_user_title_INVALID">
            Bitte wählen Sie eine Anrede aus.
           </li>
           <li id="pu_user_title_UNKNOWN">
            Bitte wählen Sie eine Anrede aus.
           </li>
           <li id="pu_first_name_IS_EMPTY">
            Bitte geben Sie den Vornamen des Ansprechpartners an.
           </li>
           <li id="pu_first_name_INVALID">
            Bitte geben Sie einen gültigen Vornamen ein.
           </li>
           <li id="pu_first_name_TOO_LONG">
            Der Vorname darf höchstens 50 Zeichen lang sein.
           </li>
           <li id="pu_last_name_IS_EMPTY">
            Bitte geben Sie den Nachnamen des Ansprechpartners an.
           </li>
           <li id="pu_last_name_INVALID">
            Bitte geben Sie einen gültigen Nachnamen ein.
           </li>
           <li id="pu_last_name_TOO_LONG">
            Der Nachname darf höchstens 50 Zeichen lang sein.
           </li>
           <li id="pu_email_IS_EMPTY">
            Bitte geben Sie Ihre E-Mail-Adresse an.
           </li>
           <li id="pu_email_DUPLICATED">
            Die angegebene E-Mail-Adresse ist bereits bei WG-Gesucht.de registriert.
           </li>
           <li id="pu_email_INVALID">
            Bitte geben Sie eine gültige E-Mail-Adresse an.
           </li>
           <li id="pu_email_TOO_LONG">
            Ihre Eingabe ist zu lang, bitte geben Sie höchstens 191 Zeichen ein.
           </li>
           <li id="pu_password_IS_EMPTY">
            Bitte geben Sie ein Passwort ein und wiederholen Sie es im Feld unten.
           </li>
           <li id="pu_password_TOO_SHORT">
            Ihre Eingabe ist zu kurz, bitte geben Sie mindestens 8 Zeichen ein.
           </li>
           <li id="pu_password_TOO_LONG">
            Ihre Eingabe ist zu lang, bitte geben Sie höchstens 64 Zeichen ein.
           </li>
           <li id="pu_password_NO_MATCH">
            Ihre eingetragenen Passwörter stimmen nicht überein.
           </li>
           <li id="pu_password_UNSAFE">
            Das eingegebene Passwort ist sehr unsicher. Bitte wählen Sie ein anderes Passwort.
           </li>
           <li id="pu_i_agree_IS_EMPTY">
            Bitte bestätigen Sie unsere AGB.
           </li>
           <li id="pu_i_agree_INVALID">
            Bitte bestätigen Sie unsere AGB.
           </li>
          </ul>
         </form>
        </div>
        <script>
         jQuery(document).ready(function () {
        "use strict";

        var options = {};
        options.ui = {
            container: "#pu_register-form-pwd-container",
            showVerdictsInsideProgressBar: true,
            bootstrap3: true,
            viewports: {
                progress: ".pu_reg-form-pwstrength-viewport-progress",
            }
        };
        options.common = {
            minChar: 1
        };
        options.rules = {
            activated: {
                wordRepetitions: true
            }
        };
        options.i18n = {
            t: function (key) {
                var result = translation_lang_verdicts[key];

                return result === key ? '' : result;
            }
        };

        $("#pu_password").pwstrength(options);

        $("#pu_password").pwstrength("addRule", "unsafePasswordsRegexes", function (options, word, score) {
            if (word.match(password_contains_word_password) ||
                word.match(password_contains_single_character_repeated) ||
                word.match(password_contains_letmein)
            ) {
                return score;
            }
            return 0;
        }, -100, true);
    });

    $('#pu_user_title').on('change', function() {
        $(this).closest('.form-group').removeClass('has-error');
        $('#pu_user_title_failed').hide();
    });

    $('#pu_hide_register_show_login').on('click', function() {
        $('#register_modal').modal('hide');
        redirection_url = $('.redirection_url').val();
        setTimeout(function() {
            fireLoginOrRegisterModalRequest('sign_in', redirection_url);
        }, 400);
    });
        </script>
       </div>
      </div>
      <div class="display-none gdpr_data mx15">
       <form action="#" id="register_gdpr" method="post">
        <input name="gdpr_checkbox_0" type="hidden" value="0"/>
        <input name="gdpr_checkbox_1" type="hidden" value="0"/>
        <input name="gdpr_checkbox_2" type="hidden" value="0"/>
        <div id="gdpr_settings">
        </div>
        <input name="policy_version" type="hidden" value="1"/>
        <div class="alert alert-without-icon alert-danger display-none" id="gdpr_confirmation_error" role="alert">
         <div class="alert-body">
          Das EU-Gesetz der Datenschutzgrundverordnung schreibt vor, dass Nutzer zustimmen, wenn die personenbezogenen Daten Vor- und Nachname sowie E-Mail-Adresse verwendet werden. Diese Daten sind notwendig, um sich zu registrieren, mit anderen Nutzern in Kontakt zu treten und so eine erfolgreiche Vermittlung von Wohnraum zu ermöglichen.
          <br/>
          <br/>
          Wenn Sie die erste Checkbox nicht markieren, können Sie WG-Gesucht.de laut DSGVO nicht nutzen. Wir werden niemals Ihre personenbezogenen Daten unberechtigt an Dritte weitergeben.
         </div>
        </div>
        <div class="form-group col-xs-12">
         <input class="btn btn-block wgg_blue" tabindex="29" type="submit" value="Account erstellen"/>
        </div>
        <div class="form-group register_previous_btn text-center">
         <div class="btn wgg_tertiary" tabindex="30">
          <span class="pull-left mdi mdi-chevron-left mdi-24px" id="glyph" style="line-height: 0.8;">
          </span>
          <span style="margin-left: 3px">
           Zurück
          </span>
         </div>
        </div>
       </form>
      </div>
     </div>
    </div>
   </div>
  </div>
  <script src="/js/translations/de_de/pwstrength-bootstrap-3.0.1.js">
  </script>
  <script src="/js/external_libraries/pwstrength-bootstrap-3.0.1.min.js">
  </script>
  <script>
   var gdpr_read_more_button = "";
    var gdpr_read_less_button = "";

        jQuery(document).ready(function () {
        "use strict";

        $('#register_company_tab').on('click', function() {
            $('#company_user_register_form').show();
            $('#private_user_register_form').hide();
            $(this).addClass("active");
            $("#register_private_tab").removeClass("active");

            gdpr_policies.updateState({
                'user_type' : '1'
            });
        });
        $('#register_private_tab').on('click', function() {
            $('#private_user_register_form').show();
            $('#company_user_register_form').hide();
            $(this).addClass("active");
            $("#register_company_tab").removeClass("active");

            gdpr_policies.updateState({
                'user_type' : '0'
            });
        });
    });
  </script>
  <div aria-labelledby="login-modal_label" class="modal fade noprint" id="login_modal" role="dialog" style="z-index: 1234567860; padding-top: 100px;" tabindex="-1">
   <div class="modal-dialog modal-sm" role="document" style="min-width: 360px;">
    <div class="position-relative modal-content">
     <div class="modal-header p15" style="border: none;">
      <button aria-label="Schließen" class="close mt0" data-dismiss="modal" type="button">
       <i class="mdi mdi-close">
       </i>
      </button>
      <div class="login_data">
       <div class="display-none text-info text-center" id="error_msg_after_reg">
        Herzlichen Glückwunsch, Ihr Account wurde erstellt. Bitte loggen Sie sich ein.
       </div>
      </div>
      <div class="gdpr_decline_warning display-none">
       <h4 class="modal-title text-info text-uppercase">
        ACHTUNG
       </h4>
      </div>
      <div class="delete_account_through_login display-none">
       <h4 class="modal-title text-info text-uppercase">
        ACCOUNT LÖSCHEN
       </h4>
      </div>
     </div>
     <div class="modal-body row pt0 px30 pb30">
      <div class="col-md-12 display-none login_data" id="credentials_error">
       <div class="alert alert-without-icon alert-danger" role="alert">
        <div class="alert-body">
         <span class="display-none" id="credentials_invalid">
          Bitte geben Sie eine gültige E-Mail-Adresse und/oder ein Passwort ein.
         </span>
         <span class="display-none" id="credentials_unknown">
          Unbekannte E-Mail-Adresse oder Passwort. Bitte versuchen Sie es erneut.
         </span>
        </div>
       </div>
      </div>
      <form action="#" class="login_data" id="login_basic" method="POST" novalidate="">
       <div class="col-md-12 mb30">
        <h4 class="m0 mb5">
         Willkommen zurück
        </h4>
        <p class="m0">
         Schön, dass Sie wieder da sind! Um von allen Vorteilen auf
         <span class="text-bold display-inline-block">
          WG-Gesucht.de
         </span>
         zu profitieren, melden Sie sich bitte an. Wir wünschen Ihnen viel Erfolg.
        </p>
       </div>
       <div class="mb10">
        <div class="col-md-12 form-group">
         <label class="text-normal">
          E-Mail-Adresse:
         </label>
         <input class="form-control wgg_input" id="login_email_username" maxlength="191" name="login_email_username" tabindex="31" type="email" value=""/>
         <div class="failed_validation_message" id="login_email_username_failed">
         </div>
        </div>
        <div class="col-md-12 form-group">
         <label class="text-normal">
          Passwort:
         </label>
         <div class="wgg_input_icon_group">
          <input autocapitalize="off" class="form-control wgg_input" id="login_password" maxlength="64" name="login_password" tabindex="32" type="password" value=""/>
          <span class="mdi mdi-eye mdi-18px cursor-pointer wgg_input_icon" id="login_show_pass_button" onclick="showPassword('login_password', 'login_show_pass_button');" title="Passwort anzeigen" type="button">
          </span>
         </div>
         <div class="text-right">
          <a class="orange_text_link" href="/passworterinnerung.html" tabindex="33">
           Passwort vergessen?
          </a>
         </div>
         <div class="failed_validation_message" id="login_password_failed">
         </div>
        </div>
        <div class="col-md-12">
         <label class="position-relative cursor-pointer" for="auto_login" style="font-weight: normal; bottom: 2px;">
          <input checked="" id="auto_login" name="login_form_auto_login" tabindex="34" type="checkbox" value="1"/>
          Angemeldet bleiben
         </label>
        </div>
        <div class="col-md-12 mt10">
         <input class="btn btn-block wgg_orange" id="login_submit" tabindex="35" type="submit" value="Login"/>
        </div>
        <input name="display_language" type="hidden" value="de"/>
       </div>
       <div class="display-none" id="gdpr_login_data">
        <div class="col-xs-12" id="gdpr_setting_login_form">
        </div>
        <div class="col-md-6 mb5">
         <input class="btn btn-block btn-danger" id="login_delete_account" tabindex="36" type="button" value="ABLEHNEN"/>
        </div>
        <div class="col-md-6">
         <input class="btn btn-block wgg_blue" disabled="true" id="accept_mandatory_gdpr" tabindex="37" type="button" value="AKZEPTIEREN"/>
        </div>
       </div>
      </form>
      <div class="gdpr_decline_warning display-none">
       <div class="col-md-12 mb20">
        Sie haben die Checkbox nicht markiert und damit der Verarbeitung Ihrer personenbezogenen Daten nicht zugestimmt. Damit können Sie WG-Gesucht.de nicht nutzen. Laut Datenschutzgrundverordnung muss Ihr Account in diesem Fall gelöscht werden.
        <br/>
        Bei Fragen zum Datenschutz wenden Sie sich bitte an unsere Kundenbetreuung unter
        <span class="emlcry1">
         <span class="emlcry2">
          kontakt
         </span>
         [at]
         <span class="emlcry3">
          wg-gesucht[dot]de
         </span>
        </span>
        .
        <br/>
        Sind Sie sicher, dass Sie Ihren Account wirklich löschen möchten?
        <br/>
       </div>
       <div class="col-md-6 mb5">
        <input class="btn btn-block wgg_blue back_to_login_form" tabindex="38" type="button" value="Zurück"/>
       </div>
       <div class="col-md-6">
        <input class="btn btn-block btn-danger" id="delete_account_proceed" tabindex="39" type="button" value="Löschen"/>
       </div>
      </div>
      <div class="display-none delete_account_through_login">
       <div class="col-xs-12">
        <div class="alert alert-without-icon alert-danger display-none" id="delete_account_credentials_error" role="alert">
         <div class="alert-body">
          Falsche E-Mail-Adresse / Benutzername oder Passwort.
         </div>
        </div>
        <div class="alert alert-without-icon alert-danger display-none" id="delete_account_unknown_error" role="alert">
         <div class="alert-body">
          Beim Löschen des Accounts ist ein Fehler aufgetreten. Wir bitten, dies zu entschuldigen.
         </div>
        </div>
       </div>
       <form action="" class="position-relative" id="deleteAccountThroughLoginForm" method="POST" name="deleteAccountThroughLoginForm">
        <div class="col-xs-12">
         <div class="form-group">
          <input class="form-control wgg_input" id="delete_login_email_username" maxlength="191" name="login_email_username" oninput="invalidEmailCheck(this, 'Bitte füllen Sie dieses Feld aus.', 'Bitte geben Sie eine gültige E-Mail-Adresse ein.')" oninvalid="invalidEmailCheck(this, 'Bitte füllen Sie dieses Feld aus.', 'Bitte geben Sie eine gültige E-Mail-Adresse ein.')" placeholder="E-Mail-Adresse:" required="" tabindex="40" title="Bitte füllen Sie dieses Feld aus." type="email" value=""/>
         </div>
        </div>
        <div class="col-xs-12">
         <div class="wgg_input_icon_group">
          <input autocapitalize="off" class="form-control wgg_input" id="delete_account_password" maxlength="64" name="login_password" placeholder="Passwort:" tabindex="41" type="password" value=""/>
          <div class="wgg_input_icon_group">
           <input autocapitalize="off" class="form-control wgg_input" id="login_password" maxlength="64" name="login_password" tabindex="42" type="password" value=""/>
           <span class="mdi mdi-eye mdi-18px cursor-pointer wgg_input_icon" id="show_delete_password_button" onclick="showPassword('show_delete_password_button', 'login_show_pass_button');" title="Passwort anzeigen">
           </span>
          </div>
         </div>
        </div>
        <br/>
        <div class="col-xs-12 col-md-6 mb5">
         <input class="btn btn-block wgg_blue back_to_login_form" tabindex="43" type="button" value="Zurück"/>
        </div>
        <input class="csrf_token" name="csrf_token" type="hidden" value=""/>
        <div class="col-xs-12 col-md-6">
         <input class="btn btn-block btn-danger" id="delete_account_proceed" tabindex="44" type="submit" value="Löschen"/>
        </div>
       </form>
      </div>
      <div class="col-md-12 login_data mt35">
       <p>
        Noch kein Konto?
       </p>
       <a class="btn btn-block wgg_orange-outline" href="#" id="hide_login_show_register" tabindex="45">
        Kostenfrei registrieren
       </a>
      </div>
      <input class="redirection_url" type="hidden" value=""/>
     </div>
    </div>
   </div>
  </div>
  <ul class="display-none noprint">
   <li id="login_email_username_IS_EMPTY">
    Bitte geben Sie eine E-Mail-Adresse ein.
   </li>
   <li id="login_password_IS_EMPTY">
    Bitte geben Sie ein Passwort ein.
   </li>
  </ul>
  <script>
   $('#hide_login_show_register').on('click', function() {
        $('#login_modal').modal('hide');
        redirection_url = $('.redirection_url').val();
        setTimeout(function() {
            fireLoginOrRegisterModalRequest('sign_up', redirection_url);
        }, 400);
    });
  </script>
  <div aria-labelledby="gdpr-modal_label" class="modal fade noprint" id="gdpr_modal" role="dialog" style="z-index: 1234567860;" tabindex="-1">
   <div class="position-relative modal-dialog modal-md" role="document" style="min-width: 360px;">
    <div class="position-relative modal-content">
     <div class="modal-header">
      <button aria-label="Schließen" class="close visible-xs-block visible-sm-block" data-dismiss="modal" type="button">
       <span aria-hidden="true">
        ×
       </span>
      </button>
      <h4 class="modal-title text-info text-uppercase" id="gdpr-modal_label">
       Datenschutzgrundverordnung
      </h4>
     </div>
     <div class="modal-body row">
      <div class="col-xs-12">
       <form action="" class="position-relative" id="gdpr_settings_login_form" method="POST" name="gdpr_settings_form">
        <div class="display-none info_message alert alert-without-icon alert-success mt10" id="success-placeholder" role="alert">
        </div>
        <div id="gdpr_settings_login">
        </div>
        <input class="csrf_token" name="csrf_token" type="hidden" value=""/>
        <input name="policy_version" type="hidden" value="1"/>
        <input name="display_language" type="hidden" value="de"/>
        <input name="login_email_username" type="hidden" value=""/>
        <input name="login_password" type="hidden" value=""/>
        <div class="alert alert-without-icon alert-danger display-none" id="gdpr_login_confirmation_error" role="alert">
         <div class="alert-body">
          Sie haben die erste Checkbox nicht markiert. Damit können Sie Ihren Account nicht mehr nutzen. Bitte beachten Sie, dass sich am Umgang mit Ihren Daten auf WG-Gesucht.de nach dem 25. Mai nichts ändert. Bei Ihrer Registrierung haben Sie unseren AGB und den Datenschutzbestimmungen bereits zugestimmt. Wir sind aufgrund des EU-Gesetzes allerdings verpflichtet, die Zustimmung erneut einzuholen.
         </div>
        </div>
        <div class="form-group" id="save_gdpr_settings">
         <input class="btn form-control wgg_orange" tabindex="46" type="submit" value="Änderungen übernehmen"/>
        </div>
        <div class="row form-group display-none" id="accept_decline_gdpr_settings">
         <div class="col-md-4">
          <input class="btn btn-block btn-danger" id="decline_gdpr_policies_btn" tabindex="47" type="button" value="ABLEHNEN"/>
         </div>
         <div class="col-md-4 col-md-offset-4">
          <input class="btn btn-block wgg_blue" disabled="true" id="accept_gdpr_policies_btn" tabindex="48" type="button" value="AKZEPTIEREN"/>
         </div>
        </div>
       </form>
      </div>
     </div>
    </div>
   </div>
  </div>
  <script>
   var gdpr_read_more_button = "Lesen Sie mehr dazu";
    var gdpr_read_less_button = "Text ausblenden";

    // Opening a modal the instant another modal closes, fails to add the modal-open class to the body, thus preventing scroll
    $('#gdpr_modal').on('shown.bs.modal', function(e) {
        $('body').addClass('modal-open');
    });
  </script>
  <script src="/ajax/api/Smp/js/Register.tjb1698761961.js">
  </script>
  <script src="/js/User/GdprPolicies.class.tjb1699368845.js">
  </script>
  <script>
   window.gdpr_policies = GdprPolicies({
                language: site_language,
                domain_base: domain_base,
                min_log_level: '5'
            })
  </script>
  <div class="modal fade noprint mt80" id="unlock_benefits_modal" role="dialog">
   <div class="modal-dialog" role="document">
    <div class="modal-content" style="border-radius: 6px">
     <div class="modal-header" style="border-bottom: 0;">
      <span class="mdi mdi-close mdi-26px text-medium-gray pull-right cursor-pointer" data-dismiss="modal">
      </span>
     </div>
     <div class="modal-body pt30 pb80">
      <div class="row">
       <div class="col-xs-12">
        <div class="text-center mb50">
         <p class="font-20px">
          <b>
           Möchten Sie als Premium Mitglied fortfahren?
          </b>
         </p>
        </div>
       </div>
      </div>
      <div class="row">
       <div class="col-xs-6 col-sm-offset-2 col-sm-4">
        <a class="campaign_click display-block text-center p30 background-gray black_text_link" data-campaign_click_position="homescreen_lock_icon" data-campaign_click_source="advertise_button" data-campaign_partner="WG-Gesucht" data-campaign_type="wggpro_promotion" data-google-interstitial="false" href="/shop.html" style="border-radius: 6px;">
         <img alt="Anbieten" class="center-block mb10" src="/img/icons/shop_promo_landlord.svg"/>
         <b class="font-16px text-black">
          Anbieten
         </b>
        </a>
       </div>
       <div class="col-xs-6 col-sm-4">
        <a class="campaign_click display-block text-center p30 background-gray black_text_link" data-campaign_click_position="homescreen_lock_icon" data-campaign_click_source="search_button" data-campaign_partner="WG-Gesucht" data-campaign_type="wggplus_promotion" data-google-interstitial="false" href="/wgg-plus-shop.html?standalone=1" style="border-radius: 6px;">
         <img alt="Suchen" class="center-block mb10" src="/img/icons/shop_promo_search.svg"/>
         <b class="font-16px text-black">
          Suchen
         </b>
        </a>
       </div>
      </div>
     </div>
    </div>
   </div># Example of extracting titles, prices, and URLs
titles = soup.find_all('h2')  # Replace 'h2' with the appropriate tag for titles
prices = soup.find_all('span', class_='price')  # Adjust class name as needed
urls = soup.find_all('a', href=True)  # This retrieves all links

# Extract text from the elements
data = []
for title, price, url in zip(titles, prices, urls):
    data.append({
        'Title': title.get_text(strip=True),
        'Price': price.get_text(strip=True),
        'URL': url['href']  # Assuming you want the href attribute
    })

# Display extracted data
print(data)

  </div>
  <script src="/ajax/api/Smp/js/Session.tjb1698761961.js">
  </script>
  <script src="/js/jquery/jquery.featherlight.min.tjb1632386809.js">
  </script>
  <script src="/js/lib/Validation/FavouritesValidation.lib.tjb1632386809.js">
  </script>
  <script src="/js/lib/FavouritesManipulation.lib.tjb1688571989.js">
  </script>
  <script src="/js/User/Favourites.class.tjb1645637673.js">
  </script>
  <script>
   var config = {
            language: site_language,
            user_id:  user_id,
            min_log_level: '5'
        }
        window.favourites = Favourites(config);
  </script>
  <script>
   $(function() {
            if (logged_in) {
                favourites.syncFavourites();
            }

            $('.asset_favourite').on('click', function(e) {
                favourites.changeFavouriteStatusOfAdFromList(this);
            });
        });
  </script>
 </body>
</html>
"""

# %%
# Example of extracting titles, prices, and URLs
titles = soup.find_all('h2')  # Replace 'h2' with the appropriate tag for titles
prices = soup.find_all('span', class_='price')  # Adjust class name as needed
urls = soup.find_all('a', href=True)  # This retrieves all links

# Extract text from the elements
data = []
for title, price, url in zip(titles, prices, urls):
    data.append({
        'Title': title.get_text(strip=True),
        'Price': price.get_text(strip=True),
        'URL': url['href']  # Assuming you want the href attribute
    })

# Display extracted data
print(data)
